# %% [markdown]
# ### Parsing Steps
#     - Use parser (stanford or bllip) to parse each sentence
#     - For each noun phrase, travel up the tree to find verb.
#     - Write wordnet ancestor search to resolve references from noun phrase to ingredient
#     - Keep dict of ingredients -> counter of actions
#
# ### Search Steps
#     - For given set of ingredients
#         - Sort recipes by most shared ingredients
#         - For any missing ingredients, see how similar the dict entries are to determine if can substitute

# %%
import os
from nltk.parse import stanford
from nltk.tree import Tree

os.environ['STANFORD_PARSER'] = 'stanford-parser-full-2015-01-30/'
os.environ['STANFORD_MODELS'] = 'stanford-parser-full-2015-01-30/'
parser = stanford.StanfordParser(model_path="stanford-parser-full-2015-01-30/englishPCFG.ser.gz")

def parse_sentences(sentences):
    """ returns list of Tree's for input list of strings """
    return parser.parse_sents([sentence.split() for sentence in sentences])

def draw_sentences(tree_list):
    """ GUI debugging """
    for sentence in tree_list:
        sentence.draw()

# %%
import json
with open('sample.json') as f:
    sample_recipe = json.load(f)

# %%
with open('bigoven_cleaned.json') as f:
    test_recipes = json.load(f)[0:100]

# %%
def process_recipe(recipe):
    print 'Ingredients:'
    for ingredient in recipe['ingredients']:
        print ingredient
    
    print 'Instructions:'
    instr_trees = parse_sentences(recipe['instructions'])
    for instruction, tree in zip(recipe['instructions'], instr_trees):
        print instruction
        #print tree
    
    return instr_trees
    
    #draw_sentences(instr_trees)
    
trees = process_recipe(sample_recipe)
# Out:
# Ingredients:
# {u'name': u'Lasagna noodles ', u'unit': u'package (~12 oz.)', u'quantity': u'1'}
# {u'name': u'Olive oil', u'unit': u'ml', u'quantity': u'30'}
# {u'name': u'Tomato basil pasta sauce', u'unit': u'jars', u'quantity': u'1 1/2'}
# {u'name': u'Ricotta Cheese part skim', u'unit': u'16 oz container', u'quantity': u'1'}
# {u'name': u'Roasted garlic', u'unit': u'cloves', u'quantity': u'10'}
# {u'name': u'Fresh baby spinach', u'unit': u'handfuls', u'quantity': u'4'}
# {u'name': u'Artichoke hearts (in water)', u'unit': u'15 oz can/jar', u'quantity': u'1'}
# {u'name': u'Dried parsley', u'unit': u'ml', u'quantity': u'2'}
# {u'name': u'Red pepper flakes', u'unit': u'ml', u'quantity': u'2'}
# {u'name': u'Ground black pepper ', u'unit': u'ml', u'quantity': u'2'}
# {u'name': u'Parmesan cheese', u'unit': u'ml', u'quantity': u'177'}
# {u'name': u'Monterey jack cheese, reduced fat', u'unit': u'g', u'quantity': u'170'}
# {u'name': u'Part Skim Mozzarella Cheese', u'unit': u'g', u'quantity': u'170'}
# {u'name': u'Fresh basil', u'unit': u'ml', u'quantity': u'59'}
# Instructions:
# Bring large pot of water to a boil.
# While water is heating up, mix the ricotta, roasted garlic, spinach, artichoke hearts, dried parsley, red pepper flakes, black pepper and 1/4 cup parmesan cheese together in a large bowl.
# Pour 1 tablespoon of olive oil in the boiling water before adding the pasta.
# Cook the pasta a few minutes or until about halfway cooked, then drain.
# Drizzle the remaining tablespoon of olive oil in a large rectangular glass pan.
# Layer a little bit of the pasta sauce on the bottom of the pan.
# Layer 1/3 of the pasta noodles in the pan.
# Layer a little more pasta sauce on top of the noodles.
# Take 1/2 of the ricotta mixture and drop evenly over the noodles and sauce in the pan.
# Top the ricotta with 1/3 of the jack cheese and 1/3 of the mozzarella.
# Layer another 1/3 of the noodles in the pan with more sauce on top.
# Finish dropping the rest of the ricotta mixture over the lasagna.
# Top with 1/3 of the jack cheese and 1/3 of the mozzarella.
# Use the rest of the noodles and top with the rest of the sauce.
# Sprinkle the top of the lasagna with the remaining parmesan, jack, and mozzarella cheeses.
# Bake in a 375 degree oven until hot, golden and bubbly, making sure the noodles are cooked through (about 40 minutes.)
# Top with fresh basil before serving.

# %%
tree = trees[0]

for sub in tree.subtrees():
    print sub
    if sub == tree:
        print 'same'

for sub in tree.subtrees(lambda t: t.label() in ['VP']):
    print sub.label()
    for sub2 in tree.subtrees(lambda t: t.label() in ['VP']):
        print sub2.label()
        print sub2
        if sub2 == sub:
            print 'same'

print ''
# Out:
# (ROOT
#   (S
#     (VP
#       (VB Bring)
#       (NP (NP (JJ large) (NN pot)) (PP (IN of) (NP (NN water))))
#       (PP (TO to) (NP (DT a) (NN boil.))))))
# same
# (S
#   (VP
#     (VB Bring)
#     (NP (NP (JJ large) (NN pot)) (PP (IN of) (NP (NN water))))
#     (PP (TO to) (NP (DT a) (NN boil.)))))
# (VP
#   (VB Bring)
#   (NP (NP (JJ large) (NN pot)) (PP (IN of) (NP (NN water))))
#   (PP (TO to) (NP (DT a) (NN boil.))))
# (VB Bring)
# (NP (NP (JJ large) (NN pot)) (PP (IN of) (NP (NN water))))
# (NP (JJ large) (NN pot))
# (JJ large)
# (NN pot)
# (PP (IN of) (NP (NN water)))
# (IN of)
# (NP (NN water))
# (NN water)
# (PP (TO to) (NP (DT a) (NN boil.)))
# (TO to)
# (NP (DT a) (NN boil.))
# (DT a)
# (NN boil.)
# VP
# VP
# (VP
#   (VB Bring)
#   (NP (NP (JJ large) (NN pot)) (PP (IN of) (NP (NN water))))
#   (PP (TO to) (NP (DT a) (NN boil.))))
# same

# %%
from collections import Counter

"""
Search subtrees, calling match_noun_to_verb() on every verb phrase.
"""
def crawl_tree(tree, ingredients, knowledge_base):
    for child in tree.subtrees(lambda t: t.label() in ['VP']):
        #print 'found verb phrase:', child.flatten(), 'Looking for noun in children.'
        
        for ing in match_noun_to_verb_phrase(child):
            
            knowledge_base[ing].update(find_verb(child, ing))
        
"""
Returns the verb phrase's VB's and NN's.
"""
def find_verb(vp, ingredient):
    return filter(lambda w: w[1] in ['VB'] and w[0] not in [ingredient], vp.pos())
        
        
"""
Search subtrees for ingredient(s) affected by the verb in a verb phrase.
"""
def match_noun_to_verb_phrase(tree):
    matches = []
    for child in tree.subtrees(lambda t: t.label() in ['NP']):
        #print 'found NP:', child.flatten()
        (ingredient_match, confidence) = resolve_np(child, ingredients)
        if confidence > 0:
            matches.append(ingredient_match)
            #print 'confident match! saving:', ingredient_match, verb.flatten()
                
    return matches


"""
For Tree np and list ingredients, tries to find match between np and ingredients.
Returns (matched_ingredient_name, confidence)
"""
def resolve_np(np, ingredients):
    np_flat = ' '.join(np.flatten())
    
    np_flat = norm_noun(np_flat)
    
    #print 'Trying to resolve NP:', np_flat
    
    matches = [(ing, wordnet_search(np_flat, norm_noun(ing))) for ing in ingredients]
    
    if matches:
        match = max(matches, key=lambda e:e[1])

        min_confidence = 0.9
        if match[1] > min_confidence:
            print 'WordNet match: ', np_flat, match
            return match

    #print 'Found no match.'
    
    return ('', 0)


"""
Searches through wordnet for common ancestors between two strings.
"""
from nltk.corpus import wordnet as wn

def wordnet_search(ing1, ing2):
    # Exact match is exact
    if ing1.lower() == ing2.lower():
        return 1
    
    full_syns1 = wn.synsets(ing1)
    full_syns2 = wn.synsets(ing2)
    
    
    if full_syns1 == []:
        full_syns1 = wn.synsets(normed_noun_truncate(ing1))
    
    if full_syns2 == []:
        full_syns2 = wn.synsets(normed_noun_truncate(ing2))

    
    possible_matches = [ syn1.wup_similarity(syn2) for syn2 in full_syns2 for syn1 in full_syns1]
    if len(possible_matches) > 0:
        return max(possible_matches)
    
    return 0

"""
Gets singular form of noun.
Runs lemmatizer on last word, prepends rest of name
"""
from nltk.stem.wordnet import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
def norm_noun(noun):
    # TODO handle 'artichoke hearts', ex
    
    # strip ( ,
    noun = noun.split('(')[0].split(',')[0].strip(' .?!')
    
    # remove leading "the"
    leading_strip = ['the ', 'rest of the ']
    for banned in leading_strip:
        if noun.startswith(banned):
            noun = noun[len(banned):]
    
    pieces = noun.split()
    
    if len(pieces) > 0:
        return '_'.join(pieces[:-1] + [lemmatizer.lemmatize(pieces[-1], pos='n')])
    return noun

"""
Drops first word from multi-word noun phrase.
"""
def normed_noun_truncate(noun):
    return '_'.join(noun.split('_')[1:])

def print_knowledge_base(knowledge_base):
    for ingredient,matches in knowledge_base.iteritems():
        print ingredient
        print '\t', matches

# %%
# Runs above algorithm on ten sample recipes
total_kb = {}
for r in test_recipes:
    ingredients = [ing['name'].lower() for ing in r['ingredients']]
    # ingredients.append('meat')
    # ingredients.append('noodles')
    
    knowledge_base = {ing : Counter() for ing in ingredients}
    
    for tree in process_recipe(r):
        crawl_tree(tree, ingredients, knowledge_base)
#     print_knowledge_base(knowledge_base)
    
    # merge knowledge_base into total_kb
    for ingredient,matches in knowledge_base.iteritems():
        if ingredient in total_kb:
            knowledge_base[ingredient] = matches.update(total_kb[ingredient])
    total_kb.update(knowledge_base)
# Out:
# Ingredients:
# {u'name': u'frozen young turkey', u'unit': u'kg', u'quantity': u'7'}
# {u'name': u'Kosher salt', u'unit': u'ml', u'quantity': u'237'}
# {u'name': u'Light brown sugar', u'unit': u'ml', u'quantity': u'118'}
# {u'name': u'Water', u'unit': u'l', u'quantity': u'4'}
# {u'name': u'black peppercorns', u'unit': u'ml', u'quantity': u'15'}
# {u'name': u'allspice berry', u'unit': u'ml', u'quantity': u'7'}
# {u'name': u'Water', u'unit': u'l', u'quantity': u'4'}
# {u'name': u'red apple', u'unit': u'', u'quantity': u'1'}
# {u'name': u'onion', u'unit': u'', u'quantity': u'1/2'}
# {u'name': u'Cinnamon', u'unit': u'', u'quantity': u'1'}
# {u'name': u'Water', u'unit': u'ml', u'quantity': u'237'}
# {u'name': u'rosemary', u'unit': u'sprigs', u'quantity': u'4'}
# {u'name': u'leaves sage', u'unit': u'', u'quantity': u'6'}
# {u'name': u'Canola Oil', u'unit': u'ml', u'quantity': u'118'}
# Instructions:
# Combine all brine ingredients, except ice water, in a stock pot and bring to a boil.
# Stir to dissolve solids, then remove from heat, cool to room temperature refrigerate until thoroughly chilled.
# Early on the day of cooking, (or late the night before) combine the brine and ice water in a clean 5 gallon bucket.
# Place thawed turkey breast side down in brine, cover, and refrigerate or set in cool area (like a basement) for 6 hours.
# Turn turkey over once, half way through brining.
# A few minutes before roasting, heat oven to 500 degrees.
# Combine the apple, onion, cinnamon stick and cup of water in a microwave safe dish and microwave on high for 5 minutes.
# Remove bird from brine and rinse inside and out with cold water.
# Discard brine.
# Place bird on roasting rack inside wide, low pan and pat dry with paper towels.
# Add steeped aromatics to cavity along with rosemary and sage.
# Tuck back wings and coat whole bird liberally with canola (or other neutral) oil.
# Roast on lowest level of the oven at 500F for 30 minutes.
# Remove from oven and cover breast with double layer of aluminum foil, insert probe thermometer into thickest part of the breast and return to oven, reducing temperature to 350 degrees F.
# Set thermometer alarm (if available) to 161 degrees F.
# A 14-16 pound bird should require a total of 2-2 1/2 hours of roasting.
# Let turkey rest, loosely covered for 15 minutes before carving.
# WordNet match:  apple (u'red apple', 1.0)
# WordNet match:  apple (u'red apple', 1.0)
# WordNet match:  water (u'water', 1)
# Ingredients:
# {u'name': u'Salt', u'unit': u'ml', u'quantity': u'237'}
# {u'name': u'Brown sugar', u'unit': u'ml', u'quantity': u'237'}
# {u'name': u'oranges', u'unit': u'', u'quantity': u'2'}
# {u'name': u'lemons', u'unit': u'', u'quantity': u'2'}
# {u'name': u'thyme', u'unit': u'sprigs', u'quantity': u'6'}
# {u'name': u'rosemary', u'unit': u'sprigs', u'quantity': u'4'}
# {u'name': u'turkey', u'unit': u'kg', u'quantity': u'5'}
# {u'name': u'orange', u'unit': u'large', u'quantity': u'1'}
# {u'name': u'unsalted butter', u'unit': u'ml', u'quantity': u'59'}
# {u'name': u'yellow onion', u'unit': u'large', u'quantity': u'1'}
# {u'name': u'celery', u'unit': u'stalk', u'quantity': u'1'}
# {u'name': u'carrot', u'unit': u'large', u'quantity': u'1'}
# {u'name': u'Bay Leaves', u'unit': u'', u'quantity': u'2'}
# {u'name': u'thyme', u'unit': u'sprigs', u'quantity': u'2'}
# {u'name': u'rosemary', u'unit': u'sprigs', u'quantity': u'2'}
# {u'name': u'Sage', u'unit': u'bunch', u'quantity': u'1/2'}
# {u'name': u'parsley', u'unit': u'sprigs ', u'quantity': u'3'}
# {u'name': u'chicken or turkey stock', u'unit': u'ml', u'quantity': u'355'}
# {u'name': u'Vegetable oil', u'unit': u'ml', u'quantity': u'15'}
# {u'name': u'Reserved turkey neck and giblets', u'unit': u'', u'quantity': u'1'}
# {u'name': u'carrot', u'unit': u'large', u'quantity': u'1'}
# {u'name': u'onion', u'unit': u'', u'quantity': u'1'}
# {u'name': u'celery ', u'unit': u'large stalk', u'quantity': u'1'}
# {u'name': u'Bay leaf', u'unit': u'small', u'quantity': u'1'}
# {u'name': u'turkey stock', u'unit': u'ml', u'quantity': u'710'}
# {u'name': u'Water', u'unit': u'ml', u'quantity': u'710'}
# {u'name': u'turkey broth', u'unit': u'ml', u'quantity': u'946'}
# {u'name': u'Dry white wine', u'unit': u'ml', u'quantity': u'237'}
# {u'name': u'unsalted butter', u'unit': u'ml', u'quantity': u'59'}
# {u'name': u'All-purpose flour', u'unit': u'ml', u'quantity': u'59'}
# Instructions:
# For the Brine:
# Directions
# To make the brining solution, dissolve the salt and sugar in 2 gallons of cold water in a nonreactive container (such as a clean bucket or large stockpot, or a clean, heavy-duty, food grade plastic storage bag).
# Add the oranges, lemons, thyme, and rosemary.
# Note: if you have a big turkey and need more brine than this, use 1/2 cup salt and 1/2 cup brown sugar for every gallon of water.
# Remove the neck, giblets, and liver from the cavity of the turkey and reserve for the gravy.
# Rinse the turkey inside and out under cold running water.
# Soak the turkey in the brine, covered and refrigerated, for at least 4 hours and up to 24 hours.
# Preheat the oven to 325 degrees F.
# Remove the turkey from the brine and rinse well under cold running water.
# Pat dry with paper towels both inside and out.
# Place turkey, breast side up, in a large, heavy roasting pan.
# Rub breast side with orange segments and rub on all sides with the butter, stuffing some underneath the skin.
# Season lightly inside and out with salt and pepper.
# Stuff the turkey with the onion, remaining orange, celery, carrot, bay leaves, thyme, rosemary, sage and parsley.
# Loosely tie the drumsticks together with kitchen string.
# Roast the turkey, uncovered, breast side down for 1 hour.
# Remove from the oven, turn, and baste with 1/2 cup stock.
# Continue roasting with the breast side up until an instant-read meat thermometer registers 165 degrees F when inserted into the largest section of thigh (avoiding the bone), about 2 3/4 to 3 hours total cooking time.
# Baste the turkey once every hour with 1/2 to 3/4 cup chicken or turkey stock.
# Remove from the oven and place on a platter.
# Tent with aluminum foil and let rest for 20 minutes before carving.
# For the turkey broth:
# Heat the oil in a large heavy saucepan over medium-high heat.
# Add the turkey neck, heart, and gizzard to the pan and saute until just beginning to brown, about 1 minute.
# Add the chopped vegetables and bay leaf to the pan and saute until soft, about 2 minutes.
# Pour the stock and 3 cups of water into the pan and bring to a boil.
# Lower the heat to medium-low and simmer until the stock is reduced to 4 cups, about 1 hour, adding the chopped liver to the pan during the last 15 minutes of cooking.
# Strain the stock into a clean pot or large measuring cup.
# Pull the meat off the neck, chop the neck meat and giblets, and set aside.
# For the pan gravy:
# Pour the reserved turkey pan juices into a glass-measuring cup and skim off the fat.
# Place the roasting pan on 2 stovetop burners over medium heat add the pan juice and 1 cup turkey broth and the white wine to the pan, and deglaze the pan, stirring to scrape any brown bits from the bottom of the pan.
# Add the remaining 3 cup of broth and bring to a simmer, then transfer to a measuring cup.
# In a large heavy saucepan, melt the butter over medium high heat.
# Stir in the flour and cook, stirring constantly, to make a light roux.
# Add the hot stock, whisking constantly, then simmer until thickened, about 10 minutes.
# Add the reserved neck meat and giblets to the pan and adjust seasoning, to taste, with salt and black pepper.
# Pour into a gravy boat and serve.
# Have a great holiday!
# Slice and serve guests with desired sides.
# WordNet match:  orange (u'oranges', 1)
# WordNet match:  brown_sugar (u'brown sugar', 1)
# WordNet match:  water (u'water', 1)
# WordNet match:  turkey (u'turkey', 1)
# WordNet match:  turkey (u'turkey', 1)
# WordNet match:  turkey (u'turkey', 1)
# WordNet match:  turkey (u'turkey', 1)
# WordNet match:  turkey (u'turkey', 1)
# WordNet match:  turkey (u'turkey', 1)
# WordNet match:  breast_side (u'turkey stock', 0.9333333333333333)
# WordNet match:  all_side (u'turkey stock', 0.9333333333333333)
# WordNet match:  butter (u'unsalted butter', 1.0)
# WordNet match:  butter (u'unsalted butter', 1.0)
# WordNet match:  breast_side (u'turkey stock', 0.9333333333333333)
# WordNet match:  all_side (u'turkey stock', 0.9333333333333333)
# WordNet match:  butter (u'unsalted butter', 1.0)
# WordNet match:  butter (u'unsalted butter', 1.0)
# WordNet match:  turkey (u'turkey', 1)
# WordNet match:  onion (u'yellow onion', 1.0)
# WordNet match:  onion (u'yellow onion', 1.0)
# WordNet match:  parsley (u'parsley', 1)
# WordNet match:  turkey (u'turkey', 1)
# WordNet match:  breast_side (u'turkey stock', 0.9333333333333333)
# WordNet match:  turkey (u'turkey', 1)
# WordNet match:  turkey_stock (u'turkey stock', 1)
# WordNet match:  stock (u'turkey stock', 1.0)
# WordNet match:  water (u'water', 1)
# WordNet match:  stock (u'turkey stock', 1.0)
# WordNet match:  water (u'water', 1)
# WordNet match:  stock (u'turkey stock', 1.0)
# WordNet match:  stock (u'turkey stock', 1.0)
# WordNet match:  reserved_turkey (u'turkey', 1.0)
# WordNet match:  fat (u'vegetable oil', 0.9230769230769231)
# WordNet match:  fat (u'vegetable oil', 0.9230769230769231)
# WordNet match:  fat (u'vegetable oil', 0.9230769230769231)
# WordNet match:  white_wine (u'dry white wine', 1.0)
# WordNet match:  white_wine (u'dry white wine', 1.0)
# WordNet match:  white_wine (u'dry white wine', 1.0)
# WordNet match:  broth (u'turkey stock', 1.0)
# WordNet match:  broth (u'turkey stock', 1.0)
# WordNet match:  flour (u'all-purpose flour', 1.0)
# WordNet match:  hot_stock (u'turkey stock', 0.9333333333333333)
# WordNet match:  seasoning (u'salt', 0.9411764705882353)
# WordNet match:  salt (u'salt', 1)
# WordNet match:  seasoning (u'salt', 0.9411764705882353)
# WordNet match:  salt (u'salt', 1)
# WordNet match:  desired_side (u'turkey stock', 0.9333333333333333)
# WordNet match:  desired_side (u'turkey stock', 0.9333333333333333)
# Ingredients:
# {u'name': u'Water', u'unit': u'l', u'quantity': u'2'}
# {u'name': u'Salt', u'unit': u'g', u'quantity': u'28'}
# {u'name': u'Miso', u'unit': u'ml', u'quantity': u'118'}
# {u'name': u'Mirin', u'unit': u'ml', u'quantity': u'118'}
# {u'name': u'Soy', u'unit': u'ml', u'quantity': u'118'}
# {u'name': u'Rice vinegar', u'unit': u'ml', u'quantity': u'118'}
# {u'name': u'Multi-colored fingerling potatoes', u'unit': u'kg', u'quantity': u'0.91'}
# {u'name': u'Snap peas', u'unit': u'ml', u'quantity': u'473'}
# {u'name': u'Carrot', u'unit': u'ml', u'quantity': u'355'}
# {u'name': u'Scallions', u'unit': u'each', u'quantity': u'3'}
# {u'name': u'Cilantro', u'unit': u'ml', u'quantity': u'44'}
# {u'name': u'Vinaigrette', u'unit': u'ml', u'quantity': u'118'}
# {u'name': u'Miso', u'unit': u'ml', u'quantity': u'15'}
# {u'name': u'Rice wine vinegar', u'unit': u'ml', u'quantity': u'15'}
# {u'name': u'Soy sauce', u'unit': u'ml', u'quantity': u'15'}
# {u'name': u'Mirin', u'unit': u'ml', u'quantity': u'15'}
# {u'name': u'Sesame oil', u'unit': u'ml', u'quantity': u'15'}
# {u'name': u'Yellow mustard seeds', u'unit': u'ml', u'quantity': u'237'}
# {u'name': u'Mirin', u'unit': u'ml', u'quantity': u'118'}
# {u'name': u'Rice wine vinegar', u'unit': u'ml', u'quantity': u'355'}
# {u'name': u'Sugar', u'unit': u'ml', u'quantity': u'118'}
# {u'name': u'Salt', u'unit': u'ml', u'quantity': u'15'}
# {u'name': u'Soy', u'unit': u'ml', u'quantity': u'30'}
# {u'name': u'Pickling spice', u'unit': u'ml', u'quantity': u'2'}
# {u'name': u'Tumeric', u'unit': u'pinch', u'quantity': u'1'}
# {u'name': u'Star anise', u'unit': u'points', u'quantity': u'3'}
# Instructions:
# Combine all ingredients listed under potatoes in a heavy-bottomed pot and bring to a gentle simmer.
# Once it reaches a simmer, turn down the heat until there are just very small bubbles in the pot and cook until the potatoes are tender.
# Cool the potatoes in their cooking liquid in a shallow pan.
# Once cool, cut the potatoes in half lengthwise.
# The cooking liquid can be used again for the same purpose and so should be reserved.
# For the dressing: Create an Asian flavor base from miso, vinegar, mirin, and sesame oil and add this to your vinaigrette.
# Taste the dressing and adjust the seasoning as needed
# Mix the potatoes with the carrots and snap peas, and dress with the Asian vinaigrette.
# Season to taste and garnish with your favorite Asian garnishes as listed in the ingredients
# Pickled Mustard Seeds
# In a small heavy sauce pan cover the mustard seeds with water and bring to a boil.
# Drain the water and rinse the mustard seeds.
# Repeat the blanching a second time.
# Drain the water, rinse the mustard seeds and add the vinegar, sugar, salt, soy sauce, and spices in a small heavy saucepan with the blanched mustard seeds and bring to a gentle simmer over low heat.
# Cook, stirring often, until the mustard seeds are plump and tender, about 15 to 20 minutes.
# The liquid will be nearly absorbed, but the seeds will remain moist in very little thick viscous broth.
# Cool the seeds in their liquid and refrigerate in a covered container.
# It will keep for months.
# WordNet match:  miso (u'miso', 1)
# WordNet match:  miso (u'miso', 1)
# WordNet match:  sesame_oil (u'sesame oil', 1)
# WordNet match:  your_vinaigrette (u'vinaigrette', 1.0)
# WordNet match:  miso (u'miso', 1)
# WordNet match:  miso (u'miso', 1)
# WordNet match:  sesame_oil (u'sesame oil', 1)
# WordNet match:  your_vinaigrette (u'vinaigrette', 1.0)
# WordNet match:  dressing (u'vinaigrette', 0.9565217391304348)
# WordNet match:  seasoning (u'salt', 0.9411764705882353)
# WordNet match:  dressing (u'vinaigrette', 0.9565217391304348)
# WordNet match:  seasoning (u'salt', 0.9411764705882353)
# WordNet match:  Asian_vinaigrette (u'vinaigrette', 1.0)
# WordNet match:  Asian_vinaigrette (u'vinaigrette', 1.0)
# WordNet match:  mustard_seed (u'yellow mustard seeds', 1.0)
# WordNet match:  water (u'water', 1)
# WordNet match:  mustard_seed (u'yellow mustard seeds', 1.0)
# WordNet match:  water (u'water', 1)
# WordNet match:  mustard_seed (u'yellow mustard seeds', 1.0)
# WordNet match:  water (u'water', 1)
# WordNet match:  water (u'water', 1)
# WordNet match:  mustard_seed (u'yellow mustard seeds', 1.0)
# WordNet match:  water (u'water', 1)
# WordNet match:  mustard_seed (u'yellow mustard seeds', 1.0)
# WordNet match:  water (u'water', 1)
# WordNet match:  mustard_seed (u'yellow mustard seeds', 1.0)
# WordNet match:  vinegar (u'rice vinegar', 1.0)
# WordNet match:  blanched_mustard_seed (u'yellow mustard seeds', 1.0)
# WordNet match:  mustard_seed (u'yellow mustard seeds', 1.0)
# WordNet match:  vinegar (u'rice vinegar', 1.0)
# WordNet match:  blanched_mustard_seed (u'yellow mustard seeds', 1.0)
# WordNet match:  mustard_seed (u'yellow mustard seeds', 1.0)
# WordNet match:  vinegar (u'rice vinegar', 1.0)
# WordNet match:  blanched_mustard_seed (u'yellow mustard seeds', 1.0)
# WordNet match:  mustard_seed (u'yellow mustard seeds', 1.0)
# WordNet match:  seed (u'soy', 0.9090909090909091)
# WordNet match:  seed (u'soy', 0.9090909090909091)
# WordNet match:  seed (u'soy', 0.9090909090909091)
# WordNet match:  their_liquid (u'water', 0.9333333333333333)
# WordNet match:  seed (u'soy', 0.9090909090909091)
# WordNet match:  their_liquid (u'water', 0.9333333333333333)
# Ingredients:
# {u'name': u'Bell peppers', u'unit': u'', u'quantity': u'4'}
# {u'name': u'Olive oil', u'unit': u'ml', u'quantity': u'4'}
# {u'name': u'Salt', u'unit': u'ml', u'quantity': u'2'}
# {u'name': u'Potatoes', u'unit': u'large', u'quantity': u'3'}
# {u'name': u'Yellow onion ', u'unit': u'', u'quantity': u'1'}
# {u'name': u'Ground black pepper ', u'unit': u'ml', u'quantity': u'5'}
# {u'name': u'Olive oil', u'unit': u'ml', u'quantity': u'15'}
# {u'name': u"Breakstone's Sour-Cream", u'unit': u'ml', u'quantity': u'5'}
# Instructions:
# Preheat the oven on 375 degrees Fahrenheit.
# Wash peppers and cut in the halves; Take all the seeds out.
# Sprinkle with bit of salt and just lightly spray or oil them.
# Place in the oven and bake for 10 minutes or until you are finished with a filling.
# Meanwhile peel and shred the potatoes, and onion.
# Add salt to taste, ground black pepper, and chili peppers and oil.
# Mix the filling until all combined.
# Take the peppers out of the oven and stuff them with the filling mixture until each half is full.
# Once you done stuffing all the peppers, cover the baking pan with a aluminum foil for the first 15 minutes then remove the alum.
# foil and continue baking uncovered on 375 degrees for 40 minutes or until potatoes are done.
# Serve immediately!
# WordNet match:  salt (u'salt', 1)
# WordNet match:  potato (u'potatoes', 1)
# WordNet match:  salt (u'salt', 1)
# WordNet match:  taste (u'salt', 0.9473684210526315)
# WordNet match:  pepper (u'ground black pepper ', 1.0)
# WordNet match:  pepper (u'ground black pepper ', 1.0)
# WordNet match:  potato (u'potatoes', 1)
# WordNet match:  potato (u'potatoes', 1)
# WordNet match:  potato (u'potatoes', 1)
# Ingredients:
# {u'name': u'Fingerling potatoes', u'unit': u'kg', u'quantity': u'0.68'}
# {u'name': u'Red bell pepper', u'unit': u'', u'quantity': u'1'}
# {u'name': u'Red onion', u'unit': u'', u'quantity': u'1'}
# {u'name': u'Extra virgin olive oil', u'unit': u'ml', u'quantity': u'44'}
# {u'name': u'Kosher Salt', u'unit': u'ml', u'quantity': u'2'}
# {u'name': u'Pepper', u'unit': u'ml', u'quantity': u'0.62'}
# {u'name': u'Light or olive oil based mayonnaise', u'unit': u'ml', u'quantity': u'59'}
# {u'name': u'Lemon juice', u'unit': u'ml', u'quantity': u'22'}
# {u'name': u'Extra virgin olive oil', u'unit': u'ml', u'quantity': u'10'}
# {u'name': u'Fresh thyme leaves', u'unit': u'ml', u'quantity': u'10'}
# {u'name': u'Lemon zest', u'unit': u'ml', u'quantity': u'7'}
# {u'name': u'Kosher Salt', u'unit': u'ml', u'quantity': u'1'}
# {u'name': u'Pepper', u'unit': u'ml', u'quantity': u'0.62'}
# Instructions:
# Preheat oven to 425°F.
# Toss all salad ingredients together in a large bowl.
# Spread in a single layer on a large baking sheet and cook for 20 to 25 minutes or until potatoes start to brown.
# Let cool for at least 10 minutes.
# Meanwhile, whisk together all dressing ingredients in a medium bowl; toss with cooled vegetables.
# Serve at room temperature or chilled.
# Makes 6 servings.
# Ingredients:
# {u'name': u'russet ', u'unit': u'medium', u'quantity': u'2-3'}
# {u'name': u'Olive oil', u'unit': u'ml', u'quantity': u'30'}
# {u'name': u'Pepper', u'unit': u'ml', u'quantity': u'1'}
# {u'name': u'Sea Salt', u'unit': u'ml', u'quantity': u'2'}
# Instructions:
# Preheat grill or oven to 400°F.
# Thinly slice potatoes length wise to 1/4 inch thick, discarding ends.
# Toss with olive oil, salt and pepper.
# Place on grill or prepared baking sheet in single layer and cook for 10 minutes on each side.
# Top with your favorite toppings:
# Bruschetta: 2 medium tomatoes diced, 1/4 cup chopped fresh basil leaves, 2 cloves (1 teaspoon) of minced garlic and 1 tablespoon of olive oil.
# Toss together in a bowl and spoon on top of potatoes.
# Optional: Add chopped chicken to Bruschetta topping.
# Mediterranean: 1 (6 oz.)
# container of feta cheese, 1 (2.25 oz.)
# can sliced olives drained, 1 medium tomato diced (optional), salt and pepper to taste.
# Toss together in a bowl and spoon on top of potatoes.
# Creamy Greek Yogurt with Lemon and Herbs: 1/2 cup plain nonfat Greek yogurt, 2 tablespoons chopped fresh dill, juice of 1/2 lemon, salt and pepper to taste.
# Mix together in a bowl and spoon on top of potatoes.
# Garnish with dill sprigs.
# Baked Potato: 1/2 cup plain nonfat Greek yogurt, 1/4 cup shredded reduced-fat cheddar cheese, 2 tablespoons plus 1 tablespoon fresh chives chopped.
# Mix all ingredients except 1 tablespoon of chives in a bowl and spoon on top of potatoes.
# Garnish with remaining chives.
# Pico de Gallo: 1/2 cup pre-made Pico de Gallo or mix 1 medium tomato diced, 1 small onion finely chopped, 1 green onion chopped, 1/2 teaspoon minced garlic, 1 tablespoon chopped cilantro, salt and pepper to taste.
# Mix all ingredients in a bowl and spoon on top of potatoes.
# Garnish with extra cilantro.
# WordNet match:  olive_oil (u'olive oil', 1)
# WordNet match:  taste (u'sea salt', 0.9473684210526315)
# WordNet match:  taste (u'sea salt', 0.9473684210526315)
# WordNet match:  taste (u'sea salt', 0.9473684210526315)
# WordNet match:  taste (u'sea salt', 0.9473684210526315)
# WordNet match:  taste (u'sea salt', 0.9473684210526315)
# WordNet match:  taste (u'sea salt', 0.9473684210526315)
# Ingredients:
# {u'name': u'Russet potatoes', u'unit': u'5 to 6-ounce', u'quantity': u'4'}
# {u'name': u'Nonfat plain yogurt', u'unit': u'ml', u'quantity': u'59'}
# {u'name': u'Healthy buttery spread', u'unit': u'ml', u'quantity': u'20'}
# {u'name': u'Garlic or seasoned salt', u'unit': u'ml', u'quantity': u'2'}
# {u'name': u'Turkey pepperoni', u'unit': u'slices', u'quantity': u'16'}
# {u'name': u'Warm pasta sauce', u'unit': u'ml', u'quantity': u'59'}
# {u'name': u'Italian blend shredded cheese', u'unit': u'ml', u'quantity': u'59'}
# {u'name': u'Minced green pepper', u'unit': u'ml', u'quantity': u'15'}
# {u'name': u'Sliced green onion', u'unit': u'ml', u'quantity': u'15'}
# Instructions:
# Cut a wedge out of each potato about 1/8-inch wide and 1-inch deep and place in a microwave-safe dish.
# Microwave on HIGH, uncovered, for 10 to12 minutes depending on strength of microwave.
# Use oven mitts to remove dish from microwave.
# Carefully make a slit in the top of each potato and fluff with a fork.
# Stir 1 tablespoon yogurt, 1 teaspoon buttery spread and 1/8 teaspoon salt into each potato; sprinkle with chives if desired.
# Place 16 slices turkey pepperoni on a plate and microwave on HIGH for 45 to 60 seconds to crisp.
# Top each seasoned potato with pasta sauce, cheese, green pepper and green onion.
# Microwave on HIGH for 2 minutes to melt cheese, then, top with coarsely crumbled pepperoni slices
# Ingredients:
# {u'name': u'Olive oil', u'unit': u'ml', u'quantity': u'30'}
# {u'name': u'(2 medium potatoes) white potatoes', u'unit': u'g', u'quantity': u'283'}
# {u'name': u'Garlic', u'unit': u'clove', u'quantity': u'1'}
# {u'name': u'Bunch kale', u'unit': u'small', u'quantity': u'1'}
# {u'name': u'Dijon mustard', u'unit': u'ml', u'quantity': u'5'}
# {u'name': u'Eggs', u'unit': u'', u'quantity': u'10'}
# {u'name': u'Pecorino', u'unit': u'ml', u'quantity': u'118'}
# Instructions:
# Preheat oven to 400°F.
# Heat 1 tablespoon of oil over medium heat in a 10-inch ovenproof and nonstick skillet.
# Add potatoes, season with a pinch of salt and pepper, and sauté until golden brown and tender, about 10 minutes.
# Remove potatoes and set aside until needed.
# Add the remaining oil to the skillet and add garlic and kale and season with a pinch of salt and pepper.
# Sauté until kale is wilted, about 5 minutes.
# Add potatoes and mustard; stir to combine.
# Stir in beaten eggs and cheese.
# Remove from heat and place in the oven.
# Bake for 20 minutes or until cooked through and a toothpick inserted in the center comes out clean.
# Once the frittata is finished, run a knife around the edge of the skillet and gently slide the frittata to a carving board or serving plate.
# Garnish with additional pecorino cheese if desired.
# Slice and serve.
# WordNet match:  remaining_oil (u'olive oil', 0.9655172413793104)
# WordNet match:  remaining_oil (u'olive oil', 0.9655172413793104)
# WordNet match:  kale (u'bunch kale', 1.0)
# Ingredients:
# {u'name': u'Prosciutto', u'unit': u'kg', u'quantity': u'0.11'}
# {u'name': u'Russet potatoes (or 3 cups mashed potatoes)', u'unit': u'medium-sized', u'quantity': u'3'}
# {u'name': u'Milk', u'unit': u'ml', u'quantity': u'118'}
# {u'name': u'Unsalted butter', u'unit': u'ml', u'quantity': u'79'}
# {u'name': u'Eggs', u'unit': u'large', u'quantity': u'2'}
# {u'name': u'Parmesan cheese', u'unit': u'ml', u'quantity': u'118'}
# {u'name': u'Fresh thyme', u'unit': u'ml', u'quantity': u'15'}
# {u'name': u'All purpose flour', u'unit': u'ml', u'quantity': u'177'}
# {u'name': u'Baking powder', u'unit': u'ml', u'quantity': u'5'}
# {u'name': u'Salt', u'unit': u'ml', u'quantity': u'5'}
# {u'name': u'Black pepper', u'unit': u'ml', u'quantity': u'2'}
# Instructions:
# Preheat oven to 400°F.
# Line a baking sheet with parchment paper and evenly lay prosciutto on paper.
# Bake for 10 to 15 minutes until prosciutto is crispy.
# Remove from oven and allow to cool.
# Peel and cube potatoes.
# Place in a pot of salted water and bring to a boil over high heat.
# Once boiling, reduce heat to a rapid simmer and simmer until potatoes are fork tender, about 10 minutes.
# Strain potatoes from water and transfer to a large bowl.
# Mash potatoes with a fork or potato masher.
# To the potatoes, add milk, butter, eggs, cheese and thyme.
# Stir to combine.
# In a separate bowl, combine flour, baking powder, salt and pepper.
# Add to the potato mixture and stir until just combined.
# Crumble the crisp prosciutto and fold into the batter.
# Preheat a waffle iron.
# If your waffle iron requires, grease with cooking oil spray.
# Spoon batter (about 1 cup) onto the waffle iron and cook according to your iron’s instructions until waffles are golden, about 4 minutes.
# Keep waffles warm in a 200°F oven until all waffles are cooked and you are ready to serve.
# WordNet match:  prosciutto (u'prosciutto', 1)
# WordNet match:  prosciutto (u'prosciutto', 1)
# WordNet match:  prosciutto (u'prosciutto', 1)
# WordNet match:  potato (u'russet potatoes (or 3 cups mashed potatoes)', 1.0)
# WordNet match:  potato (u'russet potatoes (or 3 cups mashed potatoes)', 1.0)
# WordNet match:  potato (u'russet potatoes (or 3 cups mashed potatoes)', 1.0)
# WordNet match:  potato (u'russet potatoes (or 3 cups mashed potatoes)', 1.0)
# WordNet match:  potato (u'russet potatoes (or 3 cups mashed potatoes)', 1.0)
# WordNet match:  milk (u'milk', 1)
# WordNet match:  crisp_prosciutto (u'prosciutto', 1.0)
# WordNet match:  crisp_prosciutto (u'prosciutto', 1.0)
# Ingredients:
# {u'name': u'ham', u'unit': u'5-pound', u'quantity': u'1'}
# {u'name': u'Brown Sugar', u'unit': u'ml', u'quantity': u'237'}
# {u'name': u'Dry sherry', u'unit': u'ml', u'quantity': u'44'}
# {u'name': u'Dry mustard', u'unit': u'ml', u'quantity': u'2'}
# {u'name': u'Cinnamon', u'unit': u'ml', u'quantity': u'0.62'}
# {u'name': u'Flour', u'unit': u'ml', u'quantity': u'30'}
# {u'name': u'Orange marmalade', u'unit': u'ml', u'quantity': u'118'}
# Instructions:
# Preheat oven to 325F.
# Mix all ingredients well, except ham.
# Place ham on  rack, fat side up, and place in shallow roasting pan.
# Spread the sugar  mixture over the ham.
# Bake ham for 30 minutes or until the internal  temperature of the ham reaches 160F [Insert a meat thermometer until it  reaches the center, but not resting on a bone or fat].
# Posted to Recipe Page 17 November 96    Date: Sat, 16 Nov 1996 03:26:55 +0500    From: Gourmet Connection <capco@norwich.net>
# WordNet match:  ham (u'ham', 1)
# WordNet match:  ham (u'ham', 1)
# WordNet match:  ham (u'ham', 1)
# Ingredients:
# {u'name': u'Chile Peppers', u'unit': u'large', u'quantity': u'4'}
# {u'name': u'olive oil', u'unit': u'ml', u'quantity': u'5'}
# {u'name': u'Garlic', u'unit': u'cloves', u'quantity': u'2'}
# {u'name': u'Green onion', u'unit': u'ml', u'quantity': u'59'}
# {u'name': u'Whole corn', u'unit': u'ml', u'quantity': u'118'}
# {u'name': u'Peas', u'unit': u'ml', u'quantity': u'118'}
# {u'name': u'Carrot', u'unit': u'ml', u'quantity': u'59'}
# {u'name': u'Broccoli Slaw', u'unit': u'ml', u'quantity': u'59'}
# {u'name': u'Neufchatel Cheese', u'unit': u'g', u'quantity': u'113'}
# {u'name': u'Cheddar cheese', u'unit': u'g', u'quantity': u'57'}
# {u'name': u'Cilantro', u'unit': u'ml', u'quantity': u'59'}
# {u'name': u'Kosher Salt', u'unit': u'ml', u'quantity': u'0.62'}
# {u'name': u'Black pepper', u'unit': u'ml', u'quantity': u'1'}
# Instructions:
# You need to pick peppers that are large enough to hold some filling.
# I chose Anaheims.
# Briefly roast the peppers over an open flame (or under the broiler) to blister the skin.
# Rub off the skin and remove the seeds from each pepper through a slit down the side.
# With smaller peppers it may be easier to remove the top and remove the seeds & veins with an apple corer.
# Set aside.
# Heat the olive oil in a large pan and saute the vegetables enough to soften them (but not so much that they lose color).
# About 4 - 5 minutes should work.
# The add the cheeses and mix thoroughly.
# Season to taste with salt and pepper.
# Preheat oven to 350
# Using a spoon (or a plastic bag with a corner snipped) fill each pepper about 90% full.
# Place them on a baking sheet.
# Bake for about 15 minutes until the cheese is bubbly.
# Serve hot.
# NOTES:
# Your choice of peppers controls the number of peppers you need.
# Larger peppers hold more filling so you need fewer.
# Large jalapeno or caribe peppers hold a lot less so you'll need more of them.
# Smaller peppers can be filled from the top, capped with a bacon strip, and roasted vertically in a wire rack.
# The choice of vegetables is limited only by your imagination and availability.
# Go for a mix of colors and flavors.
# Using Anaheim peppers each (app 200g) serving contains an estimated:
# Cals: 210, FatCals: 116, TotFat: 13g
# SatFat: 7g, PolyFat: 1g, MonoFat: 4g
# Chol: 36mg, Na: 200mg, K: 410mg
# TotCarbs: 15g, Fiber: 4g, Sugars: 3g
# NetCarbs: 11g, Protein: 9g
# Adapted from recipe by Chef Bill Wavrin
# WordNet match:  pepper (u'chile peppers', 1.0)
# WordNet match:  pepper (u'chile peppers', 1.0)
# WordNet match:  pepper (u'chile peppers', 1.0)
# WordNet match:  each_pepper (u'chile peppers', 1.0)
# WordNet match:  each_pepper (u'chile peppers', 1.0)
# WordNet match:  olive_oil (u'olive oil', 1)
# WordNet match:  olive_oil (u'olive oil', 1)
# WordNet match:  each_pepper (u'chile peppers', 1.0)
# WordNet match:  each_pepper (u'chile peppers', 1.0)
# WordNet match:  cheese (u'neufchatel cheese', 1.0)
# WordNet match:  pepper (u'chile peppers', 1.0)
# Ingredients:
# {u'name': u'Coconut oil', u'unit': u'ml', u'quantity': u'118'}
# {u'name': u'Cocoa powder', u'unit': u'ml', u'quantity': u'59'}
# {u'name': u'Honey', u'unit': u'ml', u'quantity': u'30'}
# {u'name': u'Vanilla extract', u'unit': u'ml', u'quantity': u'5'}
# Instructions:
# Melt the coconut oil and add the honey.
# It must just be warm enough to melt the coconut oil and no hotter.
# Whisk and add the vanilla and cocoa powder.
# Be very careful not to overheat the mixture or you will end up cooking or burning the cocoa powder.
# Whisk occasionally while pouring into a silicone ice cube tray or silicone mini muffin tray.
# If you wish to diversify, before you fill the moulds, you can first place a few assortments, like crushed peanuts or almonds, flakes of dried coconut, raisins, berries or other delights.
# Cool for 15 to 30 minutes in the fridge or freezer, depending on how hot the coconut oil was when you started.
# If the oil is only just reached its melting stage, then it will set quicker.
# WordNet match:  coconut_oil (u'coconut oil', 1)
# WordNet match:  honey (u'honey', 1)
# WordNet match:  coconut_oil (u'coconut oil', 1)
# WordNet match:  honey (u'honey', 1)
# WordNet match:  coconut_oil (u'coconut oil', 1)
# WordNet match:  coconut_oil (u'coconut oil', 1)
# WordNet match:  coconut_oil (u'coconut oil', 1)
# WordNet match:  coconut_oil (u'coconut oil', 1)
# WordNet match:  cocoa_powder (u'cocoa powder', 1)
# WordNet match:  cocoa_powder (u'cocoa powder', 1)
# WordNet match:  cocoa_powder (u'cocoa powder', 1)
# WordNet match:  cocoa_powder (u'cocoa powder', 1)
# WordNet match:  cocoa_powder (u'cocoa powder', 1)
# WordNet match:  cocoa_powder (u'cocoa powder', 1)
# WordNet match:  coconut_oil (u'coconut oil', 1)
# WordNet match:  coconut_oil (u'coconut oil', 1)
# Ingredients:
# {u'name': u'Sandwich bread', u'unit': u'sl', u'quantity': u'20'}
# {u'name': u'asparagus', u'unit': u'15-oz can', u'quantity': u'1'}
# {u'name': u'Worcestershire Sauce', u'unit': u'ml', u'quantity': u'2'}
# {u'name': u'Garlic powder', u'unit': u'ml', u'quantity': u'0.62'}
# {u'name': u'Cream cheese', u'unit': u'g', u'quantity': u'113'}
# {u'name': u'Mayonnaise', u'unit': u'ml', u'quantity': u'22'}
# {u'name': u'Paprika', u'unit': u'ds', u'quantity': u'1'}
# {u'name': u'cheese', u'unit': u'ml', u'quantity': u'59'}
# Instructions:
# Mix cheeses with mayonnaise, Worcestershire sauce and seasonings.
# Spread on  bread then place one asparagus spear on each slice of bread.
# Roll up.
# Melt  the butter and brush bread rolls.
# Place in a pan and bake at 400 degrees  for 15 minutes.
# Makes 20.
# Freeze if desired.
# From a collection of my mothers (Judy Hosey) recipe box which contained  lots of her favorite recipes, clippings, etc.
# Downloaded from Glens MM  Recipe Archive, G Internet.
# WordNet match:  mayonnaise (u'mayonnaise', 1)
# WordNet match:  mayonnaise (u'mayonnaise', 1)
# WordNet match:  seasoning (u'paprika', 0.9411764705882353)
# WordNet match:  bread (u'sandwich bread', 1.0)
# Ingredients:
# {u'name': u'skinless chicken breast', u'unit': u'kg', u'quantity': u'0.34'}
# {u'name': u'Garlic', u'unit': u'clove', u'quantity': u'1'}
# {u'name': u'Dark soy sauce', u'unit': u'ml', u'quantity': u'30'}
# {u'name': u'Dried chile flakes', u'unit': u'ml', u'quantity': u'5'}
# {u'name': u'Peanut butter', u'unit': u'ml', u'quantity': u'30'}
# {u'name': u'Tomato puree', u'unit': u'ml', u'quantity': u'15'}
# {u'name': u'Pineapple juice', u'unit': u'mililiter', u'quantity': u'100'}
# Instructions:
# Place the chicken in a shallow, non-metallic dish.
# Mix together the garlic, soy sauce, chilli flakes, peanut butter, tomato puree and pineapple juice.
# Pour the mixture over the chicken and toss well to coat all the pieces.
# Cover and leave to marinate for 30 minutes.
# Thread the chicken pieces on to wooden skewers.
# Place them under a hot grill for 15 minutes, turning frequently.
# until evenly browned and cooked through.
# tip: Soak the wooden skewers in water for 20 minutes before using, to prevent them from burning.
# Ingredients:
# {u'name': u'chicken breasts', u'unit': u'', u'quantity': u' 5 '}
# {u'name': u'onion powder', u'unit': u'ml', u'quantity': u'20'}
# {u'name': u'fresh bread crumbs ', u'unit': u'ml', u'quantity': u'710'}
# {u'name': u'shredded Parmesan ', u'unit': u'ml', u'quantity': u'177'}
# {u'name': u'butter', u'unit': u'ml', u'quantity': u'59'}
# {u'name': u'olive oil', u'unit': u'ml', u'quantity': u'44'}
# {u'name': u'deli ham', u'unit': u'slices', u'quantity': u' 10 '}
# {u'name': u'Gruyere/Swiss cheese ', u'unit': u'slices', u'quantity': u' 10 '}
# Instructions:
# Process a few slices of bread in food processor to make about 4-5 cups of fresh breadcrumbs.
# Add Parmesan and 2 tsp onion powder.
# Set aside.
# Melt butter in a bowl and mix with oil.
# Set aside.
# Wash and clean chicken breasts.
# Pat dry and cut each breast into two pieces.
# You will have two pretty thin slices.
# Place a chicken piece on a cutting board.
# Lay a plastic wrap over the chicken piece and pound with a mallet to about a 1/4 inch thickness.
# Take care not to pound too hard because the meat may tear or create holes.
# Do the same thing with all the chicken pieces.
# You should have 10 chicken pieces to the original 5.
#  Season each chicken piece with a bit of salt/pepper and the remaining 2 tsp onion powder.
# Be careful not to over salt the chicken as it is quite thin and the cheese and ham are also salty.
# Bring all the other ingredients in close proximity.
# Take out the deli ham and place on a plate.
# Take cheese out...I usually like to cut the cheese slices in half in case I have to overlap them.
# Take a chicken piece and place a slice of ham and a slice of cheese (or 2 if you cut the original in half).
# Roll chicken... making sure you tuck the sides in as much as possible (this prevents the cheese from oozing out too much in the final baking time).
# You can secure it with a toothpick.
# I have, as of lately, started to omit this step.
# But if you are doing this for the first time, it might help to secure it with the toothpicks.
# Take the chicken roll and dip into the melted butter/oil... make sure all the sides are well coated.
#  Take the butter coated chicken roll and then roll it in the breadcrumbs/Parmesan mixture.
# Place in a casserole dish or plate.
# Finish with the rest.
# You can sprinkle some dried herbs of your choice if you like.
# I sprinkled some dried basil.
# Place in the refrigerator for at least an hour to ensure that the breadcrumbs stay put on the chicken :).
# When ready to bake, place each chicken roll on a parchment lined jelly roll pan (this will help with the cleaning later) making sure you don't overcrowd them.
# Bake in a preheated 375 oven for 15-20 minutes.
# Place the pan on the top third rack.
# Don't over cook the chicken.
# You can easily do this in a toaster oven as well.
# WordNet match:  butter (u'butter', 1)
# WordNet match:  oil (u'olive oil', 0.9655172413793104)
# WordNet match:  ham (u'deli ham', 1.0)
# WordNet match:  ham (u'deli ham', 1.0)
# WordNet match:  cheese (u'gruyere/swiss cheese ', 1.0)
# WordNet match:  butter (u'butter', 1)
# WordNet match:  butter (u'butter', 1)
# Ingredients:
# {u'name': u'chicken breasts ', u'unit': u'boneless, skinless', u'quantity': u'4'}
# {u'name': u'Cream cheese', u'unit': u'g', u'quantity': u'227'}
# {u'name': u'green onions', u'unit': u'ml', u'quantity': u'59'}
# {u'name': u'bacon', u'unit': u'slices', u'quantity': u'8'}
# {u'name': u'Jalapeno peppers', u'unit': u'medium', u'quantity': u'1'}
# Instructions:
# Pound out Chicken breasts so it is about 1/4" thick.
# Mix together cream cheese and green onions and spread cheese mixture over 1 side of chicken breast.
# Optionally add some diced jalepeno pepper into the cream cheese as well.
# Roll Chicken breast up to conceal cream cheese.
# Wrap partially cooked bacon around chicken breast and secure with toothpick.
# Place on grill for about 30 minutes at 375(F).
# Broil for about 5 minute to crisp bacon.
# WordNet match:  cream_cheese (u'cream cheese', 1)
# WordNet match:  green_onion (u'green onions', 1)
# WordNet match:  chicken_breast (u'chicken breasts ', 1)
# WordNet match:  cream_cheese (u'cream cheese', 1)
# WordNet match:  green_onion (u'green onions', 1)
# WordNet match:  chicken_breast (u'chicken breasts ', 1)
# WordNet match:  cream_cheese (u'cream cheese', 1)
# WordNet match:  cream_cheese (u'cream cheese', 1)
# WordNet match:  cream_cheese (u'cream cheese', 1)
# WordNet match:  cream_cheese (u'cream cheese', 1)
# WordNet match:  bacon (u'bacon', 1)
# WordNet match:  chicken_breast (u'chicken breasts ', 1)
# WordNet match:  bacon (u'bacon', 1)
# WordNet match:  chicken_breast (u'chicken breasts ', 1)
# WordNet match:  crisp_bacon (u'bacon', 1.0)
# Ingredients:
# {u'name': u'refrigerated reduced fat crescent dinner rolls', u'unit': u'8-ounce packages', u'quantity': u'2'}
# {u'name': u'Crystal Farms\xae Fat-Free Cream Cheese', u'unit': u'8-ounce packages', u'quantity': u'2'}
# {u'name': u'sugar', u'unit': u'ml', u'quantity': u'158'}
# {u'name': u'almond extract', u'unit': u'ml', u'quantity': u'5'}
# {u'name': u'assorted fresh fruit pieces', u'unit': u'ml', u'quantity': u'473'}
# {u'name': u'apple jelly', u'unit': u'ml', u'quantity': u'59'}
# {u'name': u'apricot preserves or orange marmalade', u'unit': u'ml', u'quantity': u'59'}
# Instructions:
# Heat oven to 375° F.
# Separate dough into 4 long rectangles.
# Place rectangles crosswise on large, ungreased cookie sheet; firmly press edges and perforations to seal.
# Press or roll out to form 15- x 10-inch rectangle; form 1/2-inch crust edge.
# Bake 12 to 15 minutes or until golden brown; cool completely, about 20 minutes.
# In medium mixing bowl, combine filling ingredients; beat until smooth.
# Spread evenly over crust.
# Sprinkle with fresh fruit.
# In small saucepan, melt apple jelly and apricot preserves or orange marmalade over low heat until smooth, stirring constantly.
# Drizzle over fruit.
# Refrigerate at least 2 hours.
# Cover and refrigerate any remaining tart.
# WordNet match:  dough (u'sugar', 1.0)
# Ingredients:
# {u'name': u'Shredded hash browns', u'unit': u'ounce-package', u'quantity': u'20'}
# {u'name': u'Eggs', u'unit': u'large', u'quantity': u'2'}
# {u'name': u'Shredded mozzarella cheese', u'unit': u'ml', u'quantity': u'118'}
# {u'name': u'Pure ground black pepper', u'unit': u'ml', u'quantity': u'1'}
# {u'name': u'Table salt', u'unit': u'ml', u'quantity': u'2'}
# {u'name': u'Olive oil', u'unit': u'ml', u'quantity': u'10'}
# {u'name': u'Avocados', u'unit': u'small', u'quantity': u'3'}
# {u'name': u'Garlic salt', u'unit': u'pinch ', u'quantity': u''}
# {u'name': u'Mozzarella cheese', u'unit': u'g', u'quantity': u'227'}
# {u'name': u'Serrano ham', u'unit': u'g', u'quantity': u'113'}
# Instructions:
# In a large bowl add hash browns, egg, shredded cheese, pepper and salt.
# Mix the mixture using your hands, making sure everything is well coated.
# Add a teaspoon of olive oil to a large non-stick sauté pan over low to medium heat.
# Grab a handful of the potato mixture, about ¼ cup, and create a ball.
# Place it down on the pan and carefully pat it down to create a flat disc shape.
# Cook for 3 to 4 minutes and then flip for an additional 3 to 4 minutes.
# Remove and place on a paper towel.
# Repeat until all hash browns have been used.
# In a small bowl, mash the avocados and sprinkle with a little garlic salt.
# Place a spoonful of the mixture onto a hash brown stack.
# Top with half slice of Serrano ham and a slice of mozzarella cheese.
# Top it with another hash brown stack.
# WordNet match:  olive_oil (u'olive oil', 1)
# Ingredients:
# {u'name': u'2% Milk', u'unit': u'ml', u'quantity': u'473'}
# {u'name': u'Cinnamon', u'unit': u'ml', u'quantity': u'2'}
# {u'name': u'Vanilla bean', u'unit': u'', u'quantity': u'1'}
# {u'name': u'Quinoa', u'unit': u'ml', u'quantity': u'473'}
# {u'name': u'Blueberries', u'unit': u'ml', u'quantity': u'237'}
# {u'name': u'Sliced almonds', u'unit': u'Cup', u'quantity': u'1/4'}
# {u'name': u'Honey', u'unit': u'ml', u'quantity': u'15'}
# Instructions:
# In a large glass measuring cup, whisk together milk, cinnamon, and vanilla bean seeds.
# Scoop the quinoa evenly into serving bowls.
# Serve immediately with milk mixture, topped with blueberries, almonds, and a drizzle of honey.
# WordNet match:  quinoa (u'quinoa', 1)
# WordNet match:  blueberry (u'blueberries', 1)
# WordNet match:  blueberry (u'blueberries', 1)
# WordNet match:  honey (u'honey', 1)
# WordNet match:  blueberry (u'blueberries', 1)
# WordNet match:  blueberry (u'blueberries', 1)
# WordNet match:  honey (u'honey', 1)
# Ingredients:
# {u'name': u'(4 medium) Red or Yukon Gold potatoes', u'unit': u'kg', u'quantity': u'0.15'}
# {u'name': u'Garlic salt', u'unit': u'ml', u'quantity': u'2'}
# {u'name': u'Soft cream cheese', u'unit': u'cup (6 ounces)', u'quantity': u'3/4'}
# {u'name': u'Prepared pesto', u'unit': u'ml', u'quantity': u'59'}
# {u'name': u'Red pepper sauce (optional)', u'unit': u'ml', u'quantity': u'0'}
# {u'name': u'Finely chopped prepared roasted red peppers', u'unit': u'ml', u'quantity': u'59'}
# Instructions:
# Heat oven to 400 degrees F.  Spray baking sheet with cooking spray.
# On baking sheet, arrange potatoes in single layer; spray lightly with additional cooking spray.
# Sprinkle evenly with ¼ teaspoon of the garlic salt.
# Roast 20 to 25 minutes or until potatoes are tender and browned, turning potatoes over halfway and sprinkling with remaining garlic salt.
# Meanwhile, in a small bowl, mix together cream cheese, pesto and red pepper sauce, if desired.
# Pipe or spoon about 2 teaspoons pesto mixture onto each potato; top with red pepper.
# Sprinkle with chives if desired.
# WordNet match:  garlic_salt (u'garlic salt', 1)
# WordNet match:  remaining_garlic_salt (u'garlic salt', 1.0)
# WordNet match:  remaining_garlic_salt (u'garlic salt', 1.0)
# WordNet match:  remaining_garlic_salt (u'garlic salt', 1.0)
# Ingredients:
# {u'name': u'large red peppers', u'unit': u'', u'quantity': u'2'}
# {u'name': u'Basmati Rice', u'unit': u'ml', u'quantity': u'237'}
# {u'name': u'Wild mushrooms', u'unit': u'', u'quantity': u'5'}
# {u'name': u'Mexican Veggie Beef', u'unit': u'Package', u'quantity': u'1'}
# {u'name': u'Tomato', u'unit': u'whole', u'quantity': u'1'}
# {u'name': u'Shallot', u'unit': u'', u'quantity': u'1'}
# {u'name': u'fresh basil leaves', u'unit': u'leaves', u'quantity': u'2'}
# {u'name': u'red wine', u'unit': u'ml', u'quantity': u'59'}
# {u'name': u'Tomato Paste', u'unit': u'Tbsp', u'quantity': u'1'}
# {u'name': u'vegetable stock', u'unit': u'ml', u'quantity': u'59'}
# Instructions:
# Cook the rice until light and fluffy.
# Preheat oven to 375 degrees.
# Mix Rice, mushrooms and veggie beef together.
# Sweat the shallots in a separate saucepan add tomato paste and then deglaze with red wine.
# Combine all remaining ingredients and reduce the liquid by half.
# Use half of the red wine sauce in the rice mixture and fold together.
# Cut peppers in half (or use whole peppers per person) and stuff the halved peppers with mixture.
# Place on a baking sheet and bake for 25-30 minutes.
# Remove from oven and spoon remaining red wine sauce over the roasted red pepper.
# WordNet match:  rice (u'basmati rice', 1.0)
# WordNet match:  shallot (u'shallot', 1)
# WordNet match:  tomato_paste (u'tomato paste', 1)
# WordNet match:  red_wine (u'red wine', 1)
# WordNet match:  tomato_paste (u'tomato paste', 1)
# WordNet match:  red_wine (u'red wine', 1)
# WordNet match:  tomato_paste (u'tomato paste', 1)
# WordNet match:  red_wine (u'red wine', 1)
# WordNet match:  roasted_red_pepper (u'large red peppers', 1.0)
# WordNet match:  roasted_red_pepper (u'large red peppers', 1.0)
# Ingredients:
# {u'name': u'Olive oil', u'unit': u'ml', u'quantity': u'44'}
# {u'name': u'Garlic', u'unit': u'cloves', u'quantity': u'6'}
# {u'name': u'Diced tomatoes with Italian seasoning', u'unit': u'14.5-oz can', u'quantity': u'1'}
# {u'name': u'Dry spaghetti', u'unit': u'g', u'quantity': u'170'}
# Instructions:
# Boil salted water for pasta (add a little oil to the water).
# Heat 3 tbs olive oil over medium heat, and add the garlic.
# Heat for about 1 minute, and then add the tomatoes.
# Heat over medium-low heat while the pasta cooks.
# Once the pasta is done, drain, and toss with tomato mixture.
# Garnish with Asiago or Parmesan cheese, and serve with a crusty bread and a salad.
# WordNet match:  oil (u'olive oil', 0.9655172413793104)
# WordNet match:  garlic (u'garlic', 1)
# WordNet match:  oil (u'olive oil', 0.9655172413793104)
# WordNet match:  garlic (u'garlic', 1)
# Ingredients:
# {u'name': u'weight Pasta Of Your Choice (I Prefer Short Ones L', u'unit': u'ounces,', u'quantity': u'12'}
# {u'name': u'Butter', u'unit': u'Tablespoons', u'quantity': u'4'}
# {u'name': u'Large Onion', u'unit': u'whole', u'quantity': u'1/2'}
# {u'name': u'Garlic Minced', u'unit': u'cloves', u'quantity': u'3'}
# {u'name': u'(15.5 Ounces) Roasted Red Peppers', u'unit': u'jar', u'quantity': u'1'}
# {u'name': u'Vegetable Or Chicken Broth', u'unit': u'ml', u'quantity': u'237'}
# {u'name': u'Salt More To Taste', u'unit': u'ml', u'quantity': u'2'}
# {u'name': u'Heavy Cream (more To Taste)', u'unit': u'ml', u'quantity': u'118'}
# {u'name': u'Parmesan Shavings (more For Serving)', u'unit': u'ml', u'quantity': u'118'}
# Instructions:
# Cook pasta in salted water according to package directions.
# Melt 2 tablespoons butter in a large skillet over medium-high heat.
# Add the onions and garlic and saute for 2 to 3 minutes or until starting to soften.
# Add the chopped red peppers and cook for 2 to 3 minutes, until hot.
# Remove the skillet from the heat.
# Carefully transfer the contents of the skillet to a food processor or blender.
# Place on the lid and puree the pepper mixture until totally blended (there will still be some texture to the peppers.)
# Heat the other 2 tablespoon butter back to the skillet over medium heat.
# Pour the pepper puree back into the skillet.
# Add the broth, salt, and pepper, and stir until heated.
# Splash in the cream and stir to combine.
# Taste and adjust seasonings if you need to.
# Drain the pasta and add it to the skillet.
# Add Parmesan and parsley/basil, then stir it together to coat the pasta.
# WordNet match:  soften (u'garlic minced', 1.0)
# WordNet match:  soften (u'garlic minced', 1.0)
# WordNet match:  soften (u'garlic minced', 1.0)
# WordNet match:  cream (u'heavy cream (more to taste)', 0.9411764705882353)
# WordNet match:  cream (u'heavy cream (more to taste)', 0.9411764705882353)
# Ingredients:
# {u'name': u'Swanson\xae Premium White Chunk Chicken', u'unit': u'9.75-oz can', u'quantity': u' 1 '}
# {u'name': u"Frank's\xae RedHot\xae Sauce ", u'unit': u'ml', u'quantity': u'59'}
# {u'name': u'Butter', u'unit': u'ml', u'quantity': u'30'}
# {u'name': u'prepared thin pizza crust  (12-inch) ', u'unit': u'10-oz package', u'quantity': u' 1 '}
# {u'name': u'green pepper', u'unit': u'', u'quantity': u' 1/2 '}
# {u'name': u'crumbled blue cheese ', u'unit': u'ml', u'quantity': u'59'}
# Instructions:
#  Heat the oven to 425°F.
# ...
# Shake some of the glaze off the beef and cook it for about 7 minutes on each side for rare, and a few minutes longer for medium.
# Take it off the barbecue and leave it to rest for 10 minutes.
# Meanwhile, heat the discarded glaze in a saucepan until it boils and cook for a couple of minutes.
# Taste and season.
# Add a little more bourbon if you like.
# Glaze the beef again and then carve it into thick slices.
# Serve with some green leaves dressed with vinaigrette.
#
# If it rains...
# Sear the beef fillet all over in a hot pan for about 10 minutes in total, then cook in an oven heated to 200C/fan 180C/gas 6 for 10 minutes for rare, 15 for medium rare.
# WordNet match:  thick_slice (u'beef fillet', 0.9333333333333333)
# WordNet match:  thick_slice (u'beef fillet', 0.9333333333333333)
# WordNet match:  beef_fillet (u'beef fillet', 1)
# Ingredients:
# {u'name': u'McCormick\xae Basil Leaves', u'unit': u'ml', u'quantity': u'30'}
# {u'name': u'McCormick\xae Oregano Leaves', u'unit': u'ml', u'quantity': u'30'}
# {u'name': u'McCormick\xae Garlic Powder', u'unit': u'ml', u'quantity': u'15'}
# {u'name': u'McCormick\xae Onion Powder', u'unit': u'ml', u'quantity': u'10'}
# {u'name': u'McCormick\xae Black Pepper, Ground', u'unit': u'ml', u'quantity': u'5'}
# {u'name': u'boneless beef rib roast, 5 to 6 pounds', u'unit': u'', u'quantity': u'1'}
# {u'name': u'oil', u'unit': u'ml', u'quantity': u'30'}
# {u'name': u'salt', u'unit': u'ml', u'quantity': u'5'}
# Instructions:
# Preheat oven to 350°F.
# Mix first 5 ingredients in small bowl.
# Set aside.
# Trim excess fat from top of beef, leaving a layer of fat about 1/4-inch thick.
# Place roast on rack in shallow roasting pan.
# Brush beef with oil.
# Sprinkle with salt.
# Coat with seasoning mixture.
# Roast, uncovered, until internal temperature reaches 130°F for medium-rare (1 3/4 to 2 1/4 hours) or 140°F for medium (2 1/4 to 2 3/4 hours).
# Cover with foil and let stand 15 minutes before carving.
# (The temperature of the meat will rise about 10 degrees during standing.)
# WordNet match:  excess_fat (u'oil', 0.9230769230769231)
# WordNet match:  salt (u'salt', 1)
# Ingredients:
# {u'name': u'Turkey Breast', u'unit': u'Whole', u'quantity': u'1'}
# {u'name': u'Butter', u'unit': u'ml', u'quantity': u'118'}
# {u'name': u'Chicken Broth', u'unit': u'can', u'quantity': u'1'}
# {u'name': u'Mayonnaise', u'unit': u'Tbls', u'quantity': u'3'}
# Instructions:
# Clean thawed turkey breast and place in a baking pan (foil is good for cleanup).
# Melt butter.
# Pour chicken broth and melted butter over turkey breast and spread the mayonnaise all over skin.
# Bake as directed.
# I basted about every 30 minutes.
# This method is not too dry and not too moist, and the taste is wonderful (NO!!
# BEYOND WHAT WORDS CAN SAY)
# I found this recipe somewhere online and have been making it every since.
# I know you will enjoy this.
# WordNet match:  turkey_breast (u'turkey breast', 1)
# WordNet match:  mayonnaise (u'mayonnaise', 1)
# WordNet match:  turkey_breast (u'turkey breast', 1)
# WordNet match:  mayonnaise (u'mayonnaise', 1)
# Ingredients:
# {u'name': u'Cauliflower', u'unit': u'', u'quantity': u'1'}
# {u'name': u'Parsnips', u'unit': u'', u'quantity': u'2'}
# {u'name': u'Olive oil', u'unit': u'ml', u'quantity': u'44'}
# {u'name': u'Lemon', u'unit': u'', u'quantity': u'1'}
# {u'name': u'Kosher Salt', u'unit': u'ml', u'quantity': u'10'}
# {u'name': u'Freshly ground pepper', u'unit': u'ml', u'quantity': u'5'}
# {u'name': u'Rosemary sprigs', u'unit': u'', u'quantity': u'4'}
# {u'name': u'Red Pepper Flakes', u'unit': u'pinch', u'quantity': u'1'}
# {u'name': u'Garlic', u'unit': u'cloves', u'quantity': u'2'}
# {u'name': u'Kale (lacinto)', u'unit': u'bunch', u'quantity': u'1'}
# Instructions:
# Preheat the oven to 425°.
# In a large bowl, add the cauliflower, parsnips, 1½ tablespoons of olive oil, the lemon zest, 1 teaspoon of salt and ½ teaspoon of pepper and toss to combine.
# Turn the vegetables out onto a rimmed baking sheet.
# Tuck the rosemary sprigs among the vegetables, sprinkle with the red pepper flakes and roast until the vegetables begin to brown around the edges, 20 to 25 minutes.
# Reduce the oven temperature to 325° and continue to roast the vegetables until they are tender, about 15 minutes longer.
# Remove the baking sheet from the oven and discard the rosemary sprigs.
# In a small bowl, whisk together the remaining 1½ tablespoons of olive oil, the lemon juice, garlic, the remaining 1 teaspoon of salt and the ½ teaspoon of pepper.
# Add half of this vinaigrette to a large bowl along with the kale ribbons.
# Use your hands to massage the kale until it becomes slightly brighter in color, 2 to 3 minutes.
# To the kale ribbons, add the roasted cauliflower and parsnips and the remaining vinaigrette.
# Toss to combine and serve.
# Calories per Serving: 220; Sodium: 1,030mg; Total Carbohydrate: 28g; Fiber: 7g; Fat: 12g
# Read more: http://www.tastingtable.com/entry_detail/chefs_recipes/13059/chefs_recipes/The_next_kale_salad_youll_crave.htm#ixzz2QfLJwfiT
# WordNet match:  cauliflower (u'cauliflower', 1)
# WordNet match:  rosemary_sprig (u'rosemary sprigs', 1)
# WordNet match:  red_pepper_flake (u'red pepper flakes', 1)
# WordNet match:  red_pepper_flake (u'red pepper flakes', 1)
# WordNet match:  rosemary_sprig (u'rosemary sprigs', 1)
# WordNet match:  rosemary_sprig (u'rosemary sprigs', 1)
# WordNet match:  olive_oil (u'olive oil', 1)
# WordNet match:  kale (u'kale (lacinto)', 1)
# WordNet match:  kale (u'kale (lacinto)', 1)
# WordNet match:  kale (u'kale (lacinto)', 1)
# Ingredients:
# {u'name': u'chuck roast ', u'unit': u'kg', u'quantity': u'2'}
# {u'name': u'spicy tomato sauce', u'unit': u'cans', u'quantity': u' 2 '}
# {u'name': u'white wine ', u'unit': u'ml', u'quantity': u'237'}
# {u'name': u'garlic', u'unit': u'tbls', u'quantity': u' 3 '}
# {u'name': u'cilantro leaves', u'unit': u'bunch', u'quantity': u' 1 '}
# {u'name': u'green onions', u'unit': u'bunch', u'quantity': u' 1 '}
# Instructions:
# Pour the cup of wine in your slow cooker and add the roast.
# Season to taste with salt & pepper.
# Pour the tomato sauce over the roast, then the crushed garlic.
# Cook 9 to 10 hours on low.
# 30 minutes before you're ready to use the meat, shred it with 2 forks as best you can in the slow cooker with the juices.
# Stir in the cilantro and green onions.
# Cook for 30 minutes.
# After 30 minutes, drain the meat in a colander.
# Put the meat in a pan and finish shredding it until it's where you like it.
# The meat is now ready to use in any shredded beef recipe.
# WordNet match:  wine (u'white wine ', 0.9523809523809523)
# WordNet match:  roast (u'chuck roast ', 1.0)
# WordNet match:  wine (u'white wine ', 0.9523809523809523)
# WordNet match:  roast (u'chuck roast ', 1.0)
# WordNet match:  tomato_sauce (u'spicy tomato sauce', 1.0)
# WordNet match:  roast (u'chuck roast ', 1.0)
# WordNet match:  green_onion (u'green onions', 1)
# Ingredients:
# {u'name': u'large shrimp', u'unit': u'kg', u'quantity': u'0.45'}
# {u'name': u'pico de gallo', u'unit': u'g', u'quantity': u'454'}
# {u'name': u'ketchup', u'unit': u'ml', u'quantity': u'237'}
# {u'name': u'lime juice', u'unit': u'ml', u'quantity': u'59'}
# {u'name': u'Avocado', u'unit': u'', u'quantity': u'1'}
# Instructions:
# Mix all ingredients together except avocado and crackers.
# Store in fridge until ready to serve.
# Add avocado just before serving.
# Serve in bowls or margarita glasses with hot sauce and crackers on the side.
# WordNet match:  avocado (u'avocado', 1)
# Ingredients:
# {u'name': u'bitter-sweet chocolate', u'unit': u'g', u'quantity': u'113'}
# {u'name': u'semi-sweet chocolate', u'unit': u'g', u'quantity': u'113'}
# {u'name': u'unsalted butter', u'unit': u'ml', u'quantity': u'59'}
# {u'name': u'brown sugar', u'unit': u'ml', u'quantity': u'237'}
# {u'name': u'Eggs', u'unit': u'large', u'quantity': u'2'}
# {u'name': u'Pure vanilla extract', u'unit': u'ml', u'quantity': u'5'}
# {u'name': u'unbleached all-purpose flour', u'unit': u'ml', u'quantity': u'158'}
# {u'name': u'Baking Powder', u'unit': u'ml', u'quantity': u'2'}
# {u'name': u'Salt', u'unit': u'ml', u'quantity': u'2'}
# {u'name': u'milk chocolate chips', u'unit': u'ml', u'quantity': u'473'}
# Instructions:
# Adjust oven rack to middle position and heat oven to 350 degrees F. Lightly grease or line two large baking sheets with either parchment paper or silicon baking pads (e,g,, Silpad); set aside.
# In a microwave safe bowl, combine chopped chocolate and butter.
# Heat in microwave, stirring every 20 seconds, until almost melted.
# Continue stirring until smooth and completely melted.
# Do NOT overheat chocolate mixture.
# Set aside.
# In a small bowl, whisk together flour, baking powder, and salt; set aside.
# In a large mixing bowl, beat eggs, brown sugar, and vanilla on high speed until light and fluffy, about 3 to 4 minutes.
# Reduce speed to low and slowly add melted chocolate mixture, beating until well combined.
# Fold in dry ingredients and mix until just combined.
# Do NOT overmix.
# Gently fold in chocolate chips.
# Chill dough in fridge and allow to firm up for at least 15 minutes before baking.
# Using 1 rounded tablespoon dough per cookie, drop cookies 2-inches apart, in staggered rows of 3-2-3-2-3, on prepared baking sheets.
# Bake one sheet at a time on middle shelf of preheated 350 degree F oven until the cookies are puffed, centers are slightly soft to the touch and edges are set, about 10 to 13 minutes, rotating baking sheet halfway through baking.
# Do NOT overbake.
# Remove from oven and let the cookies sit on the baking sheet for 5 minutes, then use a wide metal spatula to transfer cookies to wire rack to cool completely.
# If using parchment paper or silicon pad, remove baking sheet from oven and immediately slide cookies on parchment or silicon pad directly onto cooling racks.
# Store cookies in an airtight container at room temperature for up to 1 week.
# Cookies freeze well.
# Makes about 24 cookies..
# Make Ahead Note:
# You can freeze this dough.
# If you want to have ready-to-bake cookies, form the dough into balls and place on a parchment lined baking sheet and place in the freezer until the dough is frozen firm.
# Then, place frozen cookie dough in a plastic bag, seal, and keep frozen until ready to bake.
# When baking, simply place the frozen balls of dough on a baking sheet and bake as directed  expect the frozen cookies to take a few minutes longer to bake than normal.
# WordNet match:  baking_powder (u'baking powder', 1)
# WordNet match:  egg (u'eggs', 1)
# Ingredients:
# {u'name': u'Gorgonzola Cheese', u'unit': u'cup', u'quantity': u'3/4'}
# {u'name': u'Butter', u'unit': u'tablespoon', u'quantity': u'6'}
# {u'name': u'Fresh Lemon Juice', u'unit': u'teaspoon', u'quantity': u'1'}
# {u'name': u'olive oil', u'unit': u'tablespoon', u'quantity': u'2'}
# {u'name': u'Fresh Basil', u'unit': u'tablespoon', u'quantity': u'1'}
# {u'name': u'Garlic', u'unit': u'cloves', u'quantity': u'3'}
# {u'name': u'Asparagus', u'unit': u'pounds', u'quantity': u'2'}
# Instructions:
# Stir Gorgonzola cheese, butter and lemon juice in medium bowl to blend.
# Season to taste with salt and pepper.
# Cover and refrigerate.
# (Gorgonzola butter can be prepared 2 days ahead.
# Keep refrigerated.)
# Prepare barbecue (high heat).
# Whisk oil, basil and garlic to blend in small bowl.
# Spread out asparagus in single layer in baking dish.
# Pour oil mixture over asparagus and turn to coat.
# Sprinkle with salt and pepper.
# Transfer asparagus to barbecue.
# Grill until charred on all sides, turning occasionally, about 4 minutes.
# Transfer to plates.
# Top asparagus with some Gorgonzola butter and serve.
# WordNet match:  asparagus (u'asparagus', 1)
# WordNet match:  asparagus (u'asparagus', 1)
# WordNet match:  asparagus (u'asparagus', 1)
# WordNet match:  asparagus (u'asparagus', 1)
# Ingredients:
# Instructions:
# Preheat oven to 375.
# Spray muffin cups with cooking spray.
# Brown beef in skillet and drain fat.
# Add taco seasoning mix and water called for one package and simmer for 4/5 minutes.
# Set aside.
# Place one wanton paper in bottom of each muffin cup.
# Later about 1 tbsp of refried beans on top of each.
# Crush one tortilla chip on top of beans.
# Top with 1 tbsp of taco meat and 1 tbsp of shredded cheese.
# Bake for 15-18 minutes.
# Ingredients:
# {u'name': u'box of brownie mix and ', u'unit': u'', u'quantity': u'1'}
# {u'name': u'cream cheese', u'unit': u'8 oz', u'quantity': u'1'}
# {u'name': u'sugar', u'unit': u'ml', u'quantity': u'79'}
# {u'name': u'vanilla', u'unit': u'ml', u'quantity': u'2'}
# {u'name': u'sliced fresh strawberries', u'unit': u'ml', u'quantity': u'473'}
# {u'name': u'fresh blueberries', u'unit': u'ml', u'quantity': u'237'}
# {u'name': u'fresh raspberries', u'unit': u'ml', u'quantity': u'237'}
# {u'name': u'apple jelly', u'unit': u'ml', u'quantity': u'118'}
# Instructions:
# Heat oven to 350°F (or 325°F for dark or nonstick pan).
# Grease bottom only of 12-inch pizza pan with cooking spray or shortening.
# In large bowl, stir brownie mix, butter and eggs until well blended.
# Spread in pan.
# Bake 18 to 20 minutes or until toothpick inserted 2 inches from side of pan comes out clean or almost clean.
# Cool completely, about 1 hour.
# In small bowl, beat cream cheese, sugar and vanilla with electric mixer on medium speed until smooth.
# Spread mixture evenly over brownie base.
# Arrange berries over cream cheese mixture.
# Stir jelly until smooth; brush over berries.
# Refrigerate about 1 hour or until chilled.
# Cut into wedges.
# Store covered in refrigerator.
# Ingredients:
# {u'name': u'Butter', u'unit': u'ml', u'quantity': u'355'}
# {u'name': u'Sugar', u'unit': u'ml', u'quantity': u'473'}
# {u'name': u'Eggs', u'unit': u'large', u'quantity': u'4'}
# {u'name': u'Vanilla extract', u'unit': u'ml', u'quantity': u'5'}
# {u'name': u'All purpose flour', u'unit': u'ml', u'quantity': u'1183'}
# {u'name': u'Baking powder', u'unit': u'ml', u'quantity': u'10'}
# {u'name': u'Salt', u'unit': u'ml', u'quantity': u'5'}
# Instructions:
# In a large bowl, cream together butter and sugar until smooth.
# Beat in eggs and vanilla.
# Stir in the flour, baking powder, and salt.
# Cover, and chill dough for at least one hour (or overnight).
# Preheat oven to 400 degrees F. Roll out dough on a floured surface to desired thickness (thin will make crispy cookies - a little thicker, approximately 1/4 inch will make fluffy, melt in your mouth cookies).
# Cut into desired shapes with floured cookie cutters.
# Place cookies 1 inch apart on a parchment lined cookie sheet (sprinkle with a little colored or Turbinado sugar, if desired).
# Bake cookies for 6 to 8 minutes in preheated oven.
# Let sit a few minutes on the sheet, then transfer to a wire rack to cool completely.
# Enjoy as is, or frost and decorate as desired.
# Makes about 5 dozen cookies (depending on thickness and size).
# WordNet match:  salt (u'salt', 1)
# WordNet match:  dough (u'sugar', 1.0)
# WordNet match:  Turbinado_sugar (u'sugar', 1.0)
# WordNet match:  Turbinado_sugar (u'sugar', 1.0)
# Ingredients:
# {u'name': u'Biscuits', u'unit': u'cans', u'quantity': u'2'}
# {u'name': u'Ground Beef', u'unit': u'kg', u'quantity': u'0.45'}
# {u'name': u'Cheese of your choice', u'unit': u'kg', u'quantity': u'0.23'}
# {u'name': u'Bacon', u'unit': u'kg', u'quantity': u'0.45'}
# Instructions:
# Just separate refrigerated biscuit dough into 8 biscuits.
# Cut each biscuit in half; roll each into ball.
# Roll out each ball with rolling pin or press with hands until about 3 inches in diameter.
# In center of each biscuit round, place 1 teaspoon ground beef and 1 cube of cheese.
# Roll up dough to completely enclose beef and cheese; pinch to seal well.
# Set aside.
# Wrap each stuffed “bomb” with 1 bacon slice; gently secure loose bacon with toothpick by inserting it through bacon and halfway into the bomb.
# In 10- to 12-inch skillet, heat oil to 350°F.
# Fry stuffed bombs for 4 to 5 minutes or until dough is golden brown on all sides.
# (If needed, remove toothpick once bacon has fried on one side in order to flip them over in the oil.)
# Place on paper towels to cool.
# Cool slightly before serving.
# WordNet match:  8_biscuit (u'biscuits', 1.0)
# WordNet match:  each_biscuit (u'biscuits', 1.0)
# WordNet match:  loose_bacon (u'bacon', 1.0)
# WordNet match:  loose_bacon (u'bacon', 1.0)
# WordNet match:  bacon (u'bacon', 1)

# %%
total_kb = {key:value for key,value in total_kb.iteritems() if value and len(value) > 0}
print_knowledge_base(total_kb)
# Out:
# icing sugar
# 	Counter({(u'add', u'VB'): 1})
# deli ham
# 	Counter({(u'place', u'VB'): 2, (u'Take', u'VB'): 1})
# chuck roast
# 	Counter({(u'Pour', u'VB'): 2, (u'add', u'VB'): 2})
# bunch kale
# 	Counter({(u'Saut\xe9', u'VB'): 1})
# chicken
# 	Counter({(u'Add', u'VB'): 1})
# medium zucchini
# 	Counter({(u'add', u'VB'): 4, (u'cook', u'VB'): 4, (u'Add', u'VB'): 2})
# blueberries
# 	Counter({(u'Serve', u'VB'): 2})
# raw honey
# 	Counter({(u'add', u'VB'): 2, (u'stir', u'VB'): 1})
# rosemary sprigs
# 	Counter({(u'discard', u'VB'): 2, (u'brown', u'VB'): 1, (u'Remove', u'VB'): 1, (u'Tuck', u'VB'): 1})
# gherkin pickles
# 	Counter({(u'pour', u'VB'): 6, (u'add', u'VB'): 4, (u'Pllace', u'VB'): 2})
# oranges
# 	Counter({(u'Add', u'VB'): 1})
# red wine
# 	Counter({(u'deglaze', u'VB'): 3, (u'add', u'VB'): 2, (u'Sweat', u'VB'): 1})
# crushed tomatoes
# 	Counter({(u'Add', u'VB'): 1})
# garlic, or 1/4 teaspoon garlic powder
# 	Counter({(u'chop', u'VB'): 2, (u'Peel', u'VB'): 1})
# caramel ice cream topping
# 	Counter({(u'drizzle', u'VB'): 2, (u'Place', u'VB'): 1})
# potatoes
# 	Counter({(u'continue', u'VB'): 2, (u'shred', u'VB'): 1, (u'peel', u'VB'): 1, (u'foil', u'VB'): 1})
# sliced mushrooms
# 	Counter({(u'Add', u'VB'): 2, (u'cook', u'VB'): 1})
# pork tenderloins
# 	Counter({(u'Place', u'VB'): 2, (u'test', u'VB'): 2, (u'pour', u'VB'): 1, (u'Remove', u'VB'): 1})
# prosciutto
# 	Counter({(u'Crumble', u'VB'): 2, (u'fold', u'VB'): 1, (u'Bake', u'VB'): 1})
# cooked corn
# 	Counter({(u'Turn', u'VB'): 4, (u'top', u'VB'): 2})
# white wine
# 	Counter({(u'Pour', u'VB'): 2, (u'add', u'VB'): 1})
# lime zest
# 	Counter({(u'lime', u'VB'): 2})
# lean corned beef
# 	Counter({(u'Add', u'VB'): 6, (u'bring', u'VB'): 3, (u'Remove', u'VB'): 2})
# hibiscus tea bags
# 	Counter({(u'remove', u'VB'): 4, (u'allow', u'VB'): 3, (u'squeeze', u'VB'): 1})
# white vinegar
# 	Counter({(u'Fill', u'VB'): 1})
# wheat english muffin
# 	Counter({(u'SERVE', u'VB'): 1})
# chicken stock
# 	Counter({(u'stir', u'VB'): 4, (u'Turn', u'VB'): 1})
# turkey breast
# 	Counter({(u'Pour', u'VB'): 2, (u'spread', u'VB'): 1})
# ground beef patties
# 	Counter({(u'Top', u'VB'): 2, (u'continue', u'VB'): 1})
# tomato salsa
# 	Counter({(u'Serve', u'VB'): 1})
# real butter
# 	Counter({(u'add', u'VB'): 2, (u'Run', u'VB'): 1})
# barley
# 	Counter({(u'saute', u'VB'): 1, (u'stir', u'VB'): 1, (u'Add', u'VB'): 1})
# garlic minced
# 	Counter({(u'saute', u'VB'): 2, (u'Add', u'VB'): 1})
# coconut oil
# 	Counter({(u'melt', u'VB'): 4, (u'be', u'VB'): 2, (u'freezer,', u'VB'): 2, (u'Melt', u'VB'): 2, (u'Cool', u'VB'): 1, (u'add', u'VB'): 1})
# balsamic vinegar
# 	Counter({(u'combine', u'VB'): 3, (u'make', u'VB'): 2})
# vinegar
# 	Counter({(u'Add', u'VB'): 1})
# biscuits
# 	Counter({(u'Cut', u'VB'): 1})
# wheat hamburger buns
# 	Counter({(u'cover', u'VB'): 2, (u'onion', u'VB'): 1, (u'Add', u'VB'): 1})
# yellow pepper
# 	Counter({(u'Add', u'VB'): 4, (u'cook', u'VB'): 2})
# neufchatel cheese
# 	Counter({(u'Bake', u'VB'): 1})
# miso
# 	Counter({(u'Create', u'VB'): 4, (u'add', u'VB'): 2})
# spicy tomato sauce
# 	Counter({(u'Pour', u'VB'): 1})
# kale (lacinto)
# 	Counter({(u'massage', u'VB'): 3, (u'Use', u'VB'): 1})
# red potatoes
# 	Counter({(u'cook', u'VB'): 7, (u'stick', u'VB'): 3, (u'Put', u'VB'): 3, (u'Drain', u'VB'): 2, (u'need', u'VB'): 2, (u'toss', u'VB'): 2, (u'be', u'VB'): 1, (u'Add', u'VB'): 1, (u'put', u'VB'): 1, (u'fall', u'VB'): 1, (u'bring', u'VB'): 1, (u'Cook', u'VB'): 1, (u'flip', u'VB'): 1})
# soy
# 	Counter({(u'be', u'VB'): 2, (u'Cool', u'VB'): 2, (u'remain', u'VB'): 2, (u'refrigerate', u'VB'): 1})
# large red peppers
# 	Counter({(u'Remove', u'VB'): 1})
# butterscotch chips
# 	Counter({(u'add', u'VB'): 1})
# leeks
# 	Counter({(u'Cook', u'VB'): 1})
# turkey
# 	Counter({(u'Place', u'VB'): 2, (u'Remove', u'VB'): 2, (u'rinse', u'VB'): 1, (u'Baste', u'VB'): 1, (u'Rinse', u'VB'): 1, (u'Roast', u'VB'): 1, (u'pan', u'VB'): 1, (u'Stuff', u'VB'): 1, (u'Soak', u'VB'): 1, (u'Pour', u'VB'): 1, (u'skim', u'VB'): 1})
# russet potatoes (or 3 cups mashed potatoes)
# 	Counter({(u'Strain', u'VB'): 2, (u'simmer', u'VB'): 2, (u'reduce', u'VB'): 1, (u'transfer', u'VB'): 1, (u'Mash', u'VB'): 1})
# parsley
# 	Counter({(u'Stuff', u'VB'): 1})
# buttermilk
# 	Counter({(u'Combine', u'VB'): 1})
# yellow mustard seeds
# 	Counter({(u'rinse', u'VB'): 7, (u'bring', u'VB'): 6, (u'add', u'VB'): 5, (u'cover', u'VB'): 3, (u'Drain', u'VB'): 3})
# soy flakes
# 	Counter({(u'bring', u'VB'): 1, (u'reduce', u'VB'): 1, (u'simmer,', u'VB'): 1, (u'Add', u'VB'): 1})
# white onion
# 	Counter({(u'Soak', u'VB'): 1})
# chorizo sausage
# 	Counter({(u'add', u'VB'): 2, (u'swap', u'VB'): 1, (u'cook', u'VB'): 1})
# shallot
# 	Counter({(u'deglaze', u'VB'): 1, (u'Sweat', u'VB'): 1, (u'add', u'VB'): 1})
# strawberries
# 	Counter({(u'hull', u'VB'): 2, (u'pick', u'VB'): 1})
# chile peppers
# 	Counter({(u'hold', u'VB'): 3, (u'pick', u'VB'): 3, (u'remove', u'VB'): 2, (u'Rub', u'VB'): 1})
# oil
# 	Counter({(u'Add', u'VB'): 4, (u'coat', u'VB'): 3, (u'sit', u'VB'): 2, (u'Turn', u'VB'): 1, (u'place', u'VB'): 1})
# instant yeast
# 	Counter({(u'sit', u'VB'): 2, (u'Add', u'VB'): 1})
# pizza dough
# 	Counter({(u'cut', u'VB'): 3, (u'Roll', u'VB'): 1, (u'Use', u'VB'): 1})
# fresh spinach
# 	Counter({(u'Place', u'VB'): 1, (u'Lay', u'VB'): 1})
# vegan sour cream
# 	Counter({(u'stir', u'VB'): 4, (u'Take', u'VB'): 2, (u'return', u'VB'): 1})
# monterey jack
# 	Counter({(u'Turn', u'VB'): 2, (u'top', u'VB'): 1})
# basmati rice
# 	Counter({(u'Cook', u'VB'): 1})
# broth
# 	Counter({(u'bring', u'VB'): 1, (u'reduce', u'VB'): 1, (u'simmer,', u'VB'): 1, (u'Add', u'VB'): 1})
# cauliflower
# 	Counter({(u'Place', u'VB'): 2, (u'Add', u'VB'): 1, (u'Steam', u'VB'): 1, (u'wrap', u'VB'): 1, (u'Make', u'VB'): 1})
# turkey stock
# 	Counter({(u'Rub', u'VB'): 3, (u'Add', u'VB'): 3, (u'rub', u'VB'): 3, (u'serve', u'VB'): 2, (u'bring', u'VB'): 2, (u'Pour', u'VB'): 2, (u'Strain', u'VB'): 1, (u'Slice', u'VB'): 1, (u'Baste', u'VB'): 1, (u'transfer', u'VB'): 1, (u'simmer', u'VB'): 1})
# beef fillet
# 	Counter({(u'Sear', u'VB'): 1, (u'Glaze', u'VB'): 1, (u'cook', u'VB'): 1})
# fresh lemon
# 	Counter({(u'squeeze', u'VB'): 2, (u'Add', u'VB'): 1})
# yellow onion
# 	Counter({(u'Stuff', u'VB'): 2})
# egg
# 	Counter({(u'sit', u'VB'): 2, (u'Add', u'VB'): 1})
# onions
# 	Counter({(u'stir', u'VB'): 2, (u'Add', u'VB'): 1})
# bread flour
# 	Counter({(u'add', u'VB'): 3})
# heavy cream (more to taste)
# 	Counter({(u'Splash', u'VB'): 2, (u'stir', u'VB'): 1})
#  milk
# 	Counter({(u'thicken', u'VB'): 2, (u'smooth', u'VB'): 1, (u'Add', u'VB'): 1})
# flank steak
# 	Counter({(u'place', u'VB'): 2, (u'Place', u'VB'): 1, (u'wrap', u'VB'): 1})
# minced garlic
# 	Counter({(u'Coat', u'VB'): 1})
# quinoa
# 	Counter({(u'Scoop', u'VB'): 1})
# cabbage
# 	Counter({(u'add', u'VB'): 6, (u'Return', u'VB'): 2})
# vinaigrette
# 	Counter({(u'Taste', u'VB'): 2, (u'add', u'VB'): 2, (u'dress', u'VB'): 2, (u'Mix', u'VB'): 1, (u'adjust', u'VB'): 1, (u'Create', u'VB'): 1})
# sesame seeds
# 	Counter({(u'Scatter', u'VB'): 1})
# lasagna noodles
# 	Counter({(u'Use', u'VB'): 4, (u'Layer', u'VB'): 3, (u'Cook', u'VB'): 2, (u'top', u'VB'): 2, (u'Bake', u'VB'): 1, (u'Pour', u'VB'): 1})
# hummus (cilantro or other)
# 	Counter({(u'Spread', u'VB'): 1})
# medium shrimp
# 	Counter({(u'continue', u'VB'): 2, (u'Add', u'VB'): 1})
# egg
# 	Counter({(u'MICROWAVE', u'VB'): 1})
# chicken breasts
# 	Counter({(u'spread', u'VB'): 2, (u'Mix', u'VB'): 1})
# apple cider vinegar
# 	Counter({(u'Whisk', u'VB'): 4, (u'stir', u'VB'): 2})

# %%
def get_intersection(kb, ing1, ing2):
    n = 0
    for verb1, count1 in kb[ing1].iteritems():
        for verb2, count2 in kb[ing2].iteritems():
            if verb1 == verb2:
                n += min(count1, count2)
    return n

MINIMUM_OVERLAP = 3
def are_equivalent(kb, ing1, ing2):
    return get_intersection(kb, ing1, ing2) > MINIMUM_OVERLAP
    
equivalencies = {}
for ingredient in total_kb:
    equivs = []
    for other in total_kb:
        if ingredient != other and are_equivalent(total_kb, ingredient, other):
            equivs.append(other)
    equivalencies[ingredient] = equivs

# %%
# print equivalencies
import pprint

equivalencies = {key:value for key,value in equivalencies.iteritems() if value and len(value) > 0}
pprint.pprint(equivalencies)
# Out:
# {u'broth': [u'soy flakes'],
#  u'cabbage': [u'medium zucchini', u'gherkin pickles', u'yellow mustard seeds'],
#  u'chicken stock': [u'vegan sour cream'],
#  u'gherkin pickles': [u'medium zucchini', u'yellow mustard seeds', u'cabbage'],
#  u'lean corned beef': [u'yellow pepper', u'oil ', u'turkey stock'],
#  u'medium zucchini': [u'gherkin pickles',
#                       u'yellow pepper',
#                       u'red potatoes',
#                       u'yellow mustard seeds',
#                       u'cabbage'],
#  u'oil ': [u'lean corned beef', u'yellow pepper'],
#  u'red potatoes': [u'medium zucchini'],
#  u'soy flakes': [u'broth'],
#  u'turkey stock': [u'lean corned beef'],
#  u'vegan sour cream': [u'chicken stock'],
#  u'yellow mustard seeds': [u'medium zucchini', u'gherkin pickles', u'cabbage'],
#  u'yellow pepper': [u'medium zucchini', u'lean corned beef', u'oil ']}

# %%
print total_kb['red potatoes']
print total_kb['broth']
print total_kb['shallot']
# Out:
# Counter({(u'cook', u'VB'): 7, (u'stick', u'VB'): 3, (u'Put', u'VB'): 3, (u'Drain', u'VB'): 2, (u'need', u'VB'): 2, (u'toss', u'VB'): 2, (u'be', u'VB'): 1, (u'Add', u'VB'): 1, (u'put', u'VB'): 1, (u'fall', u'VB'): 1, (u'bring', u'VB'): 1, (u'Cook', u'VB'): 1, (u'flip', u'VB'): 1})
# Counter({(u'bring', u'VB'): 1, (u'reduce', u'VB'): 1, (u'simmer,', u'VB'): 1, (u'Add', u'VB'): 1})
# Counter({(u'deglaze', u'VB'): 1, (u'Sweat', u'VB'): 1, (u'add', u'VB'): 1})

# %%
total_kb['red potatoes'][('cook', 'VB')]
# Out:
# 7
