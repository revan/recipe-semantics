# %% [markdown]
# ### Parsing Steps
#     - Use parser (stanford or bllip) to parse each sentence
#     - For each noun phrase, travel up the tree to find verb.
#     - Write wordnet ancestor search to resolve references from noun phrase to ingredient
#     - Keep dict of ingredients -> counter of actions
#
# ### Search Steps
#     - For given set of ingredients
#         - Sort recipes by most shared ingredients
#         - For any missing ingredients, see how similar the dict entries are to determine if can substitute

# %%
import os
from nltk.parse import stanford
from nltk.tree import Tree

os.environ['STANFORD_PARSER'] = 'stanford-parser-full-2015-01-30/'
os.environ['STANFORD_MODELS'] = 'stanford-parser-full-2015-01-30/'
parser = stanford.StanfordParser(model_path="stanford-parser-full-2015-01-30/englishPCFG.ser.gz")

def parse_sentences(sentences):
    """ returns list of Tree's for input list of strings """
    return parser.parse_sents([sentence.split() for sentence in sentences])

def draw_sentences(tree_list):
    """ GUI debugging """
    for sentence in tree_list:
        sentence.draw()

# %%
import json
with open('sample.json') as f:
    sample_recipe = json.load(f)

# %%
with open('bigoven_cleaned.json') as f:
    test_recipes = json.load(f)[0:100]

# %%
def process_recipe(recipe):
    print 'Ingredients:'
    for ingredient in recipe['ingredients']:
        print ingredient
    
    print 'Instructions:'
    instr_trees = parse_sentences(recipe['instructions'])
    for instruction, tree in zip(recipe['instructions'], instr_trees):
        print instruction
        print tree
    
    return instr_trees
    
    #draw_sentences(instr_trees)
    
trees = process_recipe(sample_recipe)
# Out:
# Ingredients:
# {u'name': u'Lasagna noodles ', u'unit': u'package (~12 oz.)', u'quantity': u'1'}
# {u'name': u'Olive oil', u'unit': u'ml', u'quantity': u'30'}
# {u'name': u'Tomato basil pasta sauce', u'unit': u'jars', u'quantity': u'1 1/2'}
# {u'name': u'Ricotta Cheese part skim', u'unit': u'16 oz container', u'quantity': u'1'}
# {u'name': u'Roasted garlic', u'unit': u'cloves', u'quantity': u'10'}
# {u'name': u'Fresh baby spinach', u'unit': u'handfuls', u'quantity': u'4'}
# {u'name': u'Artichoke hearts (in water)', u'unit': u'15 oz can/jar', u'quantity': u'1'}
# {u'name': u'Dried parsley', u'unit': u'ml', u'quantity': u'2'}
# {u'name': u'Red pepper flakes', u'unit': u'ml', u'quantity': u'2'}
# {u'name': u'Ground black pepper ', u'unit': u'ml', u'quantity': u'2'}
# {u'name': u'Parmesan cheese', u'unit': u'ml', u'quantity': u'177'}
# {u'name': u'Monterey jack cheese, reduced fat', u'unit': u'g', u'quantity': u'170'}
# {u'name': u'Part Skim Mozzarella Cheese', u'unit': u'g', u'quantity': u'170'}
# {u'name': u'Fresh basil', u'unit': u'ml', u'quantity': u'59'}
# Instructions:
# Bring large pot of water to a boil.
# (ROOT
#   (S
#     (VP
#       (VB Bring)
#       (NP (NP (JJ large) (NN pot)) (PP (IN of) (NP (NN water))))
#       (PP (TO to) (NP (DT a) (NN boil.))))))
# While water is heating up, mix the ricotta, roasted garlic, spinach, artichoke hearts, dried parsley, red pepper flakes, black pepper and 1/4 cup parmesan cheese together in a large bowl.
# (ROOT
#   (SBAR
#     (IN While)
#     (S
#       (NP (NN water))
#       (VP
#         (VBZ is)
#         (VP
#           (VBG heating)
#           (NP
#             (NP (NN up,) (NN mix))
#             (SBAR
#               (S
#                 (NP
#                   (DT the)
#                   (NNP ricotta,)
#                   (NNP roasted)
#                   (NNP garlic,)
#                   (NNP spinach,)
#                   (NNP artichoke)
#                   (NNP hearts,))
#                 (VP
#                   (VBD dried)
#                   (NP
#                     (JJ parsley,)
#                     (JJ red)
#                     (CD pepper)
#                     (NNP flakes,)
#                     (JJ black)
#                     (NN pepper)
#                     (CC and)
#                     (CD 1/4)
#                     (NN cup)
#                     (NN parmesan)
#                     (NN cheese))
#                   (ADVP (RB together))
#                   (PP (IN in) (NP (DT a) (JJ large) (NN bowl.))))))))))))
# Pour 1 tablespoon of olive oil in the boiling water before adding the pasta.
# (ROOT
#   (S
#     (VP
#       (VB Pour)
#       (NP
#         (NP (CD 1) (NN tablespoon))
#         (PP
#           (IN of)
#           (NP
#             (NP (JJ olive) (NN oil))
#             (PP (IN in) (NP (DT the) (JJ boiling) (NN water))))))
#       (PP
#         (IN before)
#         (S (VP (VBG adding) (NP (DT the) (NN pasta.))))))))
# Cook the pasta a few minutes or until about halfway cooked, then drain.
# (ROOT
#   (SINV
#     (VP
#       (VP
#         (VB Cook)
#         (NP (DT the) (NN pasta))
#         (NP (DT a) (JJ few) (NNS minutes)))
#       (CC or)
#       (VP
#         (PP
#           (IN until)
#           (NP (QP (RB about) (CD halfway) (CD cooked,))))
#         (ADVP (RB then))))
#     (NP (NNP drain.))))
# Drizzle the remaining tablespoon of olive oil in a large rectangular glass pan.
# (ROOT
#   (S
#     (VP
#       (VB Drizzle)
#       (NP
#         (NP (DT the) (VBG remaining) (NN tablespoon))
#         (PP
#           (IN of)
#           (NP
#             (NP (JJ olive) (NN oil))
#             (PP
#               (IN in)
#               (NP
#                 (DT a)
#                 (JJ large)
#                 (JJ rectangular)
#                 (NN glass)
#                 (NN pan.)))))))))
# Layer a little bit of the pasta sauce on the bottom of the pan.
# (ROOT
#   (S
#     (VP
#       (VB Layer)
#       (NP
#         (NP (DT a) (JJ little) (NN bit))
#         (PP
#           (IN of)
#           (NP
#             (NP (DT the) (NN pasta) (NN sauce))
#             (PP
#               (IN on)
#               (NP
#                 (NP (DT the) (NN bottom))
#                 (PP (IN of) (NP (DT the) (NN pan.)))))))))))
# Layer 1/3 of the pasta noodles in the pan.
# (ROOT
#   (S
#     (VP
#       (VB Layer)
#       (NP
#         (NP (CD 1/3))
#         (PP
#           (IN of)
#           (NP
#             (NP (DT the) (NN pasta) (NNS noodles))
#             (PP (IN in) (NP (DT the) (NN pan.)))))))))
# Layer a little more pasta sauce on top of the noodles.
# (ROOT
#   (S
#     (VP
#       (VB Layer)
#       (NP
#         (NP
#           (DT a)
#           (ADJP (RB little) (JJR more))
#           (NN pasta)
#           (NN sauce))
#         (PP
#           (IN on)
#           (NP (NP (NN top)) (PP (IN of) (NP (DT the) (NN noodles.)))))))))
# Take 1/2 of the ricotta mixture and drop evenly over the noodles and sauce in the pan.
# (ROOT
#   (S
#     (VP
#       (VP
#         (VB Take)
#         (NP
#           (NP (CD 1/2))
#           (PP (IN of) (NP (DT the) (NN ricotta) (NN mixture)))))
#       (CC and)
#       (VP
#         (VB drop)
#         (ADVP (RB evenly))
#         (PP
#           (IN over)
#           (NP
#             (NP (DT the) (NNS noodles) (CC and) (NN sauce))
#             (PP (IN in) (NP (DT the) (NN pan.)))))))))
# Top the ricotta with 1/3 of the jack cheese and 1/3 of the mozzarella.
# (ROOT
#   (NP
#     (NP (NNP Top))
#     (NP
#       (NP (DT the) (NN ricotta))
#       (PP
#         (IN with)
#         (NP
#           (NP
#             (NP (CD 1/3))
#             (PP (IN of) (NP (DT the) (NN jack) (NN cheese))))
#           (CC and)
#           (NP
#             (NP (CD 1/3))
#             (PP (IN of) (NP (DT the) (NN mozzarella.)))))))))
# Layer another 1/3 of the noodles in the pan with more sauce on top.
# (ROOT
#   (S
#     (VP
#       (VB Layer)
#       (NP
#         (NP (QP (DT another) (CD 1/3)))
#         (PP
#           (IN of)
#           (NP
#             (NP (DT the) (NNS noodles))
#             (PP
#               (IN in)
#               (NP
#                 (NP (DT the) (NN pan))
#                 (PP
#                   (IN with)
#                   (NP
#                     (NP (JJR more) (NN sauce))
#                     (PP (IN on) (NP (NN top.)))))))))))))
# Finish dropping the rest of the ricotta mixture over the lasagna.
# (ROOT
#   (S
#     (VP
#       (VB Finish)
#       (S
#         (VP
#           (VBG dropping)
#           (NP
#             (NP (DT the) (NN rest))
#             (PP
#               (IN of)
#               (NP
#                 (NP (DT the) (NN ricotta) (NN mixture))
#                 (PP (IN over) (NP (DT the) (NN lasagna.)))))))))))
# Top with 1/3 of the jack cheese and 1/3 of the mozzarella.
# (ROOT
#   (ADJP
#     (ADJP (NNP Top))
#     (PP
#       (IN with)
#       (NP
#         (NP
#           (NP (CD 1/3))
#           (PP (IN of) (NP (DT the) (NN jack) (NN cheese))))
#         (CC and)
#         (NP
#           (NP (CD 1/3))
#           (PP (IN of) (NP (DT the) (NN mozzarella.))))))))
# Use the rest of the noodles and top with the rest of the sauce.
# (ROOT
#   (S
#     (VP
#       (VP
#         (VB Use)
#         (NP
#           (NP (DT the) (NN rest))
#           (PP (IN of) (NP (DT the) (NNS noodles)))))
#       (CC and)
#       (VP
#         (VB top)
#         (PP
#           (IN with)
#           (NP
#             (NP (DT the) (NN rest))
#             (PP (IN of) (NP (DT the) (NN sauce.)))))))))
# Sprinkle the top of the lasagna with the remaining parmesan, jack, and mozzarella cheeses.
# (ROOT
#   (S
#     (VP
#       (VB Sprinkle)
#       (NP
#         (NP (DT the) (NN top))
#         (PP
#           (IN of)
#           (NP
#             (NP (DT the) (NN lasagna))
#             (PP
#               (IN with)
#               (NP
#                 (DT the)
#                 (VBG remaining)
#                 (NNP parmesan,)
#                 (NN jack,)
#                 (CC and)
#                 (NN mozzarella)
#                 (NN cheeses.)))))))))
# Bake in a 375 degree oven until hot, golden and bubbly, making sure the noodles are cooked through (about 40 minutes.)
# (ROOT
#   (S
#     (VP
#       (VB Bake)
#       (PP (IN in) (NP (DT a) (CD 375) (NN degree) (NN oven)))
#       (PP
#         (IN until)
#         (S
#           (VP
#             (VP (VBG hot,) (ADJP (JJ golden)))
#             (CC and)
#             (VP
#               (VBG bubbly,)
#               (S
#                 (VP
#                   (VBG making)
#                   (ADJP
#                     (JJ sure)
#                     (SBAR
#                       (S
#                         (NP (DT the) (NNS noodles))
#                         (VP
#                           (VBP are)
#                           (VP
#                             (VBN cooked)
#                             (PP
#                               (IN through)
#                               (NP
#                                 (JJ -LRB-about)
#                                 (CD 40)
#                                 (NNS minutes.-RRB-)))))))))))))))))
# Top with fresh basil before serving.
# (ROOT
#   (FRAG
#     (NP (NNP Top))
#     (PP (IN with) (NP (JJ fresh) (NN basil)))
#     (PP (IN before) (NP (NN serving.)))))

# %%
from collections import Counter

"""
Search subtrees, calling match_noun_to_verb() on every verb phrase.
"""
def crawl_tree(tree, ingredients, knowledge_base):
    for child in tree.subtrees(lambda t: t.label() in ['VP']):
        #print 'found verb phrase:', child.flatten(), 'Looking for noun in children.'
        
        for ing in match_noun_to_verb_phrase(child):
            
            knowledge_base[ing].update(find_verb(child, ing))
        
"""
Returns the verb phrase's VB's and NN's.
"""
def find_verb(vp, ingredient):
    return map(lambda w: (w[0].lower(), w[1]), filter(lambda w: w[1] in ['VB'] and w[0] not in [ingredient], vp.pos()))
        
        
"""
Search subtrees for ingredient(s) affected by the verb in a verb phrase.
"""
def match_noun_to_verb_phrase(tree):
    matches = []
    for child in tree.subtrees(lambda t: t.label() in ['NP']):
        #print 'found NP:', child.flatten()
        (ingredient_match, confidence) = resolve_np(child, ingredients)
        if confidence > 0:
            matches.append(ingredient_match)
            #print 'confident match! saving:', ingredient_match, child.flatten()
                
    return matches


"""
For Tree np and list ingredients, tries to find match between np and ingredients.
Returns (matched_ingredient_name, confidence)
"""
def resolve_np(np, ingredients):
    np_flat = ' '.join(np.flatten())
    
    np_flat = norm_noun(np_flat)
    
    #print 'Trying to resolve NP:', np_flat
    
    matches = [(ing, wordnet_search(np_flat, norm_noun(ing))) for ing in ingredients]
    
    if matches:
        match = max(matches, key=lambda e:e[1])

        min_confidence = 0.9
        if match[1] > min_confidence:
            print 'WordNet match: ', np_flat, match
            return match

    #print 'Found no match.'
    
    return ('', 0)


"""
Searches through wordnet for common ancestors between two strings.
"""
from nltk.corpus import wordnet as wn
known_matches = {}
def wordnet_search(ing1, ing2):
    # Try to hit cache first
    if (ing1, ing2) in known_matches:
        return known_matches[(ing1, ing2)]
    if (ing2, ing1) in known_matches:
        return known_matches[(ing2, ing1)]
    
    # Exact match is exact
    if ing1.lower() == ing2.lower():
        return 1
    
    full_syns1 = wn.synsets(ing1)
    full_syns2 = wn.synsets(ing2)
    
    
    if full_syns1 == []:
        full_syns1 = wn.synsets(normed_noun_truncate(ing1))
    
    if full_syns2 == []:
        full_syns2 = wn.synsets(normed_noun_truncate(ing2))

    
    possible_matches = [ syn1.wup_similarity(syn2) for syn2 in full_syns2 for syn1 in full_syns1]
    if len(possible_matches) > 0:
        best = max(possible_matches)
        known_matches[(ing1, ing2)] = best
        return best
    
    return 0

"""
Gets singular form of noun.
Runs lemmatizer on last word, prepends rest of name
"""
from nltk.stem.wordnet import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
def norm_noun(noun):
    # TODO handle 'artichoke hearts', ex
    
    # strip ( ,
    noun = noun.split('(')[0].split(',')[0].strip(' .?!')
    
    # remove leading "the"
    leading_strip = ['the ', 'rest of the ']
    for banned in leading_strip:
        if noun.startswith(banned):
            noun = noun[len(banned):]
    
    pieces = noun.split()
    
    if len(pieces) > 0:
        return '_'.join(pieces[:-1] + [lemmatizer.lemmatize(pieces[-1], pos='n')])
    return noun

"""
Drops first word from multi-word noun phrase.
"""
def normed_noun_truncate(noun):
    return '_'.join(noun.split('_')[1:])

def print_knowledge_base(knowledge_base):
    for ingredient,matches in knowledge_base.iteritems():
        print ingredient
        print '\t', matches

# %%
# Runs above algorithm on ten sample recipes
total_kb = {}
for r in test_recipes:
    ingredients = [ing['name'].lower() for ing in r['ingredients']]
    # ingredients.append('meat')
    # ingredients.append('noodles')
    
    knowledge_base = {ing : Counter() for ing in ingredients}
    
    for tree in process_recipe(r):
        crawl_tree(tree, ingredients, knowledge_base)
#     print_knowledge_base(knowledge_base)
    
    # merge knowledge_base into total_kb
    for ingredient,matches in knowledge_base.iteritems():
        if ingredient in total_kb:
            knowledge_base[ingredient] = matches.update(total_kb[ingredient])
    total_kb.update(knowledge_base)
# Out:
# Ingredients:
# {u'name': u'frozen young turkey', u'unit': u'kg', u'quantity': u'7'}
# {u'name': u'Kosher salt', u'unit': u'ml', u'quantity': u'237'}
# {u'name': u'Light brown sugar', u'unit': u'ml', u'quantity': u'118'}
# {u'name': u'Water', u'unit': u'l', u'quantity': u'4'}
# {u'name': u'black peppercorns', u'unit': u'ml', u'quantity': u'15'}
# {u'name': u'allspice berry', u'unit': u'ml', u'quantity': u'7'}
# {u'name': u'Water', u'unit': u'l', u'quantity': u'4'}
# {u'name': u'red apple', u'unit': u'', u'quantity': u'1'}
# {u'name': u'onion', u'unit': u'', u'quantity': u'1/2'}
# {u'name': u'Cinnamon', u'unit': u'', u'quantity': u'1'}
# {u'name': u'Water', u'unit': u'ml', u'quantity': u'237'}
# {u'name': u'rosemary', u'unit': u'sprigs', u'quantity': u'4'}
# {u'name': u'leaves sage', u'unit': u'', u'quantity': u'6'}
# {u'name': u'Canola Oil', u'unit': u'ml', u'quantity': u'118'}
# Instructions:
# Combine all brine ingredients, except ice water, in a stock pot and bring to a boil.
# (ROOT
#   (S
#     (VP
#       (VP
#         (VB Combine)
#         (NP (DT all) (NN brine) (NN ingredients,))
#         (PP
#           (IN except)
#           (NP
#             (NP (NN ice) (NNS water,))
#             (PP (IN in) (NP (DT a) (NN stock) (NN pot))))))
#       (CC and)
#       (VP (VB bring) (PP (TO to) (NP (DT a) (NN boil.)))))))
# Stir to dissolve solids, then remove from heat, cool to room temperature refrigerate until thoroughly chilled.
# (ROOT
#   (S
#     (VP
#       (VB Stir)
#       (S
#         (VP
#           (TO to)
#           (VP
#             (VB dissolve)
#             (S
#               (NP (NNP solids,))
#               (RB then)
#               (VP
#                 (VB remove)
#                 (PP
#                   (IN from)
#                   (NP
#                     (ADJP
#                       (RB heat,)
#                       (JJ cool)
#                       (PP (TO to) (NP (NN room) (NN temperature))))
#                     (ADJP
#                       (JJ refrigerate)
#                       (PP (IN until) (ADVP (RB thoroughly))))
#                     (NN chilled.)))))))))))
# Early on the day of cooking, (or late the night before) combine the brine and ice water in a clean 5 gallon bucket.
# (ROOT
#   (S
#     (VP
#       (ADVP
#         (RB Early)
#         (PP
#           (IN on)
#           (NP
#             (NP (DT the) (NN day))
#             (PP
#               (IN of)
#               (NP
#                 (JJ cooking,)
#                 (ADJP
#                   (JJ -LRB-or)
#                   (NP (RB late) (DT the) (NN night)))
#                 (NNS before-RRB-))))))
#       (VB combine)
#       (NP
#         (NP (DT the) (NN brine) (CC and) (NN ice) (NN water))
#         (PP
#           (IN in)
#           (NP
#             (DT a)
#             (JJ clean)
#             (ADJP (CD 5) (NN gallon))
#             (NN bucket.)))))))
# Place thawed turkey breast side down in brine, cover, and refrigerate or set in cool area (like a basement) for 6 hours.
# (ROOT
#   (S
#     (VP
#       (VP
#         (VB Place)
#         (NP (JJ thawed) (NN turkey) (NN breast) (NN side))
#         (PRT (RP down))
#         (PP (IN in) (NP (NNP brine,) (NNP cover,))))
#       (CC and)
#       (VP
#         (VB refrigerate)
#         (CC or)
#         (VB set)
#         (PP (IN in) (NP (JJ cool) (NN area) (NN -LRB-like))))
#       (NP (DT a) (NN basement-RRB-))
#       (PP (IN for) (NP (CD 6) (NN hours.))))))
# Turn turkey over once, half way through brining.
# (ROOT
#   (S
#     (VP
#       (VB Turn)
#       (NP (NN turkey))
#       (PP
#         (IN over)
#         (S
#           (VP
#             (VBG once,)
#             (NP (DT half) (NN way))
#             (PP (IN through) (NP (NN brining.)))))))))
# A few minutes before roasting, heat oven to 500 degrees.
# (ROOT
#   (FRAG
#     (NP (DT A) (JJ few) (NNS minutes))
#     (PP
#       (IN before)
#       (S
#         (VP
#           (VBG roasting,)
#           (NP (NN heat) (NN oven))
#           (PP (TO to) (NP (QP (CD 500) (CD degrees.)))))))))
# Combine the apple, onion, cinnamon stick and cup of water in a microwave safe dish and microwave on high for 5 minutes.
# (ROOT
#   (S
#     (VP
#       (VB Combine)
#       (NP
#         (NP
#           (DT the)
#           (NNP apple,)
#           (NNP onion,)
#           (NNP cinnamon)
#           (NN stick)
#           (CC and)
#           (NN cup))
#         (PP
#           (IN of)
#           (NP
#             (NP
#               (NP (NN water))
#               (PP
#                 (IN in)
#                 (NP (DT a) (NN microwave) (JJ safe) (NN dish))))
#             (CC and)
#             (NP
#               (NP (NN microwave))
#               (PP
#                 (IN on)
#                 (NP
#                   (ADJP (JJ high) (PP (IN for) (NP (CD 5))))
#                   (NN minutes.))))))))))
# Remove bird from brine and rinse inside and out with cold water.
# (ROOT
#   (S
#     (VP
#       (VP (VB Remove) (NP (NN bird)) (PP (IN from) (NP (NN brine))))
#       (CC and)
#       (VP
#         (VB rinse)
#         (ADVP (RB inside) (CC and) (RB out))
#         (PP (IN with) (NP (JJ cold) (NN water.)))))))
# Discard brine.
# (ROOT (NP (NNP Discard) (NNP brine.)))
# Place bird on roasting rack inside wide, low pan and pat dry with paper towels.
# (ROOT
#   (S
#     (VP
#       (VP
#         (VB Place)
#         (NP (NN bird))
#         (PP
#           (IN on)
#           (S
#             (VP
#               (VBG roasting)
#               (NP (NN rack))
#               (PP (IN inside) (NP (JJ wide,) (JJ low) (NNS pan)))))))
#       (CC and)
#       (VP
#         (VB pat)
#         (ADJP (JJ dry))
#         (PP (IN with) (NP (NN paper) (NN towels.)))))))
# Add steeped aromatics to cavity along with rosemary and sage.
# (ROOT
#   (S
#     (VP
#       (VB Add)
#       (S
#         (NP (JJ steeped) (NNS aromatics))
#         (VP
#           (TO to)
#           (VP
#             (VB cavity)
#             (PRT (RP along))
#             (PP (IN with) (NP (NN rosemary) (CC and) (NN sage.)))))))))
# Tuck back wings and coat whole bird liberally with canola (or other neutral) oil.
# (ROOT
#   (S
#     (VP
#       (VP (VB Tuck) (PRT (RP back)) (NP (NNS wings)))
#       (CC and)
#       (VP
#         (VB coat)
#         (NP (JJ whole) (NN bird) (NN liberally))
#         (PP
#           (IN with)
#           (NP
#             (NN canola)
#             (JJ -LRB-or)
#             (JJ other)
#             (NN neutral-RRB-)
#             (NN oil.)))))))
# Roast on lowest level of the oven at 500F for 30 minutes.
# (ROOT
#   (S
#     (VP
#       (VB Roast)
#       (PP
#         (IN on)
#         (NP
#           (NP (JJS lowest) (NN level))
#           (PP
#             (IN of)
#             (NP (NP (DT the) (NN oven)) (PP (IN at) (NP (CD 500F)))))))
#       (PP (IN for) (NP (CD 30) (NN minutes.))))))
# Remove from oven and cover breast with double layer of aluminum foil, insert probe thermometer into thickest part of the breast and return to oven, reducing temperature to 350 degrees F.
# (ROOT
#   (SINV
#     (VP
#       (VP (VB Remove) (PP (IN from) (NP (NN oven))))
#       (CC and)
#       (VP
#         (VP
#           (VB cover)
#           (NP (NN breast))
#           (PP
#             (IN with)
#             (NP
#               (NP (JJ double) (NN layer))
#               (PP
#                 (IN of)
#                 (NP
#                   (NN aluminum)
#                   (CD foil,)
#                   (NN insert)
#                   (NN probe)
#                   (NN thermometer)))))
#           (PP
#             (IN into)
#             (NP
#               (NP (JJ thickest) (NN part))
#               (PP (IN of) (NP (DT the) (NN breast))))))
#         (CC and)
#         (VP
#           (VB return)
#           (S
#             (VP
#               (TO to)
#               (VP
#                 (VB oven,)
#                 (S
#                   (VP
#                     (VBG reducing)
#                     (NP (NN temperature))
#                     (PP (TO to) (NP (CD 350) (NNS degrees)))))))))))
#     (NP (NNP F.))))
# Set thermometer alarm (if available) to 161 degrees F.
# (ROOT
#   (SINV
#     (VP
#       (VB Set)
#       (NP
#         (NN thermometer)
#         (NN alarm)
#         (NN -LRB-if)
#         (NNS available-RRB-))
#       (PP (TO to) (NP (CD 161) (NNS degrees))))
#     (NP (NNP F.))))
# A 14-16 pound bird should require a total of 2-2 1/2 hours of roasting.
# (ROOT
#   (S
#     (NP (DT A) (CD 14-16) (NN pound) (NN bird))
#     (VP
#       (MD should)
#       (VP
#         (VB require)
#         (NP
#           (NP (DT a) (NN total))
#           (PP
#             (IN of)
#             (NP
#               (NP (QP (CD 2-2) (CD 1/2)) (NNS hours))
#               (PP (IN of) (NP (NN roasting.))))))))))
# Let turkey rest, loosely covered for 15 minutes before carving.
# (ROOT
#   (S
#     (VP
#       (VB Let)
#       (NP
#         (NP (NN turkey) (NNS rest,))
#         (VP
#           (ADVP (RB loosely))
#           (VBN covered)
#           (PP
#             (IN for)
#             (NP
#               (NP (CD 15) (NNS minutes))
#               (PP (IN before) (NP (NN carving.))))))))))
# WordNet match:  apple (u'red apple', 1.0)
# WordNet match:  apple (u'red apple', 1.0)
# WordNet match:  water (u'water', 1)
# Ingredients:
# {u'name': u'Salt', u'unit': u'ml', u'quantity': u'237'}
# {u'name': u'Brown sugar', u'unit': u'ml', u'quantity': u'237'}
# {u'name': u'oranges', u'unit': u'', u'quantity': u'2'}
# {u'name': u'lemons', u'unit': u'', u'quantity': u'2'}
# {u'name': u'thyme', u'unit': u'sprigs', u'quantity': u'6'}
# {u'name': u'rosemary', u'unit': u'sprigs', u'quantity': u'4'}
# {u'name': u'turkey', u'unit': u'kg', u'quantity': u'5'}
# {u'name': u'orange', u'unit': u'large', u'quantity': u'1'}
# {u'name': u'unsalted butter', u'unit': u'ml', u'quantity': u'59'}
# {u'name': u'yellow onion', u'unit': u'large', u'quantity': u'1'}
# {u'name': u'celery', u'unit': u'stalk', u'quantity': u'1'}
# {u'name': u'carrot', u'unit': u'large', u'quantity': u'1'}
# {u'name': u'Bay Leaves', u'unit': u'', u'quantity': u'2'}
# {u'name': u'thyme', u'unit': u'sprigs', u'quantity': u'2'}
# {u'name': u'rosemary', u'unit': u'sprigs', u'quantity': u'2'}
# {u'name': u'Sage', u'unit': u'bunch', u'quantity': u'1/2'}
# {u'name': u'parsley', u'unit': u'sprigs ', u'quantity': u'3'}
# {u'name': u'chicken or turkey stock', u'unit': u'ml', u'quantity': u'355'}
# {u'name': u'Vegetable oil', u'unit': u'ml', u'quantity': u'15'}
# {u'name': u'Reserved turkey neck and giblets', u'unit': u'', u'quantity': u'1'}
# {u'name': u'carrot', u'unit': u'large', u'quantity': u'1'}
# {u'name': u'onion', u'unit': u'', u'quantity': u'1'}
# {u'name': u'celery ', u'unit': u'large stalk', u'quantity': u'1'}
# {u'name': u'Bay leaf', u'unit': u'small', u'quantity': u'1'}
# {u'name': u'turkey stock', u'unit': u'ml', u'quantity': u'710'}
# {u'name': u'Water', u'unit': u'ml', u'quantity': u'710'}
# {u'name': u'turkey broth', u'unit': u'ml', u'quantity': u'946'}
# {u'name': u'Dry white wine', u'unit': u'ml', u'quantity': u'237'}
# {u'name': u'unsalted butter', u'unit': u'ml', u'quantity': u'59'}
# {u'name': u'All-purpose flour', u'unit': u'ml', u'quantity': u'59'}
# Instructions:
# For the Brine:
# (ROOT (PP (IN For) (NP (DT the) (NN Brine:))))
# Directions
# (ROOT (NP (NNS Directions)))
# To make the brining solution, dissolve the salt and sugar in 2 gallons of cold water in a nonreactive container (such as a clean bucket or large stockpot, or a clean, heavy-duty, food grade plastic storage bag).
# (ROOT
#   (FRAG
#     (S
#       (VP
#         (TO To)
#         (VP
#           (VB make)
#           (S
#             (NP (DT the) (JJ brining) (NN solution,))
#             (VP
#               (VB dissolve)
#               (NP (DT the) (NN salt) (CC and) (NN sugar))
#               (PP
#                 (IN in)
#                 (NP
#                   (NP (CD 2) (NNS gallons))
#                   (PP
#                     (IN of)
#                     (NP
#                       (NP (JJ cold) (NN water))
#                       (PP
#                         (IN in)
#                         (NP
#                           (NP
#                             (NP
#                               (DT a)
#                               (JJ nonreactive)
#                               (NN container)
#                               (NN -LRB-such))
#                             (PP
#                               (IN as)
#                               (NP
#                                 (NP (DT a) (JJ clean) (NN bucket))
#                                 (CC or)
#                                 (NP (JJ large) (NNS stockpot,)))))
#                           (CC or)
#                           (NP
#                             (NP
#                               (DT a)
#                               (JJ clean,)
#                               (JJ heavy-duty,)
#                               (NN food)
#                               (NN grade))
#                             (NP
#                               (JJ plastic)
#                               (NN storage)
#                               (NNS bag-RRB-.))))))))))))))))
# Add the oranges, lemons, thyme, and rosemary.
# (ROOT
#   (S
#     (VP
#       (VB Add)
#       (NP
#         (DT the)
#         (NNP oranges,)
#         (NNP lemons,)
#         (NNP thyme,)
#         (CC and)
#         (NN rosemary.)))))
# Note: if you have a big turkey and need more brine than this, use 1/2 cup salt and 1/2 cup brown sugar for every gallon of water.
# (ROOT
#   (S
#     (VP
#       (VP
#         (VB Note:)
#         (SBAR
#           (IN if)
#           (S
#             (NP (PRP you))
#             (VP (VBP have) (NP (DT a) (JJ big) (NN turkey))))))
#       (CC and)
#       (VP
#         (VB need)
#         (NP (JJR more) (NN brine))
#         (PP
#           (IN than)
#           (S
#             (VP
#               (VBG this,)
#               (NP
#                 (NP (NN use) (CD 1/2) (NN cup) (NN salt))
#                 (CC and)
#                 (NP (CD 1/2) (NN cup)))))))
#       (NP (JJ brown) (NN sugar))
#       (PP
#         (IN for)
#         (NP
#           (NP (DT every) (NN gallon))
#           (PP (IN of) (NP (NN water.))))))))
# Remove the neck, giblets, and liver from the cavity of the turkey and reserve for the gravy.
# (ROOT
#   (S
#     (VP
#       (VB Remove)
#       (NP (DT the) (JJ neck,) (NN giblets,) (CC and) (NN liver))
#       (PP
#         (IN from)
#         (NP
#           (NP (DT the) (NN cavity))
#           (PP
#             (IN of)
#             (NP
#               (NP (DT the) (NN turkey) (CC and) (NN reserve))
#               (PP (IN for) (NP (DT the) (NN gravy.))))))))))
# Rinse the turkey inside and out under cold running water.
# (ROOT
#   (S
#     (VP
#       (VB Rinse)
#       (NP (DT the) (NN turkey))
#       (ADVP (RB inside) (CC and) (RB out))
#       (PP (IN under) (NP (JJ cold) (JJ running) (NN water.))))))
# Soak the turkey in the brine, covered and refrigerated, for at least 4 hours and up to 24 hours.
# (ROOT
#   (S
#     (VP
#       (VB Soak)
#       (NP
#         (NP (DT the) (NN turkey))
#         (PP
#           (IN in)
#           (NP
#             (NP (DT the) (NN brine,))
#             (VP
#               (VBN covered)
#               (CC and)
#               (VBN refrigerated,)
#               (PP
#                 (IN for)
#                 (NP
#                   (NP (QP (IN at) (JJS least) (CD 4)) (NNS hours))
#                   (CC and)
#                   (NP (QP (IN up) (TO to) (CD 24)) (NN hours.)))))))))))
# Preheat the oven to 325 degrees F.
# (ROOT
#   (SINV
#     (VP
#       (VB Preheat)
#       (NP (DT the) (NN oven))
#       (PP (TO to) (NP (QP (CD 325) (CD degrees)))))
#     (NP (NNP F.))))
# Remove the turkey from the brine and rinse well under cold running water.
# (ROOT
#   (S
#     (VP
#       (VP
#         (VB Remove)
#         (NP (DT the) (NN turkey))
#         (PP (IN from) (NP (DT the) (NN brine))))
#       (CC and)
#       (VP
#         (VB rinse)
#         (ADVP (RB well))
#         (PP (IN under) (NP (JJ cold) (JJ running) (NN water.)))))))
# Pat dry with paper towels both inside and out.
# (ROOT
#   (NP
#     (NP
#       (NP (NNP Pat) (NNP dry))
#       (PP (IN with) (NP (NN paper) (NNS towels))))
#     (NP (DT both) (NN inside) (CC and) (NN out.))))
# Place turkey, breast side up, in a large, heavy roasting pan.
# (ROOT
#   (S
#     (VP
#       (VB Place)
#       (NP
#         (NP (JJ turkey,) (NN breast) (NN side) (NN up,))
#         (PP
#           (IN in)
#           (NP (DT a) (JJ large,) (JJ heavy) (NN roasting) (NN pan.)))))))
# Rub breast side with orange segments and rub on all sides with the butter, stuffing some underneath the skin.
# (ROOT
#   (S
#     (VP
#       (VP
#         (VB Rub)
#         (NP (NN breast) (NN side))
#         (PP (IN with) (NP (JJ orange) (NNS segments))))
#       (CC and)
#       (VP
#         (VB rub)
#         (PP (IN on) (NP (DT all) (NNS sides)))
#         (PP
#           (IN with)
#           (NP
#             (NP (DT the) (NN butter,))
#             (VP
#               (VBG stuffing)
#               (NP
#                 (NP (DT some))
#                 (PP (IN underneath) (NP (DT the) (NN skin.)))))))))))
# Season lightly inside and out with salt and pepper.
# (ROOT
#   (S
#     (VP
#       (VB Season)
#       (ADVP (RB lightly))
#       (PP
#         (IN inside)
#         (CC and)
#         (IN out)
#         (PP (IN with) (NP (NN salt) (CC and) (NN pepper.)))))))
# Stuff the turkey with the onion, remaining orange, celery, carrot, bay leaves, thyme, rosemary, sage and parsley.
# (ROOT
#   (S
#     (VP
#       (VB Stuff)
#       (NP (DT the) (NN turkey))
#       (PP
#         (IN with)
#         (NP
#           (NP
#             (DT the)
#             (JJ onion,)
#             (VBG remaining)
#             (JJ orange,)
#             (JJ celery,)
#             (VBG carrot,)
#             (NN bay)
#             (NNP leaves,)
#             (NNP thyme,)
#             (NNP rosemary,)
#             (NNP sage))
#           (CC and)
#           (NP (NN parsley.)))))))
# Loosely tie the drumsticks together with kitchen string.
# (ROOT
#   (S
#     (ADVP (RB Loosely))
#     (VP
#       (VB tie)
#       (NP (DT the) (NNS drumsticks))
#       (ADVP (RB together))
#       (PP (IN with) (NP (NN kitchen) (NN string.))))))
# Roast the turkey, uncovered, breast side down for 1 hour.
# (ROOT
#   (S
#     (VP
#       (VB Roast)
#       (NP
#         (DT the)
#         (JJ turkey,)
#         (JJ uncovered,)
#         (NN breast)
#         (NN side))
#       (ADVP (RB down) (PP (IN for) (NP (CD 1) (NN hour.)))))))
# Remove from the oven, turn, and baste with 1/2 cup stock.
# (ROOT
#   (S
#     (VP
#       (VP
#         (VB Remove)
#         (PP (IN from) (NP (DT the) (JJ oven,) (NN turn,))))
#       (CC and)
#       (VP
#         (VB baste)
#         (PP (IN with) (NP (CD 1/2) (NN cup) (NN stock.)))))))
# Continue roasting with the breast side up until an instant-read meat thermometer registers 165 degrees F when inserted into the largest section of thigh (avoiding the bone), about 2 3/4 to 3 hours total cooking time.
# (ROOT
#   (SINV
#     (VP
#       (ADVP (RB Continue))
#       (VBG roasting)
#       (PP (IN with) (NP (DT the) (NN breast) (NN side))))
#     (VP
#       (ADVP
#         (RB up)
#         (PP
#           (IN until)
#           (NP (DT an) (JJ instant-read) (NN meat) (NN thermometer))))
#       (VBZ registers)
#       (NP (CD 165) (NNS degrees)))
#     (NP
#       (NN F)
#       (SBAR
#         (WHADVP (WRB when))
#         (S
#           (S
#             (VP
#               (VBN inserted)
#               (PP
#                 (IN into)
#                 (NP
#                   (NP (DT the) (JJS largest) (NN section))
#                   (PP (IN of) (NP (NN thigh) (NN -LRB-avoiding)))))
#               (NP
#                 (DT the)
#                 (JJ bone-RRB-,)
#                 (QP (RB about) (CD 2) (CD 3/4) (TO to) (CD 3))
#                 (NNS hours))))
#           (VP (VBP total) (NP (JJ cooking) (NN time.))))))))
# Baste the turkey once every hour with 1/2 to 3/4 cup chicken or turkey stock.
# (ROOT
#   (S
#     (VP
#       (VB Baste)
#       (NP (DT the) (NN turkey))
#       (ADVP (RB once) (NP (DT every) (NN hour)))
#       (PP
#         (IN with)
#         (NP
#           (NP (QP (CD 1/2) (TO to) (CD 3/4)) (NN cup) (NN chicken))
#           (CC or)
#           (NP (NN turkey) (NN stock.)))))))
# Remove from the oven and place on a platter.
# (ROOT
#   (S
#     (VP
#       (VB Remove)
#       (PP
#         (IN from)
#         (NP
#           (NP (DT the) (NN oven) (CC and) (NN place))
#           (PP (IN on) (NP (DT a) (NN platter.))))))))
# Tent with aluminum foil and let rest for 20 minutes before carving.
# (ROOT
#   (S
#     (VP
#       (VP (VB Tent) (PP (IN with) (NP (NN aluminum) (NN foil))))
#       (CC and)
#       (VP
#         (VB let)
#         (NP (NP (NN rest)) (PP (IN for) (NP (CD 20) (NNS minutes))))
#         (PP (IN before) (NP (NN carving.)))))))
# For the turkey broth:
# (ROOT (PP (IN For) (NP (DT the) (NN turkey) (NN broth:))))
# Heat the oil in a large heavy saucepan over medium-high heat.
# (ROOT
#   (NP
#     (NP (NNP Heat))
#     (NP
#       (NP (DT the) (NN oil))
#       (PP
#         (IN in)
#         (NP
#           (NP (DT a) (JJ large) (JJ heavy) (NN saucepan))
#           (PP (IN over) (NP (JJ medium-high) (NN heat.))))))))
# Add the turkey neck, heart, and gizzard to the pan and saute until just beginning to brown, about 1 minute.
# (ROOT
#   (S
#     (VP
#       (VP
#         (VB Add)
#         (NP
#           (NP (DT the) (NN turkey) (NN neck,))
#           (ADJP (JJ heart,) (CC and) (JJ gizzard)))
#         (PP (TO to) (NP (DT the) (NN pan))))
#       (CC and)
#       (VP
#         (VB saute)
#         (PP
#           (IN until)
#           (S
#             (ADVP (RB just))
#             (VP
#               (VBG beginning)
#               (S
#                 (VP
#                   (TO to)
#                   (VP
#                     (VB brown,)
#                     (NP (QP (RB about) (CD 1)) (NN minute.))))))))))))
# Add the chopped vegetables and bay leaf to the pan and saute until soft, about 2 minutes.
# (ROOT
#   (S
#     (VP
#       (VP
#         (VB Add)
#         (NP
#           (NP
#             (DT the)
#             (JJ chopped)
#             (NNS vegetables)
#             (CC and)
#             (NN bay)
#             (NN leaf))
#           (PP (TO to) (NP (DT the) (NN pan)))))
#       (CC and)
#       (VP
#         (VB saute)
#         (PP
#           (IN until)
#           (S
#             (VP
#               (VBG soft,)
#               (NP (QP (RB about) (CD 2)) (NN minutes.)))))))))
# Pour the stock and 3 cups of water into the pan and bring to a boil.
# (ROOT
#   (S
#     (VP
#       (VP
#         (VB Pour)
#         (NP
#           (NP (DT the) (NN stock))
#           (CC and)
#           (NP (NP (CD 3) (NNS cups)) (PP (IN of) (NP (NN water)))))
#         (PP (IN into) (NP (DT the) (NN pan))))
#       (CC and)
#       (VP (VB bring) (PP (TO to) (NP (DT a) (NN boil.)))))))
# Lower the heat to medium-low and simmer until the stock is reduced to 4 cups, about 1 hour, adding the chopped liver to the pan during the last 15 minutes of cooking.
# (ROOT
#   (SINV
#     (VP
#       (VBD Lower)
#       (NP (DT the) (NN heat))
#       (PP (TO to) (NP (NN medium-low) (CC and) (NN simmer)))
#       (SBAR
#         (IN until)
#         (S
#           (NP (DT the) (NN stock))
#           (VP
#             (VBZ is)
#             (VP
#               (VBN reduced)
#               (PP (TO to) (NP (QP (CD 4) (CD cups,)))))))))
#     (NP
#       (NP (QP (RB about) (CD 1)) (NNS hour,))
#       (VP
#         (VBG adding)
#         (NP (DT the) (JJ chopped) (NN liver))
#         (PP (TO to) (NP (DT the) (NN pan)))
#         (PP
#           (IN during)
#           (NP
#             (NP (DT the) (JJ last) (CD 15) (NNS minutes))
#             (PP (IN of) (NP (NN cooking.)))))))))
# Strain the stock into a clean pot or large measuring cup.
# (ROOT
#   (S
#     (VP
#       (VB Strain)
#       (NP (DT the) (NN stock))
#       (PP
#         (IN into)
#         (NP
#           (NP (DT a) (JJ clean) (NN pot))
#           (CC or)
#           (NP (JJ large) (NN measuring) (NN cup.)))))))
# Pull the meat off the neck, chop the neck meat and giblets, and set aside.
# (ROOT
#   (S
#     (VP
#       (VB Pull)
#       (NP (DT the) (NN meat))
#       (ADVP (RB off) (NP (DT the) (NN neck,)))
#       (VP
#         (VP (VB chop) (NP (DT the) (NN neck) (NN meat)))
#         (CC and)
#         (VP (VB giblets,) (CC and) (VB set) (NP (NN aside.)))))))
# For the pan gravy:
# (ROOT (PP (IN For) (NP (DT the) (JJ pan) (NN gravy:))))
# Pour the reserved turkey pan juices into a glass-measuring cup and skim off the fat.
# (ROOT
#   (S
#     (VP
#       (VB Pour)
#       (S
#         (NP (DT the) (JJ reserved) (NN turkey))
#         (VP
#           (VP
#             (VB pan)
#             (NP (NNS juices))
#             (PP (IN into) (NP (DT a) (JJ glass-measuring) (NN cup))))
#           (CC and)
#           (VP (VB skim) (PRT (RP off)) (NP (DT the) (NN fat.))))))))
# Place the roasting pan on 2 stovetop burners over medium heat add the pan juice and 1 cup turkey broth and the white wine to the pan, and deglaze the pan, stirring to scrape any brown bits from the bottom of the pan.
# (ROOT
#   (S
#     (VP
#       (VB Place)
#       (S
#         (NP
#           (NP (DT the) (VBG roasting) (NN pan))
#           (PP
#             (IN on)
#             (NP
#               (NP (CD 2) (NN stovetop) (NNS burners))
#               (PP (IN over) (NP (NN medium) (NN heat))))))
#         (VP
#           (VP
#             (VB add)
#             (NP
#               (NP
#                 (NP (DT the) (JJ pan) (NN juice))
#                 (CC and)
#                 (NP (CD 1) (NN cup) (NN turkey) (NN broth)))
#               (CC and)
#               (NP
#                 (NP (DT the) (JJ white) (NN wine))
#                 (PP (TO to) (NP (DT the) (NN pan,))))))
#           (CC and)
#           (VP
#             (VB deglaze)
#             (NP
#               (NP (DT the) (NN pan,))
#               (VP
#                 (VBG stirring)
#                 (S
#                   (VP
#                     (TO to)
#                     (VP
#                       (VB scrape)
#                       (NP (DT any) (JJ brown) (NNS bits))
#                       (PP
#                         (IN from)
#                         (NP
#                           (NP (DT the) (NN bottom))
#                           (PP (IN of) (NP (DT the) (NN pan.))))))))))))))))
# Add the remaining 3 cup of broth and bring to a simmer, then transfer to a measuring cup.
# (ROOT
#   (S
#     (VP
#       (VP
#         (VB Add)
#         (NP
#           (NP (DT the) (JJ remaining) (CD 3) (NN cup))
#           (PP (IN of) (NP (NN broth)))))
#       (CC and)
#       (VP
#         (VB bring)
#         (S
#           (VP
#             (TO to)
#             (VP
#               (ADVP (NP (DT a) (NN simmer,)) (RB then))
#               (VB transfer)
#               (PP (TO to) (NP (DT a) (NN measuring) (NN cup.))))))))))
# In a large heavy saucepan, melt the butter over medium high heat.
# (ROOT
#   (FRAG
#     (PP
#       (IN In)
#       (NP (DT a) (JJ large) (JJ heavy) (NN saucepan,) (NN melt)))
#     (NP
#       (NP (DT the) (NN butter))
#       (PP (IN over) (NP (JJ medium) (JJ high) (NN heat.))))))
# Stir in the flour and cook, stirring constantly, to make a light roux.
# (ROOT
#   (S
#     (VP
#       (VB Stir)
#       (PP
#         (IN in)
#         (NP
#           (NP (DT the) (NN flour))
#           (CC and)
#           (NP (NNP cook,) (NNP stirring) (NNP constantly,))))
#       (S
#         (VP (TO to) (VP (VB make) (NP (DT a) (JJ light) (NN roux.))))))))
# Add the hot stock, whisking constantly, then simmer until thickened, about 10 minutes.
# (ROOT
#   (S
#     (VP
#       (VB Add)
#       (NP
#         (DT the)
#         (JJ hot)
#         (JJ stock,)
#         (NN whisking)
#         (NN constantly,))
#       (RB then)
#       (VP
#         (VB simmer)
#         (PP
#           (IN until)
#           (S
#             (VP
#               (VBG thickened,)
#               (NP (QP (RB about) (CD 10)) (NN minutes.)))))))))
# Add the reserved neck meat and giblets to the pan and adjust seasoning, to taste, with salt and black pepper.
# (ROOT
#   (S
#     (VP
#       (VP
#         (VB Add)
#         (NP
#           (DT the)
#           (JJ reserved)
#           (NN neck)
#           (NN meat)
#           (CC and)
#           (NNS giblets))
#         (PP (TO to) (NP (DT the) (NN pan))))
#       (CC and)
#       (VP
#         (VB adjust)
#         (NP (QP (CD seasoning,) (TO to) (CD taste,)))
#         (PP
#           (IN with)
#           (NP (NP (NN salt)) (CC and) (NP (JJ black) (NN pepper.))))))))
# Pour into a gravy boat and serve.
# (ROOT
#   (S
#     (VP
#       (VB Pour)
#       (PP
#         (IN into)
#         (NP
#           (NP (DT a) (NN gravy) (NN boat))
#           (CC and)
#           (NP (NN serve.)))))))
# Have a great holiday!
# (ROOT (S (VP (VB Have) (NP (DT a) (JJ great) (NN holiday!)))))
# Slice and serve guests with desired sides.
# (ROOT
#   (S
#     (VP
#       (VP (VB Slice))
#       (CC and)
#       (VP
#         (VB serve)
#         (NP (NNS guests))
#         (PP (IN with) (NP (VBN desired) (NN sides.)))))))
# WordNet match:  orange (u'oranges', 1)
# WordNet match:  brown_sugar (u'brown sugar', 1)
# WordNet match:  water (u'water', 1)
# WordNet match:  turkey (u'turkey', 1)
# WordNet match:  turkey (u'turkey', 1)
# WordNet match:  turkey (u'turkey', 1)
# WordNet match:  turkey (u'turkey', 1)
# WordNet match:  turkey (u'turkey', 1)
# WordNet match:  turkey (u'turkey', 1)
# WordNet match:  breast_side (u'turkey stock', 0.9333333333333333)
# WordNet match:  all_side (u'turkey stock', 0.9333333333333333)
# WordNet match:  butter (u'unsalted butter', 1.0)
# WordNet match:  butter (u'unsalted butter', 1.0)
# WordNet match:  breast_side (u'turkey stock', 0.9333333333333333)
# WordNet match:  all_side (u'turkey stock', 0.9333333333333333)
# WordNet match:  butter (u'unsalted butter', 1.0)
# WordNet match:  butter (u'unsalted butter', 1.0)
# WordNet match:  turkey (u'turkey', 1)
# WordNet match:  onion (u'yellow onion', 1.0)
# WordNet match:  onion (u'yellow onion', 1.0)
# WordNet match:  parsley (u'parsley', 1)
# WordNet match:  turkey (u'turkey', 1)
# WordNet match:  breast_side (u'turkey stock', 0.9333333333333333)
# WordNet match:  turkey (u'turkey', 1)
# WordNet match:  turkey_stock (u'turkey stock', 1)
# WordNet match:  stock (u'turkey stock', 1.0)
# WordNet match:  water (u'water', 1)
# WordNet match:  stock (u'turkey stock', 1.0)
# WordNet match:  water (u'water', 1)
# WordNet match:  stock (u'turkey stock', 1.0)
# WordNet match:  stock (u'turkey stock', 1.0)
# WordNet match:  reserved_turkey (u'turkey', 1.0)
# WordNet match:  fat (u'vegetable oil', 0.9230769230769231)
# WordNet match:  fat (u'vegetable oil', 0.9230769230769231)
# WordNet match:  fat (u'vegetable oil', 0.9230769230769231)
# WordNet match:  white_wine (u'dry white wine', 1.0)
# WordNet match:  white_wine (u'dry white wine', 1.0)
# WordNet match:  white_wine (u'dry white wine', 1.0)
# WordNet match:  broth (u'turkey stock', 1.0)
# WordNet match:  broth (u'turkey stock', 1.0)
# WordNet match:  flour (u'all-purpose flour', 1.0)
# WordNet match:  hot_stock (u'turkey stock', 0.9333333333333333)
# WordNet match:  seasoning (u'salt', 0.9411764705882353)
# WordNet match:  salt (u'salt', 1)
# WordNet match:  seasoning (u'salt', 0.9411764705882353)
# WordNet match:  salt (u'salt', 1)
# WordNet match:  desired_side (u'turkey stock', 0.9333333333333333)
# WordNet match:  desired_side (u'turkey stock', 0.9333333333333333)
# Ingredients:
# {u'name': u'Water', u'unit': u'l', u'quantity': u'2'}
# {u'name': u'Salt', u'unit': u'g', u'quantity': u'28'}
# {u'name': u'Miso', u'unit': u'ml', u'quantity': u'118'}
# {u'name': u'Mirin', u'unit': u'ml', u'quantity': u'118'}
# {u'name': u'Soy', u'unit': u'ml', u'quantity': u'118'}
# {u'name': u'Rice vinegar', u'unit': u'ml', u'quantity': u'118'}
# {u'name': u'Multi-colored fingerling potatoes', u'unit': u'kg', u'quantity': u'0.91'}
# {u'name': u'Snap peas', u'unit': u'ml', u'quantity': u'473'}
# {u'name': u'Carrot', u'unit': u'ml', u'quantity': u'355'}
# {u'name': u'Scallions', u'unit': u'each', u'quantity': u'3'}
# {u'name': u'Cilantro', u'unit': u'ml', u'quantity': u'44'}
# {u'name': u'Vinaigrette', u'unit': u'ml', u'quantity': u'118'}
# {u'name': u'Miso', u'unit': u'ml', u'quantity': u'15'}
# {u'name': u'Rice wine vinegar', u'unit': u'ml', u'quantity': u'15'}
# {u'name': u'Soy sauce', u'unit': u'ml', u'quantity': u'15'}
# {u'name': u'Mirin', u'unit': u'ml', u'quantity': u'15'}
# {u'name': u'Sesame oil', u'unit': u'ml', u'quantity': u'15'}
# {u'name': u'Yellow mustard seeds', u'unit': u'ml', u'quantity': u'237'}
# {u'name': u'Mirin', u'unit': u'ml', u'quantity': u'118'}
# {u'name': u'Rice wine vinegar', u'unit': u'ml', u'quantity': u'355'}
# {u'name': u'Sugar', u'unit': u'ml', u'quantity': u'118'}
# {u'name': u'Salt', u'unit': u'ml', u'quantity': u'15'}
# {u'name': u'Soy', u'unit': u'ml', u'quantity': u'30'}
# {u'name': u'Pickling spice', u'unit': u'ml', u'quantity': u'2'}
# {u'name': u'Tumeric', u'unit': u'pinch', u'quantity': u'1'}
# {u'name': u'Star anise', u'unit': u'points', u'quantity': u'3'}
# Instructions:
# Combine all ingredients listed under potatoes in a heavy-bottomed pot and bring to a gentle simmer.
# (ROOT
#   (S
#     (VP
#       (VP
#         (VB Combine)
#         (NP
#           (NP (DT all) (NNS ingredients))
#           (VP
#             (VBN listed)
#             (PP
#               (IN under)
#               (NP
#                 (NP (NNS potatoes))
#                 (PP (IN in) (NP (DT a) (JJ heavy-bottomed) (NN pot))))))))
#       (CC and)
#       (VP
#         (VB bring)
#         (PP (TO to) (NP (DT a) (JJ gentle) (NN simmer.)))))))
# Once it reaches a simmer, turn down the heat until there are just very small bubbles in the pot and cook until the potatoes are tender.
# (ROOT
#   (SBAR
#     (IN Once)
#     (S
#       (NP (PRP it))
#       (VP
#         (VBZ reaches)
#         (S
#           (NP (DT a) (NN simmer,))
#           (VP
#             (VP
#               (VB turn)
#               (PRT (RP down))
#               (NP (DT the) (NN heat))
#               (SBAR
#                 (IN until)
#                 (S
#                   (NP (EX there))
#                   (VP
#                     (VBP are)
#                     (ADVP (RB just))
#                     (NP
#                       (NP (ADJP (RB very) (JJ small)) (NNS bubbles))
#                       (PP (IN in) (NP (DT the) (NN pot))))))))
#             (CC and)
#             (VP
#               (VB cook)
#               (SBAR
#                 (IN until)
#                 (S
#                   (NP (DT the) (NNS potatoes))
#                   (VP (VBP are) (ADJP (JJ tender.))))))))))))
# Cool the potatoes in their cooking liquid in a shallow pan.
# (ROOT
#   (S
#     (VP
#       (VB Cool)
#       (NP (DT the) (NNS potatoes))
#       (PP
#         (IN in)
#         (NP
#           (NP (PRP$ their) (JJ cooking) (NN liquid))
#           (PP (IN in) (NP (DT a) (JJ shallow) (NN pan.))))))))
# Once cool, cut the potatoes in half lengthwise.
# (ROOT
#   (SBAR
#     (IN Once)
#     (S
#       (NP (NNP cool,))
#       (VP
#         (VBD cut)
#         (NP (DT the) (NNS potatoes))
#         (PP (IN in) (NP (DT half) (NN lengthwise.)))))))
# The cooking liquid can be used again for the same purpose and so should be reserved.
# (ROOT
#   (S
#     (NP (DT The) (JJ cooking) (NN liquid))
#     (VP
#       (VP
#         (MD can)
#         (VP
#           (VB be)
#           (VP
#             (VBN used)
#             (ADVP (RB again))
#             (PP (IN for) (NP (DT the) (JJ same) (NN purpose))))))
#       (CC and)
#       (VP
#         (ADVP (RB so))
#         (MD should)
#         (VP (VB be) (ADJP (JJ reserved.)))))))
# For the dressing: Create an Asian flavor base from miso, vinegar, mirin, and sesame oil and add this to your vinaigrette.
# (ROOT
#   (PP
#     (IN For)
#     (NP
#       (DT the)
#       (NN dressing:)
#       (S
#         (VP
#           (VP
#             (VB Create)
#             (NP (DT an) (JJ Asian) (NN flavor) (NN base))
#             (PP
#               (IN from)
#               (NP
#                 (NP (NNP miso,) (NNP vinegar,) (NNP mirin,))
#                 (CC and)
#                 (NP (JJ sesame) (NN oil)))))
#           (CC and)
#           (VP
#             (VB add)
#             (NP (DT this))
#             (PP (TO to) (NP (PRP$ your) (NN vinaigrette.)))))))))
# Taste the dressing and adjust the seasoning as needed
# (ROOT
#   (S
#     (VP
#       (VP (VB Taste) (NP (DT the) (NN dressing)))
#       (CC and)
#       (VP
#         (VB adjust)
#         (NP (NP (DT the) (NN seasoning)) (ADJP (RB as) (VBN needed)))))))
# Mix the potatoes with the carrots and snap peas, and dress with the Asian vinaigrette.
# (ROOT
#   (S
#     (VP
#       (VP
#         (VB Mix)
#         (NP (DT the) (NNS potatoes))
#         (PP
#           (IN with)
#           (NP (DT the) (NNS carrots) (CC and) (NN snap) (NNS peas,))))
#       (CC and)
#       (VP
#         (VB dress)
#         (PP (IN with) (NP (DT the) (JJ Asian) (NN vinaigrette.)))))))
# Season to taste and garnish with your favorite Asian garnishes as listed in the ingredients
# (ROOT
#   (FRAG
#     (NP (NN Season))
#     (S
#       (VP
#         (TO to)
#         (VP
#           (VB taste)
#           (CC and)
#           (VB garnish)
#           (PP
#             (IN with)
#             (NP (PRP$ your) (JJ favorite) (JJ Asian) (NNS garnishes)))
#           (SBAR
#             (IN as)
#             (S
#               (VP
#                 (VBN listed)
#                 (PP (IN in) (NP (DT the) (NNS ingredients)))))))))))
# Pickled Mustard Seeds
# (ROOT (NP (NNP Pickled) (NNP Mustard) (NNPS Seeds)))
# In a small heavy sauce pan cover the mustard seeds with water and bring to a boil.
# (ROOT
#   (PP
#     (IN In)
#     (NP
#       (NP (DT a) (JJ small) (JJ heavy) (NN sauce))
#       (VP
#         (VBN pan)
#         (S
#           (VP
#             (VP
#               (VB cover)
#               (NP (DT the) (NN mustard) (NNS seeds))
#               (PP (IN with) (NP (NN water))))
#             (CC and)
#             (VP (VB bring) (PP (TO to) (NP (DT a) (NN boil.))))))))))
# Drain the water and rinse the mustard seeds.
# (ROOT
#   (S
#     (VP
#       (VP (VB Drain) (NP (DT the) (NN water)))
#       (CC and)
#       (VP (VB rinse) (NP (DT the) (NN mustard) (NN seeds.))))))
# Repeat the blanching a second time.
# (ROOT
#   (NP
#     (NP (NN Repeat))
#     (NP (DT the) (NN blanching))
#     (NP (DT a) (JJ second) (NN time.))))
# Drain the water, rinse the mustard seeds and add the vinegar, sugar, salt, soy sauce, and spices in a small heavy saucepan with the blanched mustard seeds and bring to a gentle simmer over low heat.
# (ROOT
#   (S
#     (VP
#       (VB Drain)
#       (S
#         (NP (DT the) (NN water,))
#         (VP
#           (VP (VB rinse) (NP (DT the) (NN mustard) (NNS seeds)))
#           (CC and)
#           (VP
#             (VB add)
#             (NP
#               (DT the)
#               (JJ vinegar,)
#               (CD sugar,)
#               (JJ salt,)
#               (NN soy)
#               (NNS sauce,)
#               (CC and)
#               (NNS spices))
#             (PP
#               (IN in)
#               (NP
#                 (NP (DT a) (JJ small) (JJ heavy) (NN saucepan))
#                 (PP
#                   (IN with)
#                   (NP
#                     (DT the)
#                     (JJ blanched)
#                     (NN mustard)
#                     (NNS seeds))))))
#           (CC and)
#           (VP
#             (VB bring)
#             (PP
#               (TO to)
#               (NP
#                 (NP (DT a) (JJ gentle) (NN simmer))
#                 (PP (IN over) (NP (JJ low) (NN heat.)))))))))))
# Cook, stirring often, until the mustard seeds are plump and tender, about 15 to 20 minutes.
# (ROOT
#   (S
#     (NP (NNP Cook,) (NNP stirring))
#     (VP
#       (VBZ often,)
#       (SBAR
#         (IN until)
#         (S
#           (NP (DT the) (NN mustard) (NNS seeds))
#           (VP
#             (VBP are)
#             (NP
#               (NP (NN plump) (CC and) (NN tender,))
#               (PP
#                 (IN about)
#                 (NP (QP (CD 15) (TO to) (CD 20)) (NN minutes.))))))))))
# The liquid will be nearly absorbed, but the seeds will remain moist in very little thick viscous broth.
# (ROOT
#   (S
#     (NP (DT The) (NN liquid))
#     (VP
#       (MD will)
#       (VP
#         (VB be)
#         (ADJP (RB nearly) (JJ absorbed,))
#         (SBAR
#           (CC but)
#           (S
#             (NP (DT the) (NNS seeds))
#             (VP
#               (MD will)
#               (VP
#                 (VB remain)
#                 (NP
#                   (ADJP
#                     (JJ moist)
#                     (PP
#                       (IN in)
#                       (NP
#                         (ADJP (RB very) (RB little) (JJ thick))
#                         (NNS viscous))))
#                   (NN broth.))))))))))
# Cool the seeds in their liquid and refrigerate in a covered container.
# (ROOT
#   (S
#     (VP
#       (VP
#         (VB Cool)
#         (NP (DT the) (NNS seeds))
#         (PP (IN in) (NP (PRP$ their) (NN liquid))))
#       (CC and)
#       (VP
#         (VB refrigerate)
#         (PP (IN in) (NP (DT a) (VBN covered) (NN container.)))))))
# It will keep for months.
# (ROOT
#   (S
#     (NP (PRP It))
#     (VP (MD will) (VP (VB keep) (PP (IN for) (NP (NN months.)))))))
# WordNet match:  miso (u'miso', 1)
# WordNet match:  miso (u'miso', 1)
# WordNet match:  sesame_oil (u'sesame oil', 1)
# WordNet match:  your_vinaigrette (u'vinaigrette', 1.0)
# WordNet match:  miso (u'miso', 1)
# WordNet match:  miso (u'miso', 1)
# WordNet match:  sesame_oil (u'sesame oil', 1)
# WordNet match:  your_vinaigrette (u'vinaigrette', 1.0)
# WordNet match:  dressing (u'vinaigrette', 0.9565217391304348)
# WordNet match:  seasoning (u'salt', 0.9411764705882353)
# WordNet match:  dressing (u'vinaigrette', 0.9565217391304348)
# WordNet match:  seasoning (u'salt', 0.9411764705882353)
# WordNet match:  Asian_vinaigrette (u'vinaigrette', 1.0)
# WordNet match:  Asian_vinaigrette (u'vinaigrette', 1.0)
# WordNet match:  mustard_seed (u'yellow mustard seeds', 1.0)
# WordNet match:  water (u'water', 1)
# WordNet match:  mustard_seed (u'yellow mustard seeds', 1.0)
# WordNet match:  water (u'water', 1)
# WordNet match:  mustard_seed (u'yellow mustard seeds', 1.0)
# WordNet match:  water (u'water', 1)
# WordNet match:  water (u'water', 1)
# WordNet match:  mustard_seed (u'yellow mustard seeds', 1.0)
# WordNet match:  water (u'water', 1)
# WordNet match:  mustard_seed (u'yellow mustard seeds', 1.0)
# WordNet match:  water (u'water', 1)
# WordNet match:  mustard_seed (u'yellow mustard seeds', 1.0)
# WordNet match:  vinegar (u'rice vinegar', 1.0)
# WordNet match:  blanched_mustard_seed (u'yellow mustard seeds', 1.0)
# WordNet match:  mustard_seed (u'yellow mustard seeds', 1.0)
# WordNet match:  vinegar (u'rice vinegar', 1.0)
# WordNet match:  blanched_mustard_seed (u'yellow mustard seeds', 1.0)
# WordNet match:  mustard_seed (u'yellow mustard seeds', 1.0)
# WordNet match:  vinegar (u'rice vinegar', 1.0)
# WordNet match:  blanched_mustard_seed (u'yellow mustard seeds', 1.0)
# WordNet match:  mustard_seed (u'yellow mustard seeds', 1.0)
# WordNet match:  seed (u'soy', 0.9090909090909091)
# WordNet match:  seed (u'soy', 0.9090909090909091)
# WordNet match:  seed (u'soy', 0.9090909090909091)
# WordNet match:  their_liquid (u'water', 0.9333333333333333)
# WordNet match:  seed (u'soy', 0.9090909090909091)
# WordNet match:  their_liquid (u'water', 0.9333333333333333)
# Ingredients:
# {u'name': u'Bell peppers', u'unit': u'', u'quantity': u'4'}
# {u'name': u'Olive oil', u'unit': u'ml', u'quantity': u'4'}
# {u'name': u'Salt', u'unit': u'ml', u'quantity': u'2'}
# {u'name': u'Potatoes', u'unit': u'large', u'quantity': u'3'}
# {u'name': u'Yellow onion ', u'unit': u'', u'quantity': u'1'}
# {u'name': u'Ground black pepper ', u'unit': u'ml', u'quantity': u'5'}
# {u'name': u'Olive oil', u'unit': u'ml', u'quantity': u'15'}
# {u'name': u"Breakstone's Sour-Cream", u'unit': u'ml', u'quantity': u'5'}
# Instructions:
# Preheat the oven on 375 degrees Fahrenheit.
# (ROOT
#   (SINV
#     (VP
#       (VB Preheat)
#       (NP (DT the) (NN oven))
#       (PP (IN on) (NP (CD 375) (NNS degrees))))
#     (NP (NNP Fahrenheit.))))
# Wash peppers and cut in the halves; Take all the seeds out.
# (ROOT
#   (S
#     (NP (NNP Wash))
#     (VP
#       (VP (VBZ peppers))
#       (CC and)
#       (VP
#         (VBD cut)
#         (PP (IN in) (NP (DT the) (NN halves;)))
#         (S
#           (VP
#             (VB Take)
#             (NP (PDT all) (DT the) (NNS seeds))
#             (NP (NN out.))))))))
# Sprinkle with bit of salt and just lightly spray or oil them.
# (ROOT
#   (S
#     (VP
#       (VB Sprinkle)
#       (PP
#         (IN with)
#         (NP
#           (NP (NN bit))
#           (PP
#             (IN of)
#             (NP
#               (NP (NN salt))
#               (CC and)
#               (NP
#                 (RB just)
#                 (NN lightly)
#                 (NN spray)
#                 (CC or)
#                 (NN oil)
#                 (NN them.)))))))))
# Place in the oven and bake for 10 minutes or until you are finished with a filling.
# (ROOT
#   (S
#     (VP
#       (VP (VB Place) (PP (IN in) (NP (DT the) (NN oven))))
#       (CC and)
#       (VP
#         (VB bake)
#         (UCP
#           (PP (IN for) (NP (CD 10) (NNS minutes)))
#           (CC or)
#           (SBAR
#             (IN until)
#             (S
#               (NP (PRP you))
#               (VP
#                 (VBP are)
#                 (VP
#                   (VBN finished)
#                   (PP (IN with) (NP (DT a) (NN filling.))))))))))))
# Meanwhile peel and shred the potatoes, and onion.
# (ROOT
#   (S
#     (VP
#       (ADVP (RB Meanwhile))
#       (VB peel)
#       (CC and)
#       (VB shred)
#       (NP (DT the) (NN potatoes,) (CC and) (NN onion.)))))
# Add salt to taste, ground black pepper, and chili peppers and oil.
# (ROOT
#   (S
#     (VP
#       (VB Add)
#       (NP (NN salt))
#       (PP
#         (TO to)
#         (NP
#           (JJ taste,)
#           (NN ground)
#           (JJ black)
#           (NN pepper,)
#           (CC and)
#           (JJ chili)
#           (NNS peppers)
#           (CC and)
#           (NN oil.))))))
# Mix the filling until all combined.
# (ROOT
#   (S
#     (VP
#       (VB Mix)
#       (NP (DT the) (NN filling))
#       (PP (IN until) (NP (DT all) (NN combined.))))))
# Take the peppers out of the oven and stuff them with the filling mixture until each half is full.
# (ROOT
#   (S
#     (VP
#       (VP
#         (VB Take)
#         (NP (DT the) (NNS peppers))
#         (PRT (RP out))
#         (PP (IN of) (NP (DT the) (NN oven))))
#       (CC and)
#       (VP
#         (VBP stuff)
#         (NP (PRP them))
#         (PP (IN with) (NP (DT the) (NN filling) (NN mixture)))
#         (SBAR
#           (IN until)
#           (S
#             (NP (DT each) (NN half))
#             (VP (VBZ is) (ADJP (JJ full.)))))))))
# Once you done stuffing all the peppers, cover the baking pan with a aluminum foil for the first 15 minutes then remove the alum.
# (ROOT
#   (SBAR
#     (IN Once)
#     (S
#       (NP (PRP you))
#       (VP
#         (VBN done)
#         (S
#           (VP
#             (VBG stuffing)
#             (S
#               (NP (PDT all) (DT the) (NN peppers,))
#               (VP
#                 (VB cover)
#                 (NP
#                   (NP (DT the) (JJ baking) (NN pan))
#                   (PP
#                     (IN with)
#                     (NP
#                       (NP (DT a) (NN aluminum) (NN foil))
#                       (PP
#                         (IN for)
#                         (NP
#                           (DT the)
#                           (JJ first)
#                           (CD 15)
#                           (NNS minutes))))))
#                 (ADVP (RB then))
#                 (VP (VB remove) (NP (DT the) (NN alum.)))))))))))
# foil and continue baking uncovered on 375 degrees for 40 minutes or until potatoes are done.
# (ROOT
#   (S
#     (VP
#       (VP (VB foil))
#       (CC and)
#       (VP
#         (VB continue)
#         (S
#           (VP
#             (VBG baking)
#             (SBAR
#               (SBAR
#                 (S
#                   (VP
#                     (VBN uncovered)
#                     (PP
#                       (IN on)
#                       (NP
#                         (NP (CD 375) (NNS degrees))
#                         (PP (IN for) (NP (CD 40) (NNS minutes))))))))
#               (CC or)
#               (SBAR
#                 (IN until)
#                 (S
#                   (NP (NNS potatoes))
#                   (VP (VBP are) (ADJP (JJ done.))))))))))))
# Serve immediately!
# (ROOT (NP (NNP Serve) (NNP immediately!)))
# WordNet match:  salt (u'salt', 1)
# WordNet match:  potato (u'potatoes', 1)
# WordNet match:  salt (u'salt', 1)
# WordNet match:  taste (u'salt', 0.9473684210526315)
# WordNet match:  pepper (u'ground black pepper ', 1.0)
# WordNet match:  pepper (u'ground black pepper ', 1.0)
# WordNet match:  potato (u'potatoes', 1)
# WordNet match:  potato (u'potatoes', 1)
# WordNet match:  potato (u'potatoes', 1)
# Ingredients:
# {u'name': u'Fingerling potatoes', u'unit': u'kg', u'quantity': u'0.68'}
# {u'name': u'Red bell pepper', u'unit': u'', u'quantity': u'1'}
# {u'name': u'Red onion', u'unit': u'', u'quantity': u'1'}
# {u'name': u'Extra virgin olive oil', u'unit': u'ml', u'quantity': u'44'}
# {u'name': u'Kosher Salt', u'unit': u'ml', u'quantity': u'2'}
# {u'name': u'Pepper', u'unit': u'ml', u'quantity': u'0.62'}
# {u'name': u'Light or olive oil based mayonnaise', u'unit': u'ml', u'quantity': u'59'}
# {u'name': u'Lemon juice', u'unit': u'ml', u'quantity': u'22'}
# {u'name': u'Extra virgin olive oil', u'unit': u'ml', u'quantity': u'10'}
# {u'name': u'Fresh thyme leaves', u'unit': u'ml', u'quantity': u'10'}
# {u'name': u'Lemon zest', u'unit': u'ml', u'quantity': u'7'}
# ...
#     (PP
#       (IN with)
#       (NP
#         (NP (DT some) (NNP Gorgonzola) (NN butter))
#         (CC and)
#         (NP (NN serve.))))))
# WordNet match:  asparagus (u'asparagus', 1)
# WordNet match:  asparagus (u'asparagus', 1)
# WordNet match:  asparagus (u'asparagus', 1)
# WordNet match:  asparagus (u'asparagus', 1)
# Ingredients:
# Instructions:
# Preheat oven to 375.
# (ROOT
#   (S (VP (VB Preheat) (NP (NN oven)) (PP (TO to) (NP (CD 375.))))))
# Spray muffin cups with cooking spray.
# (ROOT
#   (S
#     (VP
#       (VB Spray)
#       (NP (NN muffin) (NNS cups))
#       (PP (IN with) (NP (JJ cooking) (NN spray.))))))
# Brown beef in skillet and drain fat.
# (ROOT
#   (NP
#     (NP (NNP Brown))
#     (NP
#       (NP (NN beef))
#       (PP (IN in) (NP (NN skillet) (CC and) (NN drain) (NN fat.))))))
# Add taco seasoning mix and water called for one package and simmer for 4/5 minutes.
# (ROOT
#   (S
#     (VP
#       (VP
#         (VB Add)
#         (NP
#           (NP (NN taco) (VBG seasoning) (NN mix))
#           (CC and)
#           (NP
#             (NP (NN water))
#             (VP
#               (VBN called)
#               (PP (IN for) (NP (CD one) (NN package)))))))
#       (CC and)
#       (VP (VB simmer) (PP (IN for) (NP (CD 4/5) (NN minutes.)))))))
# Set aside.
# (ROOT (S (VP (VB Set) (NP (NN aside.)))))
# Place one wanton paper in bottom of each muffin cup.
# (ROOT
#   (S
#     (VP
#       (VB Place)
#       (NP (CD one) (NN wanton) (NN paper))
#       (PP
#         (IN in)
#         (NP
#           (NP (NN bottom))
#           (PP (IN of) (NP (DT each) (NN muffin) (NN cup.))))))))
# Later about 1 tbsp of refried beans on top of each.
# (ROOT
#   (NP
#     (NP (RB Later) (RB about))
#     (NP
#       (NP (CD 1) (NN tbsp))
#       (PP
#         (IN of)
#         (NP
#           (NP (JJ refried) (NNS beans))
#           (PP
#             (IN on)
#             (NP (NP (NN top)) (PP (IN of) (NP (NN each.))))))))))
# Crush one tortilla chip on top of beans.
# (ROOT
#   (S
#     (VP
#       (VB Crush)
#       (NP (CD one) (NN tortilla) (NN chip))
#       (PP (IN on) (NP (NP (NN top)) (PP (IN of) (NP (NN beans.))))))))
# Top with 1 tbsp of taco meat and 1 tbsp of shredded cheese.
# (ROOT
#   (ADJP
#     (ADJP (NNP Top))
#     (PP
#       (IN with)
#       (NP
#         (NP
#           (NP (CD 1) (NN tbsp))
#           (PP (IN of) (NP (NN taco) (NN meat))))
#         (CC and)
#         (NP
#           (NP (CD 1) (NN tbsp))
#           (PP (IN of) (NP (JJ shredded) (NN cheese.))))))))
# Bake for 15-18 minutes.
# (ROOT (S (VP (VB Bake) (PP (IN for) (NP (CD 15-18) (NN minutes.))))))
# Ingredients:
# {u'name': u'box of brownie mix and ', u'unit': u'', u'quantity': u'1'}
# {u'name': u'cream cheese', u'unit': u'8 oz', u'quantity': u'1'}
# {u'name': u'sugar', u'unit': u'ml', u'quantity': u'79'}
# {u'name': u'vanilla', u'unit': u'ml', u'quantity': u'2'}
# {u'name': u'sliced fresh strawberries', u'unit': u'ml', u'quantity': u'473'}
# {u'name': u'fresh blueberries', u'unit': u'ml', u'quantity': u'237'}
# {u'name': u'fresh raspberries', u'unit': u'ml', u'quantity': u'237'}
# {u'name': u'apple jelly', u'unit': u'ml', u'quantity': u'118'}
# Instructions:
# Heat oven to 350°F (or 325°F for dark or nonstick pan).
# (ROOT
#   (S
#     (NP (NNP Heat))
#     (VP
#       (VBN oven)
#       (PP
#         (TO to)
#         (NP
#           (CD 350degF)
#           (JJ -LRB-or)
#           (CD 325degF)
#           (IN for)
#           (NN dark)
#           (CC or)
#           (NN nonstick)
#           (NNS pan-RRB-.))))))
# Grease bottom only of 12-inch pizza pan with cooking spray or shortening.
# (ROOT
#   (NP
#     (NP (NN Grease))
#     (NP
#       (NP (NN bottom) (RB only))
#       (PP
#         (IN of)
#         (NP
#           (NP (JJ 12-inch) (NN pizza) (NNS pan))
#           (PP
#             (IN with)
#             (NP (JJ cooking) (NN spray) (CC or) (NN shortening.))))))))
# In large bowl, stir brownie mix, butter and eggs until well blended.
# (ROOT
#   (SINV
#     (PP (IN In) (NP (JJ large) (NNS bowl,)))
#     (VP
#       (VBP stir)
#       (NP (JJ brownie) (JJ mix,) (NN butter) (CC and) (NNS eggs))
#       (SBAR (IN until) (FRAG (ADVP (RB well)))))
#     (NP (NNP blended.))))
# Spread in pan.
# (ROOT (VP (VBN Spread) (PP (IN in) (NP (NN pan.)))))
# Bake 18 to 20 minutes or until toothpick inserted 2 inches from side of pan comes out clean or almost clean.
# (ROOT
#   (S
#     (NP
#       (NP (NNP Bake) (CD 18))
#       (PP
#         (PP (TO to) (NP (CD 20) (NNS minutes)))
#         (CC or)
#         (PP
#           (IN until)
#           (NP
#             (NP (NN toothpick))
#             (VP
#               (VBN inserted)
#               (NP (CD 2) (NNS inches))
#               (PP
#                 (IN from)
#                 (NP (NP (NN side)) (PP (IN of) (NP (NNP pan))))))))))
#     (VP
#       (VBZ comes)
#       (PRT (RP out))
#       (NP (ADJP (JJ clean) (CC or) (RB almost)) (NN clean.)))))
# Cool completely, about 1 hour.
# (ROOT
#   (NP
#     (NP (NNP Cool) (NNP completely,))
#     (NP (NP (QP (RB about) (CD 1))) (NP (NN hour.)))))
# In small bowl, beat cream cheese, sugar and vanilla with electric mixer on medium speed until smooth.
# (ROOT
#   (S
#     (PP (IN In) (NP (JJ small) (NNS bowl,)))
#     (NP (NN beat) (NN cream))
#     (VP
#       (VBD cheese,)
#       (NP (NN sugar) (CC and) (NN vanilla))
#       (PP
#         (IN with)
#         (NP
#           (NP (JJ electric) (NN mixer))
#           (PP (IN on) (NP (NN medium) (NN speed)))))
#       (PP (IN until) (NP (NN smooth.))))))
# Spread mixture evenly over brownie base.
# (ROOT
#   (S
#     (VP
#       (VB Spread)
#       (NP (NN mixture))
#       (ADVP (RB evenly))
#       (PP (IN over) (NP (JJ brownie) (NN base.))))))
# Arrange berries over cream cheese mixture.
# (ROOT
#   (S
#     (VP
#       (VB Arrange)
#       (NP (NNS berries))
#       (PP (IN over) (NP (NN cream) (NN cheese) (NN mixture.))))))
# Stir jelly until smooth; brush over berries.
# (ROOT
#   (S
#     (VP
#       (VB Stir)
#       (ADVP (RB jelly))
#       (PP
#         (IN until)
#         (NP
#           (NP (JJ smooth;) (NN brush))
#           (PP (IN over) (NP (NN berries.))))))))
# Refrigerate about 1 hour or until chilled.
# (ROOT
#   (S
#     (VP
#       (VB Refrigerate)
#       (PP
#         (PP (IN about) (NP (CD 1) (NN hour)))
#         (CC or)
#         (PP (IN until) (NP (NN chilled.)))))))
# Cut into wedges.
# (ROOT (FRAG (NP (NNP Cut)) (PP (IN into) (NP (NN wedges.)))))
# Store covered in refrigerator.
# (ROOT
#   (S
#     (NP (NNP Store))
#     (VP (VBN covered) (PP (IN in) (NP (NN refrigerator.))))))
# Ingredients:
# {u'name': u'Butter', u'unit': u'ml', u'quantity': u'355'}
# {u'name': u'Sugar', u'unit': u'ml', u'quantity': u'473'}
# {u'name': u'Eggs', u'unit': u'large', u'quantity': u'4'}
# {u'name': u'Vanilla extract', u'unit': u'ml', u'quantity': u'5'}
# {u'name': u'All purpose flour', u'unit': u'ml', u'quantity': u'1183'}
# {u'name': u'Baking powder', u'unit': u'ml', u'quantity': u'10'}
# {u'name': u'Salt', u'unit': u'ml', u'quantity': u'5'}
# Instructions:
# In a large bowl, cream together butter and sugar until smooth.
# (ROOT
#   (FRAG
#     (PP (IN In) (NP (DT a) (JJ large) (JJ bowl,) (NN cream)))
#     (NP
#       (NP (RB together) (NN butter) (CC and) (NN sugar))
#       (PP (IN until) (NP (NN smooth.))))))
# Beat in eggs and vanilla.
# (ROOT
#   (S
#     (VP
#       (VB Beat)
#       (PP (IN in) (NP (NNS eggs) (CC and) (NN vanilla.))))))
# Stir in the flour, baking powder, and salt.
# (ROOT
#   (S
#     (VP
#       (VB Stir)
#       (PP
#         (IN in)
#         (NP
#           (NP (DT the) (JJ flour,) (JJ baking) (NN powder,))
#           (CC and)
#           (NP (NN salt.)))))))
# Cover, and chill dough for at least one hour (or overnight).
# (ROOT
#   (S
#     (VP
#       (VB Cover,)
#       (CC and)
#       (VB chill)
#       (NP (NN dough))
#       (PP
#         (IN for)
#         (NP
#           (QP (IN at) (JJS least) (CD one))
#           (NN hour)
#           (NN -LRB-or)
#           (NNS overnight-RRB-.))))))
# Preheat oven to 400 degrees F. Roll out dough on a floured surface to desired thickness (thin will make crispy cookies - a little thicker, approximately 1/4 inch will make fluffy, melt in your mouth cookies).
# (ROOT
#   (S
#     (S
#       (NP
#         (NP (JJ Preheat) (NN oven))
#         (PP
#           (TO to)
#           (NP
#             (NP (CD 400) (NNS degrees))
#             (SBAR
#               (S
#                 (NP (NNP F.) (NNP Roll))
#                 (ADVP (RB out))
#                 (VP
#                   (VBP dough)
#                   (PP
#                     (IN on)
#                     (NP
#                       (NP (DT a) (JJ floured) (NN surface))
#                       (PP
#                         (TO to)
#                         (NP
#                           (VBN desired)
#                           (NN thickness)
#                           (NN -LRB-thin)))))))))))
#       (VP (MD will) (VP (VB make) (NP (JJ crispy) (NNS cookies)))))
#     (: -)
#     (S
#       (NP
#         (DT a)
#         (JJ little)
#         (JJ thicker,)
#         (ADJP (QP (RB approximately) (CD 1/4)))
#         (NN inch))
#       (VP
#         (MD will)
#         (VP
#           (VB make)
#           (NP
#             (NP (NNP fluffy,) (NNP melt))
#             (PP
#               (IN in)
#               (NP (PRP$ your) (NN mouth) (NN cookies-RRB-.)))))))))
# Cut into desired shapes with floured cookie cutters.
# (ROOT
#   (FRAG
#     (NP (NNP Cut))
#     (PP
#       (IN into)
#       (NP
#         (NP (VBN desired) (NNS shapes))
#         (PP (IN with) (NP (JJ floured) (NN cookie) (NN cutters.)))))))
# Place cookies 1 inch apart on a parchment lined cookie sheet (sprinkle with a little colored or Turbinado sugar, if desired).
# (ROOT
#   (S
#     (VP
#       (VB Place)
#       (NP (NNS cookies))
#       (PP
#         (ADVP (NP (CD 1) (NN inch)) (RB apart))
#         (IN on)
#         (NP
#           (NP (DT a) (NN parchment))
#           (VP
#             (VBN lined)
#             (NP
#               (NP (NN cookie) (NN sheet) (NN -LRB-sprinkle))
#               (PP
#                 (IN with)
#                 (NP
#                   (NP (DT a) (RB little) (VBN colored))
#                   (CC or)
#                   (NP (NNP Turbinado) (NNP sugar,))))))))
#       (SBAR (IN if) (S (VP (VBZ desired-RRB-.)))))))
# Bake cookies for 6 to 8 minutes in preheated oven.
# (ROOT
#   (S
#     (VP
#       (VB Bake)
#       (NP (NNS cookies))
#       (PP
#         (IN for)
#         (NP
#           (NP (QP (CD 6) (TO to) (CD 8)) (NNS minutes))
#           (PP (IN in) (NP (JJ preheated) (NN oven.))))))))
# Let sit a few minutes on the sheet, then transfer to a wire rack to cool completely.
# (ROOT
#   (S
#     (VP
#       (VB Let)
#       (S
#         (VP
#           (VB sit)
#           (NP
#             (NP (DT a) (JJ few) (NNS minutes))
#             (PP (IN on) (NP (DT the) (NN sheet,))))
#           (ADVP (RB then))
#           (VP
#             (VB transfer)
#             (PP (TO to) (NP (DT a) (NN wire) (NN rack)))
#             (S (VP (TO to) (VP (VB cool) (NP (NN completely.)))))))))))
# Enjoy as is, or frost and decorate as desired.
# (ROOT
#   (ADJP
#     (ADJP (RB Enjoy) (RB as) (JJ is,) (CC or) (JJ frost))
#     (CC and)
#     (ADJP (JJ decorate) (PP (IN as) (NP (NN desired.))))))
# Makes about 5 dozen cookies (depending on thickness and size).
# (ROOT
#   (NP
#     (NP (NNS Makes))
#     (NP
#       (NP (QP (RB about) (CD 5) (NN dozen)) (NNS cookies))
#       (ADJP
#         (JJ -LRB-depending)
#         (PP (IN on) (NP (NN thickness) (CC and) (NN size-RRB-.)))))))
# WordNet match:  salt (u'salt', 1)
# WordNet match:  dough (u'sugar', 1.0)
# WordNet match:  Turbinado_sugar (u'sugar', 1.0)
# WordNet match:  Turbinado_sugar (u'sugar', 1.0)
# Ingredients:
# {u'name': u'Biscuits', u'unit': u'cans', u'quantity': u'2'}
# {u'name': u'Ground Beef', u'unit': u'kg', u'quantity': u'0.45'}
# {u'name': u'Cheese of your choice', u'unit': u'kg', u'quantity': u'0.23'}
# {u'name': u'Bacon', u'unit': u'kg', u'quantity': u'0.45'}
# Instructions:
# Just separate refrigerated biscuit dough into 8 biscuits.
# (ROOT
#   (FRAG
#     (NP (RB Just) (JJ separate))
#     (VP
#       (VBD refrigerated)
#       (NP (NN biscuit) (NN dough))
#       (PP (IN into) (NP (CD 8) (NN biscuits.))))))
# Cut each biscuit in half; roll each into ball.
# (ROOT
#   (S
#     (VP
#       (VB Cut)
#       (NP
#         (NP (DT each) (NN biscuit))
#         (PP (IN in) (NP (NP (JJ half;) (NN roll)) (NP (DT each)))))
#       (PP (IN into) (NP (NN ball.))))))
# Roll out each ball with rolling pin or press with hands until about 3 inches in diameter.
# (ROOT
#   (S
#     (VP
#       (VP
#         (VB Roll)
#         (PRT (RP out))
#         (NP
#           (NP (DT each) (NN ball))
#           (PP (IN with) (NP (JJ rolling) (NN pin)))))
#       (CC or)
#       (VP
#         (VB press)
#         (PP (IN with) (NP (NNS hands)))
#         (PP
#           (IN until)
#           (NP
#             (NP (QP (RB about) (CD 3)) (NNS inches))
#             (PP (IN in) (NP (NN diameter.)))))))))
# In center of each biscuit round, place 1 teaspoon ground beef and 1 cube of cheese.
# (ROOT
#   (PP
#     (IN In)
#     (NP
#       (NP (NN center))
#       (PP
#         (IN of)
#         (NP
#           (NP
#             (DT each)
#             (NN biscuit)
#             (NN round,)
#             (NN place)
#             (CD 1)
#             (NN teaspoon)
#             (NN ground)
#             (NN beef))
#           (CC and)
#           (NP (NP (CD 1) (NN cube)) (PP (IN of) (NP (NN cheese.)))))))))
# Roll up dough to completely enclose beef and cheese; pinch to seal well.
# (ROOT
#   (S
#     (NP (NNP Roll))
#     (VP
#       (ADVP (RB up))
#       (VBP dough)
#       (S
#         (VP
#           (TO to)
#           (VP
#             (ADVP (RB completely))
#             (VB enclose)
#             (NP (NN beef) (CC and) (NN cheese;) (NN pinch))
#             (S (VP (TO to) (VP (VB seal) (NP (NN well.)))))))))))
# Set aside.
# (ROOT (S (VP (VB Set) (NP (NN aside.)))))
# Wrap each stuffed “bomb” with 1 bacon slice; gently secure loose bacon with toothpick by inserting it through bacon and halfway into the bomb.
# (ROOT
#   (S
#     (VP
#       (VB Wrap)
#       (NP
#         (NP (DT each) (JJ stuffed) (NN "bomb"))
#         (PP (IN with) (NP (CD 1) (NN bacon) (NNS slice;))))
#       (ADVP (RB gently))
#       (VP
#         (VB secure)
#         (NP (JJ loose) (NN bacon))
#         (PP (IN with) (NP (NN toothpick)))
#         (PP
#           (IN by)
#           (S
#             (VP
#               (VBG inserting)
#               (NP (PRP it))
#               (PP (IN through) (NP (NN bacon) (CC and) (NN halfway)))
#               (PP (IN into) (NP (DT the) (NN bomb.))))))))))
# In 10- to 12-inch skillet, heat oil to 350°F.
# (ROOT
#   (PP
#     (IN In)
#     (NP
#       (NP (CD 10-))
#       (PP
#         (TO to)
#         (NP
#           (NP (JJ 12-inch) (JJ skillet,) (NN heat) (NN oil))
#           (PP (TO to) (NP (CD 350degF.))))))))
# Fry stuffed bombs for 4 to 5 minutes or until dough is golden brown on all sides.
# (ROOT
#   (UCP
#     (S
#       (NP (NNP Fry) (NNP stuffed))
#       (NP
#         (NP (NNS bombs))
#         (PP (IN for) (NP (QP (CD 4) (TO to) (CD 5)) (NNS minutes)))))
#     (CC or)
#     (SBAR
#       (IN until)
#       (S
#         (NP (NN dough))
#         (VP
#           (VBZ is)
#           (NP
#             (NP (JJ golden) (NNS brown))
#             (PP (IN on) (NP (DT all) (NN sides.)))))))))
# (If needed, remove toothpick once bacon has fried on one side in order to flip them over in the oil.)
# (ROOT
#   (FRAG
#     (NP (JJ -LRB-If) (NNS needed,))
#     (VP
#       (VB remove)
#       (NP (NN toothpick))
#       (SBAR
#         (IN once)
#         (S
#           (NP (NN bacon))
#           (VP
#             (VBZ has)
#             (VP
#               (VBN fried)
#               (PP
#                 (IN on)
#                 (NP
#                   (NP (CD one) (NN side))
#                   (PP (IN in) (NP (NN order)))))
#               (S
#                 (VP
#                   (TO to)
#                   (VP
#                     (VB flip)
#                     (NP (PRP them))
#                     (PRT (RP over))
#                     (PP (IN in) (NP (DT the) (NN oil.-RRB-)))))))))))))
# Place on paper towels to cool.
# (ROOT
#   (S
#     (VP
#       (VB Place)
#       (PP (IN on) (NP (NN paper) (NNS towels)))
#       (PP (TO to) (NP (NN cool.))))))
# Cool slightly before serving.
# (ROOT
#   (S
#     (VP
#       (VB Cool)
#       (ADVP (RB slightly))
#       (PP (IN before) (NP (NN serving.))))))
# WordNet match:  8_biscuit (u'biscuits', 1.0)
# WordNet match:  each_biscuit (u'biscuits', 1.0)
# WordNet match:  loose_bacon (u'bacon', 1.0)
# WordNet match:  loose_bacon (u'bacon', 1.0)
# WordNet match:  bacon (u'bacon', 1)

# %%
total_kb = {key:value for key,value in total_kb.iteritems() if value and len(value) > 0}
print_knowledge_base(total_kb)
# Out:
# icing sugar
# 	Counter({(u'add', u'VB'): 1})
# deli ham
# 	Counter({(u'place', u'VB'): 2, (u'take', u'VB'): 1})
# chuck roast
# 	Counter({(u'pour', u'VB'): 2, (u'add', u'VB'): 2})
# bunch kale
# 	Counter({(u'saut\xe9', u'VB'): 1})
# chicken
# 	Counter({(u'add', u'VB'): 1})
# medium zucchini
# 	Counter({(u'add', u'VB'): 6, (u'cook', u'VB'): 4})
# blueberries
# 	Counter({(u'serve', u'VB'): 2})
# raw honey
# 	Counter({(u'add', u'VB'): 2, (u'stir', u'VB'): 1})
# rosemary sprigs
# 	Counter({(u'discard', u'VB'): 2, (u'brown', u'VB'): 1, (u'remove', u'VB'): 1, (u'tuck', u'VB'): 1})
# gherkin pickles
# 	Counter({(u'pour', u'VB'): 6, (u'add', u'VB'): 4, (u'pllace', u'VB'): 2})
# oranges
# 	Counter({(u'add', u'VB'): 1})
# red wine
# 	Counter({(u'deglaze', u'VB'): 3, (u'add', u'VB'): 2, (u'sweat', u'VB'): 1})
# crushed tomatoes
# 	Counter({(u'add', u'VB'): 1})
# garlic, or 1/4 teaspoon garlic powder
# 	Counter({(u'chop', u'VB'): 2, (u'peel', u'VB'): 1})
# caramel ice cream topping
# 	Counter({(u'drizzle', u'VB'): 2, (u'place', u'VB'): 1})
# potatoes
# 	Counter({(u'continue', u'VB'): 2, (u'shred', u'VB'): 1, (u'peel', u'VB'): 1, (u'foil', u'VB'): 1})
# sliced mushrooms
# 	Counter({(u'add', u'VB'): 2, (u'cook', u'VB'): 1})
# pork tenderloins
# 	Counter({(u'place', u'VB'): 2, (u'test', u'VB'): 2, (u'pour', u'VB'): 1, (u'remove', u'VB'): 1})
# prosciutto
# 	Counter({(u'crumble', u'VB'): 2, (u'fold', u'VB'): 1, (u'bake', u'VB'): 1})
# cooked corn
# 	Counter({(u'turn', u'VB'): 4, (u'top', u'VB'): 2})
# white wine
# 	Counter({(u'pour', u'VB'): 2, (u'add', u'VB'): 1})
# lime zest
# 	Counter({(u'lime', u'VB'): 2})
# lean corned beef
# 	Counter({(u'add', u'VB'): 6, (u'bring', u'VB'): 3, (u'remove', u'VB'): 2})
# hibiscus tea bags
# 	Counter({(u'remove', u'VB'): 4, (u'allow', u'VB'): 3, (u'squeeze', u'VB'): 1})
# white vinegar
# 	Counter({(u'fill', u'VB'): 1})
# wheat english muffin
# 	Counter({(u'serve', u'VB'): 1})
# chicken stock
# 	Counter({(u'stir', u'VB'): 4, (u'turn', u'VB'): 1})
# turkey breast
# 	Counter({(u'pour', u'VB'): 2, (u'spread', u'VB'): 1})
# ground beef patties
# 	Counter({(u'top', u'VB'): 2, (u'continue', u'VB'): 1})
# tomato salsa
# 	Counter({(u'serve', u'VB'): 1})
# real butter
# 	Counter({(u'add', u'VB'): 2, (u'run', u'VB'): 1})
# barley
# 	Counter({(u'saute', u'VB'): 1, (u'stir', u'VB'): 1, (u'add', u'VB'): 1})
# garlic minced
# 	Counter({(u'saute', u'VB'): 2, (u'add', u'VB'): 1})
# coconut oil
# 	Counter({(u'melt', u'VB'): 6, (u'be', u'VB'): 2, (u'freezer,', u'VB'): 2, (u'cool', u'VB'): 1, (u'add', u'VB'): 1})
# balsamic vinegar
# 	Counter({(u'combine', u'VB'): 3, (u'make', u'VB'): 2})
# vinegar
# 	Counter({(u'add', u'VB'): 1})
# biscuits
# 	Counter({(u'cut', u'VB'): 1})
# wheat hamburger buns
# 	Counter({(u'cover', u'VB'): 2, (u'onion', u'VB'): 1, (u'add', u'VB'): 1})
# yellow pepper
# 	Counter({(u'add', u'VB'): 4, (u'cook', u'VB'): 2})
# neufchatel cheese
# 	Counter({(u'bake', u'VB'): 1})
# miso
# 	Counter({(u'create', u'VB'): 4, (u'add', u'VB'): 2})
# spicy tomato sauce
# 	Counter({(u'pour', u'VB'): 1})
# kale (lacinto)
# 	Counter({(u'massage', u'VB'): 3, (u'use', u'VB'): 1})
# red potatoes
# 	Counter({(u'cook', u'VB'): 8, (u'put', u'VB'): 4, (u'stick', u'VB'): 3, (u'drain', u'VB'): 2, (u'need', u'VB'): 2, (u'toss', u'VB'): 2, (u'be', u'VB'): 1, (u'add', u'VB'): 1, (u'fall', u'VB'): 1, (u'bring', u'VB'): 1, (u'flip', u'VB'): 1})
# soy
# 	Counter({(u'be', u'VB'): 2, (u'cool', u'VB'): 2, (u'remain', u'VB'): 2, (u'refrigerate', u'VB'): 1})
# large red peppers
# 	Counter({(u'remove', u'VB'): 1})
# butterscotch chips
# 	Counter({(u'add', u'VB'): 1})
# leeks
# 	Counter({(u'cook', u'VB'): 1})
# turkey
# 	Counter({(u'place', u'VB'): 2, (u'rinse', u'VB'): 2, (u'remove', u'VB'): 2, (u'roast', u'VB'): 1, (u'baste', u'VB'): 1, (u'pan', u'VB'): 1, (u'pour', u'VB'): 1, (u'stuff', u'VB'): 1, (u'soak', u'VB'): 1, (u'skim', u'VB'): 1})
# russet potatoes (or 3 cups mashed potatoes)
# 	Counter({(u'strain', u'VB'): 2, (u'simmer', u'VB'): 2, (u'reduce', u'VB'): 1, (u'transfer', u'VB'): 1, (u'mash', u'VB'): 1})
# parsley
# 	Counter({(u'stuff', u'VB'): 1})
# buttermilk
# 	Counter({(u'combine', u'VB'): 1})
# yellow mustard seeds
# 	Counter({(u'rinse', u'VB'): 7, (u'bring', u'VB'): 6, (u'add', u'VB'): 5, (u'cover', u'VB'): 3, (u'drain', u'VB'): 3})
# soy flakes
# 	Counter({(u'bring', u'VB'): 1, (u'reduce', u'VB'): 1, (u'simmer,', u'VB'): 1, (u'add', u'VB'): 1})
# white onion
# 	Counter({(u'soak', u'VB'): 1})
# chorizo sausage
# 	Counter({(u'add', u'VB'): 2, (u'swap', u'VB'): 1, (u'cook', u'VB'): 1})
# shallot
# 	Counter({(u'deglaze', u'VB'): 1, (u'sweat', u'VB'): 1, (u'add', u'VB'): 1})
# strawberries
# 	Counter({(u'hull', u'VB'): 2, (u'pick', u'VB'): 1})
# chile peppers
# 	Counter({(u'hold', u'VB'): 3, (u'pick', u'VB'): 3, (u'remove', u'VB'): 2, (u'rub', u'VB'): 1})
# oil
# 	Counter({(u'add', u'VB'): 4, (u'coat', u'VB'): 3, (u'sit', u'VB'): 2, (u'turn', u'VB'): 1, (u'place', u'VB'): 1})
# instant yeast
# 	Counter({(u'sit', u'VB'): 2, (u'add', u'VB'): 1})
# pizza dough
# 	Counter({(u'cut', u'VB'): 3, (u'roll', u'VB'): 1, (u'use', u'VB'): 1})
# fresh spinach
# 	Counter({(u'place', u'VB'): 1, (u'lay', u'VB'): 1})
# vegan sour cream
# 	Counter({(u'stir', u'VB'): 4, (u'take', u'VB'): 2, (u'return', u'VB'): 1})
# monterey jack
# 	Counter({(u'turn', u'VB'): 2, (u'top', u'VB'): 1})
# basmati rice
# 	Counter({(u'cook', u'VB'): 1})
# broth
# 	Counter({(u'bring', u'VB'): 1, (u'reduce', u'VB'): 1, (u'simmer,', u'VB'): 1, (u'add', u'VB'): 1})
# cauliflower
# 	Counter({(u'place', u'VB'): 2, (u'add', u'VB'): 1, (u'steam', u'VB'): 1, (u'wrap', u'VB'): 1, (u'make', u'VB'): 1})
# turkey stock
# 	Counter({(u'rub', u'VB'): 6, (u'add', u'VB'): 3, (u'serve', u'VB'): 2, (u'bring', u'VB'): 2, (u'pour', u'VB'): 2, (u'strain', u'VB'): 1, (u'slice', u'VB'): 1, (u'transfer', u'VB'): 1, (u'baste', u'VB'): 1, (u'simmer', u'VB'): 1})
# beef fillet
# 	Counter({(u'sear', u'VB'): 1, (u'glaze', u'VB'): 1, (u'cook', u'VB'): 1})
# fresh lemon
# 	Counter({(u'squeeze', u'VB'): 2, (u'add', u'VB'): 1})
# yellow onion
# 	Counter({(u'stuff', u'VB'): 2})
# egg
# 	Counter({(u'sit', u'VB'): 2, (u'add', u'VB'): 1})
# onions
# 	Counter({(u'stir', u'VB'): 2, (u'add', u'VB'): 1})
# bread flour
# 	Counter({(u'add', u'VB'): 3})
# heavy cream (more to taste)
# 	Counter({(u'splash', u'VB'): 2, (u'stir', u'VB'): 1})
#  milk
# 	Counter({(u'thicken', u'VB'): 2, (u'smooth', u'VB'): 1, (u'add', u'VB'): 1})
# flank steak
# 	Counter({(u'place', u'VB'): 3, (u'wrap', u'VB'): 1})
# minced garlic
# 	Counter({(u'coat', u'VB'): 1})
# quinoa
# 	Counter({(u'scoop', u'VB'): 1})
# cabbage
# 	Counter({(u'add', u'VB'): 6, (u'return', u'VB'): 2})
# vinaigrette
# 	Counter({(u'taste', u'VB'): 2, (u'add', u'VB'): 2, (u'dress', u'VB'): 2, (u'mix', u'VB'): 1, (u'adjust', u'VB'): 1, (u'create', u'VB'): 1})
# sesame seeds
# 	Counter({(u'scatter', u'VB'): 1})
# lasagna noodles
# 	Counter({(u'use', u'VB'): 4, (u'layer', u'VB'): 3, (u'cook', u'VB'): 2, (u'top', u'VB'): 2, (u'bake', u'VB'): 1, (u'pour', u'VB'): 1})
# hummus (cilantro or other)
# 	Counter({(u'spread', u'VB'): 1})
# medium shrimp
# 	Counter({(u'continue', u'VB'): 2, (u'add', u'VB'): 1})
# egg
# 	Counter({(u'microwave', u'VB'): 1})
# chicken breasts
# 	Counter({(u'spread', u'VB'): 2, (u'mix', u'VB'): 1})
# apple cider vinegar
# 	Counter({(u'whisk', u'VB'): 4, (u'stir', u'VB'): 2})

# %%
# Change counters to percentages

kb = {}
for ingredient, counts in total_kb.iteritems():
    banned = [('add', 'VB')]
    for ban in banned:
        if ban in counts:
            del(counts[ban])
            
    total = sum([count for verb,count in counts.iteritems()])
    kb[ingredient] = {verb : count/float(total) for verb,count in counts.iteritems()}
    
print_knowledge_base(kb)
# Out:
# icing sugar
# 	{}
# deli ham
# 	{(u'place', u'VB'): 0.6666666666666666, (u'take', u'VB'): 0.3333333333333333}
# chuck roast
# 	{(u'pour', u'VB'): 1.0}
# bunch kale
# 	{(u'saut\xe9', u'VB'): 1.0}
# chicken
# 	{}
# medium zucchini
# 	{(u'cook', u'VB'): 1.0}
# blueberries
# 	{(u'serve', u'VB'): 1.0}
# raw honey
# 	{(u'stir', u'VB'): 1.0}
# rosemary sprigs
# 	{(u'brown', u'VB'): 0.2, (u'discard', u'VB'): 0.4, (u'remove', u'VB'): 0.2, (u'tuck', u'VB'): 0.2}
# gherkin pickles
# 	{(u'pllace', u'VB'): 0.25, (u'pour', u'VB'): 0.75}
# oranges
# 	{}
# red wine
# 	{(u'deglaze', u'VB'): 0.75, (u'sweat', u'VB'): 0.25}
# crushed tomatoes
# 	{}
# garlic, or 1/4 teaspoon garlic powder
# 	{(u'peel', u'VB'): 0.3333333333333333, (u'chop', u'VB'): 0.6666666666666666}
# caramel ice cream topping
# 	{(u'place', u'VB'): 0.3333333333333333, (u'drizzle', u'VB'): 0.6666666666666666}
#  milk
# 	{(u'thicken', u'VB'): 0.6666666666666666, (u'smooth', u'VB'): 0.3333333333333333}
# sliced mushrooms
# 	{(u'cook', u'VB'): 1.0}
# pork tenderloins
# 	{(u'place', u'VB'): 0.3333333333333333, (u'pour', u'VB'): 0.16666666666666666, (u'test', u'VB'): 0.3333333333333333, (u'remove', u'VB'): 0.16666666666666666}
# prosciutto
# 	{(u'fold', u'VB'): 0.25, (u'bake', u'VB'): 0.25, (u'crumble', u'VB'): 0.5}
# potatoes
# 	{(u'shred', u'VB'): 0.2, (u'peel', u'VB'): 0.2, (u'continue', u'VB'): 0.4, (u'foil', u'VB'): 0.2}
# biscuits
# 	{(u'cut', u'VB'): 1.0}
# white wine
# 	{(u'pour', u'VB'): 1.0}
# lime zest
# 	{(u'lime', u'VB'): 1.0}
# lean corned beef
# 	{(u'bring', u'VB'): 0.6, (u'remove', u'VB'): 0.4}
# hibiscus tea bags
# 	{(u'squeeze', u'VB'): 0.125, (u'allow', u'VB'): 0.375, (u'remove', u'VB'): 0.5}
# egg
# 	{(u'sit', u'VB'): 1.0}
# white vinegar
# 	{(u'fill', u'VB'): 1.0}
# wheat english muffin
# 	{(u'serve', u'VB'): 1.0}
# chicken stock
# 	{(u'turn', u'VB'): 0.2, (u'stir', u'VB'): 0.8}
# ground beef patties
# 	{(u'continue', u'VB'): 0.3333333333333333, (u'top', u'VB'): 0.6666666666666666}
# tomato salsa
# 	{(u'serve', u'VB'): 1.0}
# barley
# 	{(u'saute', u'VB'): 0.5, (u'stir', u'VB'): 0.5}
# garlic minced
# 	{(u'saute', u'VB'): 1.0}
# coconut oil
# 	{(u'be', u'VB'): 0.18181818181818182, (u'melt', u'VB'): 0.5454545454545454, (u'cool', u'VB'): 0.09090909090909091, (u'freezer,', u'VB'): 0.18181818181818182}
# balsamic vinegar
# 	{(u'combine', u'VB'): 0.6, (u'make', u'VB'): 0.4}
# vinegar
# 	{}
# cooked corn
# 	{(u'turn', u'VB'): 0.6666666666666666, (u'top', u'VB'): 0.3333333333333333}
# fresh lemon
# 	{(u'squeeze', u'VB'): 1.0}
# yellow pepper
# 	{(u'cook', u'VB'): 1.0}
# neufchatel cheese
# 	{(u'bake', u'VB'): 1.0}
# miso
# 	{(u'create', u'VB'): 1.0}
# spicy tomato sauce
# 	{(u'pour', u'VB'): 1.0}
# kale (lacinto)
# 	{(u'massage', u'VB'): 0.75, (u'use', u'VB'): 0.25}
# red potatoes
# 	{(u'be', u'VB'): 0.04, (u'drain', u'VB'): 0.08, (u'flip', u'VB'): 0.04, (u'toss', u'VB'): 0.08, (u'stick', u'VB'): 0.12, (u'fall', u'VB'): 0.04, (u'bring', u'VB'): 0.04, (u'need', u'VB'): 0.08, (u'cook', u'VB'): 0.32, (u'put', u'VB'): 0.16}
# soy
# 	{(u'be', u'VB'): 0.2857142857142857, (u'refrigerate', u'VB'): 0.14285714285714285, (u'cool', u'VB'): 0.2857142857142857, (u'remain', u'VB'): 0.2857142857142857}
# large red peppers
# 	{(u'remove', u'VB'): 1.0}
# butterscotch chips
# 	{}
# leeks
# 	{(u'cook', u'VB'): 1.0}
# turkey
# 	{(u'roast', u'VB'): 0.07692307692307693, (u'baste', u'VB'): 0.07692307692307693, (u'place', u'VB'): 0.15384615384615385, (u'rinse', u'VB'): 0.15384615384615385, (u'pan', u'VB'): 0.07692307692307693, (u'stuff', u'VB'): 0.07692307692307693, (u'soak', u'VB'): 0.07692307692307693, (u'skim', u'VB'): 0.07692307692307693, (u'pour', u'VB'): 0.07692307692307693, (u'remove', u'VB'): 0.15384615384615385}
# russet potatoes (or 3 cups mashed potatoes)
# 	{(u'strain', u'VB'): 0.2857142857142857, (u'reduce', u'VB'): 0.14285714285714285, (u'simmer', u'VB'): 0.2857142857142857, (u'transfer', u'VB'): 0.14285714285714285, (u'mash', u'VB'): 0.14285714285714285}
# parsley
# 	{(u'stuff', u'VB'): 1.0}
# buttermilk
# 	{(u'combine', u'VB'): 1.0}
# yellow mustard seeds
# 	{(u'bring', u'VB'): 0.3157894736842105, (u'cover', u'VB'): 0.15789473684210525, (u'drain', u'VB'): 0.15789473684210525, (u'rinse', u'VB'): 0.3684210526315789}
# soy flakes
# 	{(u'bring', u'VB'): 0.3333333333333333, (u'reduce', u'VB'): 0.3333333333333333, (u'simmer,', u'VB'): 0.3333333333333333}
# white onion
# 	{(u'soak', u'VB'): 1.0}
# chorizo sausage
# 	{(u'swap', u'VB'): 0.5, (u'cook', u'VB'): 0.5}
# shallot
# 	{(u'deglaze', u'VB'): 0.5, (u'sweat', u'VB'): 0.5}
# strawberries
# 	{(u'hull', u'VB'): 0.6666666666666666, (u'pick', u'VB'): 0.3333333333333333}
# chile peppers
# 	{(u'hold', u'VB'): 0.3333333333333333, (u'remove', u'VB'): 0.2222222222222222, (u'rub', u'VB'): 0.1111111111111111, (u'pick', u'VB'): 0.3333333333333333}
# oil
# 	{(u'turn', u'VB'): 0.14285714285714285, (u'place', u'VB'): 0.14285714285714285, (u'sit', u'VB'): 0.2857142857142857, (u'coat', u'VB'): 0.42857142857142855}
# beef fillet
# 	{(u'sear', u'VB'): 0.3333333333333333, (u'glaze', u'VB'): 0.3333333333333333, (u'cook', u'VB'): 0.3333333333333333}
# pizza dough
# 	{(u'cut', u'VB'): 0.6, (u'roll', u'VB'): 0.2, (u'use', u'VB'): 0.2}
# fresh spinach
# 	{(u'place', u'VB'): 0.5, (u'lay', u'VB'): 0.5}
# vegan sour cream
# 	{(u'stir', u'VB'): 0.5714285714285714, (u'take', u'VB'): 0.2857142857142857, (u'return', u'VB'): 0.14285714285714285}
# monterey jack
# 	{(u'turn', u'VB'): 0.6666666666666666, (u'top', u'VB'): 0.3333333333333333}
# basmati rice
# 	{(u'cook', u'VB'): 1.0}
# broth
# 	{(u'bring', u'VB'): 0.3333333333333333, (u'reduce', u'VB'): 0.3333333333333333, (u'simmer,', u'VB'): 0.3333333333333333}
# cauliflower
# 	{(u'place', u'VB'): 0.4, (u'steam', u'VB'): 0.2, (u'wrap', u'VB'): 0.2, (u'make', u'VB'): 0.2}
# turkey stock
# 	{(u'serve', u'VB'): 0.11764705882352941, (u'slice', u'VB'): 0.058823529411764705, (u'rub', u'VB'): 0.35294117647058826, (u'baste', u'VB'): 0.058823529411764705, (u'transfer', u'VB'): 0.058823529411764705, (u'bring', u'VB'): 0.11764705882352941, (u'simmer', u'VB'): 0.058823529411764705, (u'strain', u'VB'): 0.058823529411764705, (u'pour', u'VB'): 0.11764705882352941}
# instant yeast
# 	{(u'sit', u'VB'): 1.0}
# wheat hamburger buns
# 	{(u'cover', u'VB'): 0.6666666666666666, (u'onion', u'VB'): 0.3333333333333333}
# yellow onion
# 	{(u'stuff', u'VB'): 1.0}
# real butter
# 	{(u'run', u'VB'): 1.0}
# onions
# 	{(u'stir', u'VB'): 1.0}
# bread flour
# 	{}
# heavy cream (more to taste)
# 	{(u'stir', u'VB'): 0.3333333333333333, (u'splash', u'VB'): 0.6666666666666666}
# turkey breast
# 	{(u'spread', u'VB'): 0.3333333333333333, (u'pour', u'VB'): 0.6666666666666666}
# flank steak
# 	{(u'place', u'VB'): 0.75, (u'wrap', u'VB'): 0.25}
# minced garlic
# 	{(u'coat', u'VB'): 1.0}
# quinoa
# 	{(u'scoop', u'VB'): 1.0}
# cabbage
# 	{(u'return', u'VB'): 1.0}
# lasagna noodles
# 	{(u'layer', u'VB'): 0.23076923076923078, (u'cook', u'VB'): 0.15384615384615385, (u'use', u'VB'): 0.3076923076923077, (u'bake', u'VB'): 0.07692307692307693, (u'pour', u'VB'): 0.07692307692307693, (u'top', u'VB'): 0.15384615384615385}
# sesame seeds
# 	{(u'scatter', u'VB'): 1.0}
# vinaigrette
# 	{(u'mix', u'VB'): 0.14285714285714285, (u'dress', u'VB'): 0.2857142857142857, (u'adjust', u'VB'): 0.14285714285714285, (u'taste', u'VB'): 0.2857142857142857, (u'create', u'VB'): 0.14285714285714285}
# hummus (cilantro or other)
# 	{(u'spread', u'VB'): 1.0}
# medium shrimp
# 	{(u'continue', u'VB'): 1.0}
# egg
# 	{(u'microwave', u'VB'): 1.0}
# chicken breasts
# 	{(u'mix', u'VB'): 0.3333333333333333, (u'spread', u'VB'): 0.6666666666666666}
# apple cider vinegar
# 	{(u'stir', u'VB'): 0.3333333333333333, (u'whisk', u'VB'): 0.6666666666666666}

# %%
def get_intersection(kb, ing1, ing2):
    n = 0.0
    for verb1, count1 in kb[ing1].iteritems():
        for verb2, count2 in kb[ing2].iteritems():
            if verb1 == verb2:
                n += min(count1, count2)
    return n

MINIMUM_OVERLAP = 0.7
def are_equivalent(kb, ing1, ing2):
    return get_intersection(kb, ing1, ing2) > MINIMUM_OVERLAP
    
equivalencies = {}
for ingredient in kb:
    equivs = []
    for other in kb:
        if ingredient != other and are_equivalent(kb, ingredient, other):
            equivs.append(other)
    equivalencies[ingredient] = equivs

# %%
# print equivalencies
import pprint

equivalencies = {key:value for key,value in equivalencies.iteritems() if value and len(value) > 0}
pprint.pprint(equivalencies)
# Out:
# {u'basmati rice': [u'medium zucchini',
#                    u'sliced mushrooms',
#                    u'yellow pepper',
#                    u'leeks'],
#  u'blueberries': [u'wheat english muffin', u'tomato salsa'],
#  u'broth': [u'soy flakes'],
#  u'chicken stock': [u'raw honey', u'onions'],
#  u'chuck roast ': [u'gherkin pickles', u'white wine ', u'spicy tomato sauce'],
#  u'cooked corn': [u'monterey jack'],
#  u'egg ': [u'instant yeast '],
#  u'gherkin pickles': [u'chuck roast ', u'white wine ', u'spicy tomato sauce'],
#  u'instant yeast ': [u'egg '],
#  u'leeks': [u'medium zucchini',
#             u'sliced mushrooms',
#             u'yellow pepper',
#             u'basmati rice'],
#  u'medium zucchini': [u'sliced mushrooms',
#                       u'yellow pepper',
#                       u'leeks',
#                       u'basmati rice'],
#  u'monterey jack': [u'cooked corn'],
#  u'onions': [u'raw honey', u'chicken stock'],
#  u'parsley': [u'yellow onion'],
#  u'raw honey': [u'chicken stock', u'onions'],
#  u'red wine': [u'shallot'],
#  u'shallot': [u'red wine'],
#  u'sliced mushrooms': [u'medium zucchini',
#                        u'yellow pepper',
#                        u'leeks',
#                        u'basmati rice'],
#  u'soy flakes': [u'broth'],
#  u'spicy tomato sauce': [u'chuck roast ', u'gherkin pickles', u'white wine '],
#  u'tomato salsa': [u'blueberries', u'wheat english muffin'],
#  u'wheat english muffin': [u'blueberries', u'tomato salsa'],
#  u'white wine ': [u'chuck roast ', u'gherkin pickles', u'spicy tomato sauce'],
#  u'yellow onion': [u'parsley'],
#  u'yellow pepper': [u'medium zucchini',
#                     u'sliced mushrooms',
#                     u'leeks',
#                     u'basmati rice']}

# %%
# print total_kb
# print total_kb['rum (preferably light']
print kb['broth']
print kb['soy flakes']
# Out:
# {(u'bring', u'VB'): 0.3333333333333333, (u'reduce', u'VB'): 0.3333333333333333, (u'simmer,', u'VB'): 0.3333333333333333}
# {(u'bring', u'VB'): 0.3333333333333333, (u'reduce', u'VB'): 0.3333333333333333, (u'simmer,', u'VB'): 0.3333333333333333}
